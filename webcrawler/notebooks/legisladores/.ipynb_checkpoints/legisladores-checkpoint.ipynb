# %%
import uuid

# %%
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver import Chrome
from selenium import webdriver
import re
import time
import pandas as pd
import datetime
from tqdm import tqdm
from datetime import date
from selenium.webdriver.chrome.options import Options

main_url = 'http://cronica.diputados.gob.mx:8080/exist/siid2/siid2.xql?legis=LXII#'

options = Options()
options.add_argument('--headless')
driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# [WDM] - Current google-chrome version is 85.0.4183
# [WDM] - Get LATEST driver version for 85.0.4183
# [WDM] - Driver [/Users/cblanesg/.wdm/drivers/chromedriver/mac64/85.0.4183.87/chromedriver] found in cache

# %% [markdown]
# ## Legislatura 64

# %%
main_url = 'http://sitl.diputados.gob.mx/LXIV_leg/listado_diputados_gpnp.php?tipot=TOTAL'
driver.get(main_url)

# %%
links_diputados = []
names_diputados = []
for i in tqdm(driver.find_elements_by_css_selector('a')):
    link = i.get_attribute('href')
    if any(re.findall('curricula', link)):
        links_diputados.append(link)
        names_diputados.append(re.sub('^[0-9]+ ', '', i.text))
        
    else:
        continue
# Out:
# 100%|██████████| 511/511 [00:14<00:00, 35.92it/s]

# %%
mapping_name_party = {}
for i in names_diputados[0:251]:
    mapping_name_party[i] = 'MORENA'
    
for i in names_diputados[251: 329]:
    mapping_name_party[i] = 'PAN'
    
for i in names_diputados[329:377]:
    mapping_name_party[i] = 'PRI'
    
for i in names_diputados[377:423]:
    mapping_name_party[i] = 'PT'
    
for i in names_diputados[423:450]:
    mapping_name_party[i] = 'MC'
    
for i in names_diputados[450:474]:
    mapping_name_party[i] = 'ES'
    
for i in names_diputados[474:486]:
    mapping_name_party[i] = 'PRD'
    
for i in names_diputados[486:497]:
    mapping_name_party[i] = 'PVEM'

for i in names_diputados[497:]:
    mapping_name_party[i] = 'NA'

# %%
len(mapping_name_party)
# Out:
# 500

# %%
def obtain_id_data(name, mapping_parties, link):
    dict_id = {}
    dict_id['legislatura'] = 64
    dict_id['id_legislador'] = str(uuid.uuid1())
    dict_id['nombre_completo'] = unidecode.unidecode(name)
    dict_id['tipo_legislador'] = unidecode.unidecode(driver.find_element_by_css_selector('body > div > table.cajasombra > tbody > tr > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(2) > td:nth-child(2) > strong').text)
    dict_id['entidad'] = unidecode.unidecode(driver.find_element_by_css_selector('body > div > table.cajasombra > tbody > tr > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(1)').text)
    dict_id['distrito'] = driver.find_element_by_css_selector('body > div > table.cajasombra > tbody > tr > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(3)').text
    dict_id['info_distrito'] = driver.find_element_by_css_selector('body > div > table.cajasombra > tbody > tr > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(5)').text
    dict_id['suplente'] = unidecode.unidecode(driver.find_element_by_css_selector('body > div > table.cajasombra > tbody > tr > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(6) > td:nth-child(2)').text)
    dict_id['partido'] = mapping_parties[name]
    dict_id['link_curricula'] = link
    return(dict_id)

# %% [markdown]
# ## ID Data

# %%
data_id = []
for x, y in tqdm(zip(links_diputados, names_diputados), total = len(names_diputados)):
    driver.get(x)
    data_id.append(obtain_id_data(y, mapping_name_party, x))
# Out:
# 100%|██████████| 500/500 [11:17<00:00,  1.35s/it]

# %%
len(data_id)
# Out:
# 500

# %%
mapping_id_cand = {}
for i in data_id:
    mapping_id_cand[i['nombre_completo']] = i['id_legislador']

# %%
pd.DataFrame(data_id).to_csv('/Users/cblanesg/cam.blanes Dropbox/Camila Blanes/floor-speechMX/data/diputados/id_data/id_data.csv', encoding = 'utf-8')

# %%
df_mapping_id_cand = pd.DataFrame()
df_mapping_id_cand['name'] = list(mapping_id_cand.keys())
df_mapping_id_cand['id'] = list(mapping_id_cand.values())

# %%
df_mapping_id_cand.to_csv('/Users/cblanesg/cam.blanes Dropbox/Camila Blanes/floor-speechMX/data/diputados/id_data/mapping_id_incumbent.csv', encoding = 'utf-8')

# %%
import json

# %%
with open('/Users/cblanesg/cam.blanes Dropbox/Camila Blanes/floor-speechMX/data/diputados/id_data/legislatura64.json', 'w') as json_file:
    json.dump(data_id, json_file)

# %% [markdown]
# ## Comisiones

# %%
all_comisiones = []
for x, y in tqdm(zip(links_diputados, names_diputados), total = len(names_diputados)):
    driver.get(x)
    id_inc = mapping_id_cand[y]
    
    comisiones = driver.find_element_by_css_selector('body > div > table:nth-child(7) > tbody > tr > td > table:nth-child(1) > tbody > tr:nth-child(2) > td').text
    for i in re.sub('ORDINARIA', '', comisiones.split('\n')[0]).split('|'):
        if any(i):
            temp = {}
            temp['nombre_completo'] = y
            temp['id_legislador'] = id_inc
            temp['comision'] = re.sub('[ ]+$', '', re.sub('^[ ]+', '', i))
            all_comisiones.append(temp)
        else:
            continue
# Out:
# 100%|██████████| 500/500 [10:39<00:00,  1.28s/it]

# %%
def dummy_remove(x):
    if any(re.findall('GRUPO DE AMISTAD', x)):
        return(1)
    else:
        return(0)
df = pd.DataFrame(all_comisiones)
df['dummy_remove'] = df.apply(lambda x: dummy_remove(x['comision']), axis = 1)

# %%
df_comisiones = df[df['dummy_remove'] == 0]
df_comisiones = df_comisiones[['nombre_completo', 'id_legislador', 'comision']]

# %%
df_comisiones

# %% [markdown]
# ## Legislatura 63

# %%
main_url = 'http://sitllxiii.diputados.gob.mx/listado_diputados_gpnp.php?tipot=TOTAL'
driver.get(main_url)

# %%
links_diputados = []
names_diputados = []
for i in tqdm(driver.find_elements_by_css_selector('a')):
    link = i.get_attribute('href')
    if any(re.findall('curricula', link)):
        links_diputados.append(link)
        names_diputados.append(re.sub('^[0-9]+ ', '', i.text))
        
    else:
        continue
# Out:
# 100%|██████████| 511/511 [00:12<00:00, 40.26it/s]

# %%
mapping_name_party = {}
for i in names_diputados[0:202]:
    mapping_name_party[i] = 'pri'
    
for i in names_diputados[202: 309]:
    mapping_name_party[i] = 'pan'
    
for i in names_diputados[309:360]:
    mapping_name_party[i] = 'prd'
    
for i in names_diputados[360:410]:
    mapping_name_party[i] = 'morena'
    
for i in names_diputados[410:448]:
    mapping_name_party[i] = 'partido verde ecologista'
    
for i in names_diputados[448:469]:
    mapping_name_party[i] = 'movimiento ciudadano'
    
for i in names_diputados[469:472]:
    mapping_name_party[i] = 'alianza'
    
for i in names_diputados[472:483]:
    mapping_name_party[i] = 'encuentro social'

for i in names_diputados[483:]:
    mapping_name_party[i] = 'sin partido'

# %%
len(mapping_name_party)
# Out:
# 500

# %%
mapping_name_party
# Out:
# {'Abdala Carmona Yahleel': 'pri',
#  'Abdala Saad Antonio Tarek': 'pri',
#  'Aguilar Yunes Marco Antonio': 'pri',
#  'Aguirre Romero Andrés': 'pri',
#  'Alcántara Rojas María Guadalupe': 'pri',
#  'Almanza Monroy Fidel': 'pri',
#  'Alonso Que Erubiel Lorenzo': 'pri',
#  'Alpizar Carrillo Lucely Del Perpetuo Socorro': 'pri',
#  'Alvarado Varela Edith Anabel': 'pri',
#  'Álvarez Ortiz Héctor Javier': 'pri',
#  'Anaya Mota Claudia Edith': 'pri',
#  'Anaya Orozco Alfredo': 'pri',
#  'Arcos Velázquez Montserrat Alicia': 'pri',
#  'Arellano Núñez Efrain': 'pri',
#  'Arroyo Bello Erika Lorena': 'pri',
#  'Balcázar Narro Rafael Arturo': 'pri',
#  'Barragán Amador Carlos': 'pri',
#  'Barrientos Cano Laura Mitzi': 'pri',
#  'Bañales Arambula Ramón': 'pri',
#  'Bedolla López Pablo': 'pri',
#  'Bejos Nicolás Alfredo': 'pri',
#  'Benítez Tiburcio Mariana': 'pri',
#  'Bernal Casique Iveth': 'pri',
#  'Bojórquez Castillo Martha Julisa': 'pri',
#  'Boone Godoy Ana María': 'pri',
#  'Borunda Espinoza Brenda': 'pri',
#  'Botello Santibáñez María Bárbara': 'pri',
#  'Brito Herrera Gonzalo Rene': 'pri',
#  'Bugarín Rodríguez Jasmine María': 'pri',
#  'Cabrera Ruiz José Hugo': 'pri',
#  'Camargo Félix María Esther Guadalupe': 'pri',
#  'Canales Najjar Tristán Manuel': 'pri',
#  'Cardoso Estévez José Luis': 'pri',
#  'Carvallo Delfín Jorge Alejandro': 'pri',
#  'Castro Ventura Fernando': 'pri',
#  'Cavazos Balderas Juan Manuel': 'pri',
#  'Cavazos Cavazos Juana Aurora': 'pri',
#  'Ceja García Xitlalic': 'pri',
#  'Chacón Morales Samuel Alexis': 'pri',
#  'Chan Magaña Rafael': 'pri',
#  'Chávez Acosta Rosa Guadalupe': 'pri',
#  'Cházaro Montalvo Oswaldo Guillermo': 'pri',
#  'Coheto Martínez Vitalico Cándido': 'pri',
#  'Córdova Hernández José Del Pilar': 'pri',
#  'Córdova Morán Hersilia Onfalia Adamina': 'pri',
#  'Corella Platt Susana': 'pri',
#  'Coronado Ayarzagoitia Pedro Luis': 'pri',
#  'Corzo Olán Omar': 'pri',
#  'Covarrubias Anaya Martha Lorena': 'pri',
#  'Cristopulos Ríos Héctor Ulises': 'pri',
#  'Cruz Campos Victorino': 'pri',
#  'Dávila Flores Jorge Enrique': 'pri',
#  'De León Maza Sofía Del Sagrario': 'pri',
#  'Díaz Montoya Rocío': 'pri',
#  'Domínguez Domínguez Cesar Alejandro': 'pri',
#  'Escobar Manjarrez Germán': 'pri',
#  'Escobedo Villegas Francisco': 'pri',
#  'Espinoza Meraz Ma. Idalia del Socorro': 'pri',
#  'Esquivel Hernández Olga María': 'pri',
#  'Estefan Chidiac Charbel Jorge': 'pri',
#  'Etcheverry Aranda Azul': 'pri',
#  'Félix Niebla Gloria Himelda': 'pri',
#  'Fernández Márquez Julieta': 'pri',
#  'Gaeta Esparza Hugo Daniel': 'pri',
#  'Gamboa Martínez Alicia Guadalupe': 'pri',
#  'Gárate Valenzuela Paola Iveth': 'pri',
#  'García Ayala Marco Antonio': 'pri',
#  'García Barrón Óscar': 'pri',
#  'García Portilla Ricardo David': 'pri',
#  'Giorgana Jiménez Víctor Manuel': 'pri',
#  'González Calderón Martha Hilda': 'pri',
#  'González Rojas Aarón': 'pri',
#  'González Salum Miguel Ángel': 'pri',
#  'Guerra Urbiola Braulio Mario': 'pri',
#  'Guerrero Aguilar Fabiola': 'pri',
#  'Guerrero Coronado Delia': 'pri',
#  'Guerrero Esquivel Araceli': 'pri',
#  'Guevara Cobos Luis Alejandro': 'pri',
#  'Guillén Vicente Mercedes Del Carmen': 'pri',
#  'Gutiérrez Ramírez Virginia Nallely': 'pri',
#  'Guzmán Lagunes Noemí Zoila': 'pri',
#  'Guzmán Vázquez Laura Valeria': 'pri',
#  'Hermosillo Arteaga Carlos Gerardo (DECESO)': 'pri',
#  'Hernández Madrid María Gloria': 'pri',
#  'Huicochea Alanís Arturo': 'pri',
#  'Ibarra Hinojosa Álvaro': 'pri',
#  'Ibarra Otero Próspero Manuel': 'pri',
#  'Ibarra Rangel Miriam Dennis': 'pri',
#  'Iriarte Mercado Carlos': 'pri',
#  'Ixtlahuac Orihuela Juan Antonio': 'pri',
#  'Jackson Ramírez Jesús Enrique': 'pri',
#  'Jiménez Jiménez Flor Ángel': 'pri',
#  'Juraidini Villaseñor Alejandro': 'pri',
#  'Kuri Grajales Fidel': 'pri',
#  'Lagos Hernández Erick Alejandro': 'pri',
#  'Le Baron González Alex': 'pri',
#  'Leyva García Leydi Fabiola': 'pri',
#  'López Galicia Olivia': 'pri',
#  'López Gutiérrez David Epifanio': 'pri',
#  'López Velasco Edith Yolanda': 'pri',
#  'Luna Canales Armando': 'pri',
#  'Luna Munguía Alma Lilia': 'pri',
#  'Madrigal Méndez Liliana Ivette': 'pri',
#  'Majul González Salomón': 'pri',
#  'Mata Quintero Mario Alberto': 'pri',
#  'Maya Pineda María Isabel': 'pri',
#  'Mazari Espín Rosalina': 'pri',
#  'Medrano Quezada Benjamín': 'pri',
#  'Meléndez Ortega Juan Antonio': 'pri',
#  'Melhem Salinas Edgardo': 'pri',
#  'Méndez Bazán Virgilio Daniel': 'pri',
#  'Mercado Ruiz David': 'pri',
#  'Moctezuma Pereda Fernando Quetzalcóatl': 'pri',
#  'Moguel Manzur Zacil Leonor': 'pri',
#  'Mólgora Glover Arlet': 'pri',
#  'Mondragón Orozco María Angélica': 'pri',
#  'Montes Salas Dulce María': 'pri',
#  'Montoya Díaz Tomás Roberto': 'pri',
#  'Mota Hernández Adolfo': 'pri',
#  'Murrieta Gutiérrez Abel': 'pri',
#  'Muñoz Guevara Josué': 'pri',
#  'Muñoz Sánchez Rosalinda': 'pri',
#  'Navarrete Pérez Fernando': 'pri',
#  'Nazar Morales Julián': 'pri',
#  'Nazario Morales Matias': 'pri',
#  'Noble Monterrubio Pedro Luis': 'pri',
#  'Nogués Barajas Rodolfo': 'pri',
#  'Orantes López Hernán De Jesús': 'pri',
#  'Oropeza Olguin Nora Liliana': 'pri',
#  'Orozco Sánchez Aldana José Luis': 'pri',
#  'Ortiz Lanz Adriana del Pilar': 'pri',
#  'Osorno Belmont Susana': 'pri',
#  'Oyervides Valdez María Guadalupe': 'pri',
#  'Pérez González Horalia Noemí': 'pri',
#  'Pichardo Lechuga José Ignacio': 'pri',
#  'Pineda Apodaca Luis Alonso': 'pri',
#  'Pinete Vargas María del Carmen': 'pri',
#  'Plata Inzunza Evelio': 'pri',
#  'Ponce Beltrán Esthela de Jesús': 'pri',
#  'Quinto Guillén Carlos Federico': 'pri',
#  'Quiñones Cornejo María De La Paz': 'pri',
#  'Rafael Rubio Álvaro': 'pri',
#  'Ramírez Nieto Ricardo': 'pri',
#  'Ramírez Ocampo Gianni Raul': 'pri',
#  'Ramírez Ponce Miguel Ángel': 'pri',
#  'Real Salinas Dora Elena': 'pri',
#  'Rentería Medina Flor Estela': 'pri',
#  'Reyes Tellez Silvino': 'pri',
#  'Rivera Carbajal Silvia': 'pri',
#  'Rocha Aguilar Yulma': 'pri',
#  'Rodríguez García Dalila': 'pri',
#  'Rodríguez Hernández Erika Araceli': 'pri',
#  'Rodríguez Garza Jesús Gilberto': 'pri',
#  'Rojas Orozco Enrique': 'pri',
#  'Rojas San Román Francisco Lauro (DECESO)': 'pri',
#  'Rojas Ángeles Ángel': 'pri',
#  'Romero Vega Esdras': 'pri',
#  'Romo García Edgar': 'pri',
#  'Rosales Reyes Salomón Fernando': 'pri',
#  'Ruíz Chávez Sara Latife': 'pri',
#  'Ruíz Ledesma Mariana Vanessa': 'pri',
#  'Sáenz Soto José Luis': 'pri',
#  'Salazar Espinosa Heidi': 'pri',
#  'Salazar Muciño Pedro Alberto': 'pri',
#  'Salinas Lozano Carmen': 'pri',
#  'Sánchez Arredondo Nancy Guadalupe': 'pri',
#  'Sánchez Coronel Cristina': 'pri',
#  'Sánchez Isidoro David': 'pri',
#  'Sánchez Sánchez Christian Joaquín': 'pri',
#  'Sandoval Martínez María Soledad': 'pri',
#  'Santillán Oceguera Francisco Javier': 'pri',
#  'Sarabia Camacho Carlos': 'pri',
#  'Saracho Navarro Francisco': 'pri',
#  'Scherman Leaño María Esther de Jesús': 'pri',
#  'Serna de León César Alberto': 'pri',
#  'Silva Ramos Alberto': 'pri',
#  'Silva Tejeda Víctor Manuel': 'pri',
#  'Sobreyra Santos María Monserrath': 'pri',
#  'Soto Enríquez Leobardo': 'pri',
#  'Sulub Caamal Miguel Ángel': 'pri',
#  'Taja Ramírez Ricardo': 'pri',
#  'Tamayo Morales Martha Sofía (LICENCIA)': 'pri',
#  'Tannos Cruz Yarith': 'pri',
#  'Terrazas Porras Adriana': 'pri',
#  'Tiscareño Agoitia Ruth Noemí': 'pri',
#  'Torres Huitrón José Alfredo': 'pri',
#  'Uriarte Zazueta Fernando': 'pri',
#  'Valencia García Oscar': 'pri',
#  'Vallejo Barragán Manuel': 'pri',
#  'Vargas Rodríguez Federico Eugenio': 'pri',
#  'Vázquez Guerrero Luis Felipe': 'pri',
#  'Vélez Núñez Beatriz': 'pri',
#  'Vidal Aguilar Liborio': 'pri',
#  'Viggiano Austria Alma Carolina': 'pri',
#  'Villa Ramírez Timoteo': 'pri',
#  'Villa Trujillo Edith': 'pri',
#  'Villagómez Guerrero Ramón': 'pri',
#  'Viveros Córdoba Joaquina': 'pri',
#  'Yerena Zambrano Rafael': 'pri',
#  'Zapata Lucero Ana Georgina': 'pri',
#  'Zepahua García Lillian': 'pri',
#  'Zúñiga Mendoza J. Jesús': 'pri',
#  'Aguilar López María Mercedes': 'pan',
#  'Agundis Estrada María Verónica': 'pan',
#  'Alejo Domínguez Hugo': 'pan',
#  'Alemán Olvera Emma Margarita': 'pan',
#  'Alfaro García Lorena del Carmen': 'pan',
#  'Amparano Gamez Leticia': 'pan',
#  'Antero Valle Luis Fernando': 'pan',
#  'Arámbula Meléndez Mariana': 'pan',
#  'Barraza López José Teodoro': 'pan',
#  'Barrera Marmolejo Héctor': 'pan',
#  'Bello Otero Carlos': 'pan',
#  'Bermúdez Méndez José Erandi': 'pan',
#  'Blanco Zaldívar Juan Alberto': 'pan',
#  'Bolaños Aguilar Edmundo Javier': 'pan',
#  'Bolio Pinelo Kathia María': 'pan',
#  'Cambranis Torres Enrique': 'pan',
#  'Carballo Cámara Domitilo': 'pan',
#  'Carrillo Fregoso Christian Alejandro': 'pan',
#  'Casillas Gutiérrez J. Apolinar': 'pan',
#  'Castañón Herrera Eukid': 'pan',
#  'Castro Terrazas María Elena': 'pan',
#  'Cordero Lerma Leonel Gerardo': 'pan',
#  'Corona Rodríguez Ariel Enrique': 'pan',
#  'Corral Estrada Herminio': 'pan',
#  'Corral Mier Juan': 'pan',
#  'Cortés Berumen José Hernán': 'pan',
#  'Cortés Lugo Román Francisco': 'pan',
#  'Cortés Mendoza Marko Antonio': 'pan',
#  'Cuanalo Santos Gerardo Gabriel': 'pan',
#  'Culin Jaime Gretel': 'pan',
#  'De La Fuente Flores Carlos Alberto': 'pan',
#  'Döring Casar Federico': 'pan',
#  'Elizarraraz Sandoval Adriana': 'pan',
#  'Estrada Torres Elisa': 'pan',
#  'Gama Basarte Marco Antonio': 'pan',
#  'García Escobar Lilia Arminda': 'pan',
#  'García López José Máximo': 'pan',
#  'García Pérez María': 'pan',
#  'Garrido Muñoz Rubén Alejandro': 'pan',
#  'Gómez Olivier Sergio Emilio': 'pan',
#  'González Ceceña Exaltación': 'pan',
#  'González Navarro José Adrián': 'pan',
#  'González Suástegui Guadalupe': 'pan',
#  'Gutiérrez Campos Alejandra': 'pan',
#  'Gutiérrez De Velasco Urtaza Francisco José': 'pan',
#  'Hernández Ramos Minerva': 'pan',
#  'Herrera Deras Alfredo Miguel': 'pan',
#  'Huepa Pérez Miguel Ángel': 'pan',
#  'Huerta Villegas Genoveva': 'pan',
#  'Iturbe Rosas Alejandra': 'pan',
#  'Iñiguez Mejía Elías Octavio': 'pan',
#  'Jasso Silva José Armando': 'pan',
#  'Jiménez Márquez Martha Cristina': 'pan',
#  'León Aguirre Allan Michel': 'pan',
#  'Lizárraga Figueroa Teresa de Jesús': 'pan',
#  'López Córdova José Everardo': 'pan',
#  'López Martín Jorge': 'pan',
#  'López Rodríguez Jesús Antonio': 'pan',
#  'Mandujano Tinajero Rene': 'pan',
#  'Márquez Zapata Nelly del Carmen': 'pan',
#  'Marrón Agustín Luis Gilberto': 'pan',
#  'Martínez Montemayor Baltazar': 'pan',
#  'Martínez Santos Wenceslao': 'pan',
#  'Martínez Sánchez Luis de León': 'pan',
#  'Matesanz Santamaría Rocío': 'pan',
#  'Méndez González Marcos': 'pan',
#  'Mesta Soule Luis Fernando': 'pan',
#  'Moya Marín Angélica (LICENCIA)': 'pan',
#  'Muñoz Cervantes Arlette Ivette': 'pan',
#  'Nava Mouett Jacqueline': 'pan',
#  'Neblina Vega Javier Antonio': 'pan',
#  'Osuna Carranco Karla Karina': 'pan',
#  'Ovando Reazola Janette (LICENCIA)': 'pan',
#  'Padilla Avila Karina': 'pan',
#  'Palomeque Archila Carlos Alberto': 'pan',
#  'Paniagua Figueroa Luz Argelia': 'pan',
#  'Picazo Olmos María Olivia': 'pan',
#  'Piña Kurczyn Juan Pablo': 'pan',
#  'Ramírez Núñez Ulises': 'pan',
#  'Ramírez Ramos Gabriela': 'pan',
#  'Rendón García Cesar Augusto': 'pan',
#  'Reynoso Sánchez Alejandra Noemí': 'pan',
#  'Rivera Castillejos Armando Alejandro': 'pan',
#  'Rodríguez Aguirre María de los Ángeles': 'pan',
#  'Rodríguez Dávila Alfredo Javier': 'pan',
#  'Rodríguez Rubio María del Rosario': 'pan',
#  'Rodríguez Torres Luis Agustín': 'pan',
#  'Romero Castillo María Guadalupe Cecilia': 'pan',
#  'Ruíz García Juan Carlos': 'pan',
#  'Salas Díaz Gerardo Federico': 'pan',
#  'Salim Alle Miguel Ángel': 'pan',
#  'Sánchez Carrillo Patricia': 'pan',
#  'Sánchez Juárez Claudia': 'pan',
#  'Sánchez Meza María Luisa': 'pan',
#  'Schemelensky Castro Ingrid Krasopani (LICENCIA)': 'pan',
#  'Taboada Cortina Santiago': 'pan',
#  'Talavera Hernández María Eloísa': 'pan',
#  'Tamariz García Ximena': 'pan',
#  'Toledo Soto Nicolás': 'pan',
#  'Torreblanca Engell Santiago': 'pan',
#  'Triana Tena Jorge': 'pan',
#  'Valenzuela Armas Rafael': 'pan',
#  'Valles Olvera Elva Lidia': 'pan',
#  'Vargas Bárcena Marisol': 'pan',
#  'Vega Olivas Nadia Haydee': 'pan',
#  'Velázquez Valdez Brenda': 'pan',
#  'Zapata Padilla María Olimpia': 'pan',
#  'Acosta Naranjo Guadalupe': 'prd',
#  'Alanís Pedraza Ángel II': 'prd',
#  'Amador Rodríguez Leonardo': 'prd',
#  'Aragón Castillo Hortensia': 'prd',
#  'Arguijo Herrera Tania Victoria': 'prd',
#  'Barrientos Ríos Ricardo Ángel': 'prd',
#  'Basave Benítez Agustín Francisco de Asís': 'prd',
#  'Beltrán Reyes María Luisa': 'prd',
#  'Bocanegra Ruíz Elio': 'prd',
#  'Bravo Guadarrama Arturo': 'prd',
#  'Briones Pérez Erika Irazema': 'prd',
#  'Castelán Mondragón María Elida': 'prd',
#  'Catalán Padilla Olga': 'prd',
#  'Cruz Molina Eva Florinda': 'prd',
#  'Estefan Garfias José Antonio': 'prd',
#  'Ferrer Abalos Óscar': 'prd',
#  'Flores Sonduk Lluvia': 'prd',
#  'García Bravo María Cristina Teresa': 'prd',
#  'García Calderón David Gerson': 'prd',
#  'Gaytán Hernández Cristina Ismene': 'prd',
#  'Hernández Alcalá J. Guadalupe': 'prd',
#  'Hernández Soriano Rafael': 'prd',
#  'Jiménez Rumbo David': 'prd',
#  'Juárez Blanquet Erik': 'prd',
#  'López López Irma Rebeca': 'prd',
#  'López Sánchez Sergio': 'prd',
#  'Madrigal Sánchez Araceli': 'prd',
#  'Maldonado Venegas Luis': 'prd',
#  'Martínez Soto Norberto Antonio': 'prd',
#  'Nava Palacios Francisco Xavier': 'prd',
#  'Octaviano Félix Tómas': 'prd',
#  'Ordoñez Hernández Daniel': 'prd',
#  'Ortega Álvarez Omar': 'prd',
#  'Parra Álvarez Evelyn': 'prd',
#  'Peralta Grappin Héctor': 'prd',
#  'Pérez Alvarado Candelario': 'prd',
#  'Pool Pech Isaura Ivanova': 'prd',
#  'Ramírez Peralta Karen Orney': 'prd',
#  'Reyes Álvarez Felipe': 'prd',
#  'Rubio Quiroz Juan Fernando': 'prd',
#  'Saldaña Morán Julio': 'prd',
#  'Santana Alfaro Arturo': 'prd',
#  'Santiago López José': 'prd',
#  'Saucedo Reyes Araceli': 'prd',
#  'Soto Espino Armando': 'prd',
#  'Soto González Cecilia Guadalupe': 'prd',
#  'Tello López Jorge': 'prd',
#  'Valdés Ramírez María Concepción': 'prd',
#  'Valera Fuentes Diego Valente': 'prd',
#  'Wences Real Victoriano': 'prd',
#  'Zambrano Grijalva José de Jesús': 'prd',
#  'Abdala Dartigues Rodrigo': 'morena',
#  'Aceves Pastrana Patricia Elena': 'morena',
#  'Alva y Alva Miguel': 'morena',
#  'Álvarez López Jesús Emiliano': 'morena',
#  'Armenta Mier Alejandro': 'morena',
#  'Barón Ortiz Natalia Karina': 'morena',
#  'Barrientos Pantoja Alicia': 'morena',
#  'Basurto Román Alfredo': 'morena',
#  'Caballero Pedraza Virgilio Dante': 'morena',
#  'Calderón Torreblanca Fidel': 'morena',
#  'Cárdenas Mariscal María Antonia': 'morena',
#  'Carrera Hernández Ana Leticia': 'morena',
#  'Castro Vázquez Rogerio': 'morena',
#  'Cañedo Jiménez Roberto Alejandro': 'morena',
#  'Cervera García Rene': 'morena',
#  'Chávez García María': 'morena',
#  'Contreras Julián Maricela': 'morena',
#  'Cuata Domínguez Blanca Margarita': 'morena',
#  'Damián González Araceli': 'morena',
#  'Esquivel Valdés Laura Beatriz': 'morena',
#  'Fuentes Alonso Modesta': 'morena',
#  'Galico Félix Díaz Sara Paola': 'morena',
#  'García Chávez Héctor Javier': 'morena',
#  'García Jiménez Cuitláhuac': 'morena',
#  'García Navarro Otniel': 'morena',
#  'Godoy Ramos Ernestina': 'morena',
#  'Gómez Álvarez Delfina': 'morena',
#  'Guzmán Jacobo Roberto': 'morena',
#  'Hernández Colín Norma Xochitl': 'morena',
#  'Hernández Correa Guadalupe': 'morena',
#  'Hernández Mirón Carlos': 'morena',
#  'Hernández de la Piedra Ángel Antonio': 'morena',
#  'Hurtado Arana Karen': 'morena',
#  'Juárez Rodríguez Mario Ariel': 'morena',
#  'Lomelí Bolaños Carlos (LICENCIA)': 'morena',
#  'Martínez Urincho Alberto': 'morena',
#  'Meza Guzmán Lucia Virginia': 'morena',
#  'Molina Arias Renato Josafat': 'morena',
#  'Montiel Reyes Ariadna': 'morena',
#  'Nahle García Norma Rocío': 'morena',
#  'Ojeda Anguiano Jerónimo Alejandro': 'morena',
#  'Ramírez Rosete Jorge': 'morena',
#  'Ramos Ramírez Blandina': 'morena',
#  'Rivera Tavizón Alma América': 'morena',
#  'Romero Tenorio Juan': 'morena',
#  'Santiago Rodríguez Guillermo Rafael': 'morena',
#  'Serrano Lora Jesús': 'morena',
#  'Trejo Flores Mariana': 'morena',
#  'Valencia Guzmán Jesús Salvador': 'morena',
#  'Villa González Concepción': 'morena',
#  'Álvarez Angli Arturo': 'partido verde ecologista',
#  'Álvarez Piñones Rosa Alicia': 'partido verde ecologista',
#  'Arévalo González José Antonio': 'partido verde ecologista',
#  'Arzaluz Alonso Alma Lucía': 'partido verde ecologista',
#  'Ávila Serna María': 'partido verde ecologista',
#  'Bernardino Vargas Omar Noé': 'partido verde ecologista',
#  'Canales Suárez Paloma': 'partido verde ecologista',
#  'Canavati Tafich Jesús Ricardo': 'partido verde ecologista',
#  'Celis Aguirre Juan Manuel': 'partido verde ecologista',
#  'Chavarrias Barajas Eloisa': 'partido verde ecologista',
#  'Corona Valdés Lorena': 'partido verde ecologista',
#  'Couttolenc Buentello José Alberto': 'partido verde ecologista',
#  'Cuenca Ayala Sharon María Teresa': 'partido verde ecologista',
#  'Fernández del Valle Laisequilla Andrés': 'partido verde ecologista',
#  'Flores Carranza Evelyng Soraya': 'partido verde ecologista',
#  'Galindo Rosas Jose De Jesus': 'partido verde ecologista',
#  'García Treviño Daniela': 'partido verde ecologista',
#  'González Evia Edna': 'partido verde ecologista',
#  'González Torres Sofía': 'partido verde ecologista',
#  'Gordillo Sánchez Jorge De Jesús': 'partido verde ecologista',
#  'Guevara Jiménez Yaret Adriana': 'partido verde ecologista',
#  'Guirao Aguilar Leonardo Rafael': 'partido verde ecologista',
#  'Herrera Borunda Javier Octavio': 'partido verde ecologista',
#  'Limón García Lia': 'partido verde ecologista',
#  'López Roblero Uberly': 'partido verde ecologista',
#  'Machuca Sánchez Mario': 'partido verde ecologista',
#  'Márquez Alvarado Cesáreo Jorge': 'partido verde ecologista',
#  'Mendoza Amezcua Virgilio': 'partido verde ecologista',
#  'Ochoa Rojas Cándido': 'partido verde ecologista',
#  'Rodríguez Torres Samuel': 'partido verde ecologista',
#  'Salazar Farías Emilio Enrique': 'partido verde ecologista',
#  'Sandoval Rodríguez José Refugio': 'partido verde ecologista',
#  'Sedas Castro Miguel Ángel': 'partido verde ecologista',
#  'Sesma Suárez Jesús': 'partido verde ecologista',
#  'Torres Rivas Francisco Alberto': 'partido verde ecologista',
#  'Villalpando Barrios Georgina Paola': 'partido verde ecologista',
#  'Villanueva Huerta Claudia': 'partido verde ecologista',
#  'Zamora Morlet Enrique': 'partido verde ecologista',
#  'Álvarez Maynez Jorge': 'movimiento ciudadano',
#  'Bermúdez Torres Verónica': 'movimiento ciudadano',
#  'Cárdenas Gutiérrez Gustavo Adolfo': 'movimiento ciudadano',
#  'Chávez Ocegueda Juan': 'movimiento ciudadano',
#  'Corichi García Claudia Sofía': 'movimiento ciudadano',
#  'Flores Gómez Mirza (LICENCIA)': 'movimiento ciudadano',
#  'Franco Madrigal Osvaldo Alfredo': 'movimiento ciudadano',
#  'García González Salvador': 'movimiento ciudadano',
#  'Guerra Mota Moisés': 'movimiento ciudadano',
#  'Hauffen Torres Angie Dennisse': 'movimiento ciudadano',
#  'Mercado Sánchez Ma. Victoria': 'movimiento ciudadano',
#  'Nuño Guzmán José': 'movimiento ciudadano',
#  'Ochoa Avalos María Candelaria': 'movimiento ciudadano',
#  'Pérez Utrera Adán': 'movimiento ciudadano',
#  'Plascencia Pacheco Laura Nereida': 'movimiento ciudadano',
#  'Ralis Cumplido Germán Ernesto': 'movimiento ciudadano',
#  'Ramírez Nachis Rosa Alba': 'movimiento ciudadano',
#  'Rocha Ladrón de Guevara Dalia María': 'movimiento ciudadano',
#  'Sánchez Orozco Víctor Manuel': 'movimiento ciudadano',
#  'Tamez Guajardo Macedonio Salomón': 'movimiento ciudadano',
#  'Toledo Ibarra Marbella': 'movimiento ciudadano',
#  'García Yáñez Ángel': 'alianza',
#  'González Luna Josefina': 'alianza',
#  'Gutiérrez García Carlos': 'alianza',
#  'Hernández León Luis Manuel': 'encuentro social',
#  'Méndez Salas Jesús Rafael': 'encuentro social',
#  'Ocampo Bedolla María Eugenia': 'encuentro social',
#  'Palomares Ramírez Elvia Graciela': 'encuentro social',
#  'Pinto Torres Francisco Javier': 'encuentro social',
#  'Reyes Ávila Angélica': 'encuentro social',
#  'Saldívar Paz Mirna Isabel': 'encuentro social',
#  'Sánchez Ruiz Karina': 'encuentro social',
#  'Torres Sandoval Melissa': 'encuentro social',
#  'Valles Mendoza Luis Alfredo': 'encuentro social',
#  'Cruz Hernández Abel': 'encuentro social',
#  'Escobedo Miramontes Justo Federico': 'sin partido',
#  'Ferreiro Velazco José Alfredo': 'sin partido',
#  'García Soberanes Cynthia Gissel': 'sin partido',
#  'Garzón Canchola Refugio Trinidad': 'sin partido',
#  'Guízar Valladares Gonzalo': 'sin partido',
#  'López Ruiz Nancy': 'sin partido',
#  'Martínez Guzmán Norma Edith': 'sin partido',
#  'Perea Santos Ana Guadalupe': 'sin partido',
#  'Pineda Morín Abdies': 'sin partido',
#  'Sarur Torre Adriana': 'sin partido',
#  'Zazueta Osuna María del Rocío': 'sin partido',
#  'Espino Manuel de Jesús': 'sin partido',
#  'Flores Sosa Cesar': 'sin partido',
#  'Guerrero García Javier': 'sin partido',
#  'Martínez Neri Francisco': 'sin partido',
#  'Spinoso Carrera Edgar': 'sin partido',
#  'Toledo Medina José Luis': 'sin partido'}

# %%
re.sub('[ ]+$', '', re.sub('[(]ficha curricular[)]', '', 'Pablo Basáñez García  (ficha curricular)'))
# Out:
# 'Pablo Basáñez García'

# %%
def obtain_id_data63(name, mapping_parties, link):
    suplente_propietario = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(6) > td:nth-child(2) > strong > font').text
    if any(re.findall('ficha curricular', suplente_propietario)):
        dict_prop = {}
        dict_prop['legislatura'] = 63
        dict_prop['id_legislador'] = str(uuid.uuid1())
        dict_prop['nombre_completo'] = re.sub('[ ]+$', '', re.sub('[(]ficha curricular[)]', '', suplente_propietario))
        dict_prop['tipo_legislador'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(2) > td:nth-child(2) > strong > font').text
        dict_prop['entidad'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(1) > font').text
        dict_prop['distrito'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(4) > font').text
        dict_prop['curul'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(7) > font').text
        dict_prop['suplente_propietario'] = 'P'
        dict_prop['name_suplente'] = name
        dict_prop['partido'] = mapping_parties[name]
        dict_prop['link_curricula'] = link
        
        
        dict_sup = {}
        dict_sup['legislatura'] = 63
        dict_sup['id_legislador'] = str(uuid.uuid1())
        dict_sup['nombre_completo'] = name
        dict_sup['tipo_legislador'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(2) > td:nth-child(2) > strong > font').text
        dict_sup['entidad'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(1) > font').text
        dict_sup['distrito'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(4) > font').text
        dict_sup['curul'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(7) > font').text
        dict_sup['suplente_propietario'] = 'S'
        dict_sup['name_suplente'] = ''
        dict_sup['partido'] = mapping_parties[name]
        dict_sup['link_curricula'] = link
        return([dict_prop, dict_sup])
    else:
    
        dict_prop = {}
        dict_prop['legislatura'] = 63
        dict_prop['id_legislador'] = str(uuid.uuid1())
        dict_prop['nombre_completo'] = name
        dict_prop['tipo_legislador'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(2) > td:nth-child(2) > strong > font').text
        dict_prop['entidad'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(1) > font').text
        dict_prop['distrito'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(4) > font').text
        dict_prop['curul'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(7) > font').text
        dict_prop['suplente_propietario'] = 'P'
        dict_prop['name_suplente'] = suplente_propietario
        dict_prop['partido'] = mapping_parties[name]
        dict_prop['link_curricula'] = link
        return([dict_prop])

# %%
def obtain_supl_prop(driver):

# %% [markdown]
# ## ID Data

# %%
data_id = []
for x, y in tqdm(zip(links_diputados, names_diputados), total = len(names_diputados)):
    driver.get(x)
    dicts = obtain_id_data63(y, mapping_name_party, x)
    for i in  dicts:
        data_id.append(i)
# Out:
# 100%|██████████| 500/500 [02:15<00:00,  3.68it/s]

# %%
data_id
# Out:
# [{'legislatura': 63,
#   'id_legislador': '6d76fca6-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Abdala Carmona Yahleel',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Tamaulipas',
#   'distrito': '1',
#   'curul': 'K-386',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Claudia Janeth Ochoa Iñiguez',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=260'},
#  {'legislatura': 63,
#   'id_legislador': '6d9adb62-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Abdala Saad Antonio Tarek',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Veracruz',
#   'distrito': '17',
#   'curul': 'L-448',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Carlos Joaquín Sosa López',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=287'},
#  {'legislatura': 63,
#   'id_legislador': '6dc46478-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Aguilar Yunes Marco Antonio',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Veracruz',
#   'distrito': '16',
#   'curul': 'P-507',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Jesús Antonio Hazouri Mansur',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=286'},
#  {'legislatura': 63,
#   'id_legislador': '6dee1b88-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Aguirre Romero Andrés',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'México',
#   'distrito': '39',
#   'curul': 'I-314',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Raymundo Moreno Ibáñez',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=164'},
#  {'legislatura': 63,
#   'id_legislador': '6e1e33ea-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Alcántara Rojas María Guadalupe',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'México',
#   'distrito': '5',
#   'curul': 'I-315',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Ma. Guadalupe Calderón Medina',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=477'},
#  {'legislatura': 63,
#   'id_legislador': '6e4845ae-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Almanza Monroy Fidel',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'México',
#   'distrito': '3',
#   'curul': 'J-356',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Marco Antonio Barranco Sánchez',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=128'},
#  {'legislatura': 63,
#   'id_legislador': '6e6d3c24-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Jorge Carlos Ramírez Marín',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Tabasco',
#   'distrito': '3',
#   'curul': 'G-212',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Alonso Que Erubiel Lorenzo',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=889'},
#  {'legislatura': 63,
#   'id_legislador': '6e77aae2-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Alonso Que Erubiel Lorenzo',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Tabasco',
#   'distrito': '3',
#   'curul': 'G-212',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=889'},
#  {'legislatura': 63,
#   'id_legislador': '6e965e2e-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Alpizar Carrillo Lucely Del Perpetuo Socorro',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Yucatán',
#   'distrito': '2',
#   'curul': 'K-392',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Sinthia Del Carmen Alvarado Canche',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=293'},
#  {'legislatura': 63,
#   'id_legislador': '6ebcbde4-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Alvarado Varela Edith Anabel',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Tlaxcala',
#   'distrito': '2',
#   'curul': 'M-496',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Fabiola Rosas Cuautle',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=269'},
#  {'legislatura': 63,
#   'id_legislador': '6eea804e-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Álvarez Ortiz Héctor Javier',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'México',
#   'distrito': '5',
#   'curul': 'K-404',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Pablo Casas Jaime',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=478'},
#  {'legislatura': 63,
#   'id_legislador': '6f0e73d2-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Anaya Mota Claudia Edith',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Zacatecas',
#   'distrito': '3',
#   'curul': 'E-145',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Elizabeth Hernández Calderón',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=299'},
#  {'legislatura': 63,
#   'id_legislador': '6f319eb6-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Anaya Orozco Alfredo',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Michoacán',
#   'distrito': '4',
#   'curul': 'J-337',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Eduardo Herrera Calixto',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=169'},
#  {'legislatura': 63,
#   'id_legislador': '6f5a1d14-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Arcos Velázquez Montserrat Alicia',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Tamaulipas',
#   'distrito': '2',
#   'curul': 'L-430',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Verónica Boreque Martínez González',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=363'},
#  {'legislatura': 63,
#   'id_legislador': '6f8acdc4-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Arellano Núñez Efrain',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Nayarit',
#   'distrito': '1',
#   'curul': 'M-491',
#   'suplente_propietario': 'P',
#   'name_suplente': 'José Lucas Vallarta Chan',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=183'},
#  {'legislatura': 63,
#   'id_legislador': '6fabb05c-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Arroyo Bello Erika Lorena',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Guanajuato',
#   'distrito': '4',
#   'curul': 'K-383',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Juana Leticia Hernández Armas',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=80'},
#  {'legislatura': 63,
#   'id_legislador': '6fcfd1da-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Pablo Basáñez García',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'México',
#   'distrito': '19',
#   'curul': 'H-269',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Balcázar Narro Rafael Arturo',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=644'},
#  {'legislatura': 63,
#   'id_legislador': '6fdbe880-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Balcázar Narro Rafael Arturo',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'México',
#   'distrito': '19',
#   'curul': 'H-269',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=644'},
#  {'legislatura': 63,
#   'id_legislador': '70007998-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Barragán Amador Carlos',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Puebla',
#   'distrito': '1',
#   'curul': 'L-451',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Rogelio López Angulo',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=209'},
#  {'legislatura': 63,
#   'id_legislador': '702b89a8-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Barrientos Cano Laura Mitzi',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'México',
#   'distrito': '26',
#   'curul': 'J-355',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Ana Yolanda Esquivel Jaramillo',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=151'},
#  {'legislatura': 63,
#   'id_legislador': '7055c128-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Bañales Arambula Ramón',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Jalisco',
#   'distrito': '15',
#   'curul': 'L-441',
#   'suplente_propietario': 'P',
#   'name_suplente': 'César Alfonso Padilla Vázquez',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=121'},
#  {'legislatura': 63,
#   'id_legislador': '707e95b2-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Bedolla López Pablo',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'México',
#   'distrito': '11',
#   'curul': 'H-265',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Carlos Rangel Aquino',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=136'},
#  {'legislatura': 63,
#   'id_legislador': '70a8a032-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Bejos Nicolás Alfredo',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Hidalgo',
#   'distrito': '6',
#   'curul': 'E-137',
#   'suplente_propietario': 'P',
#   'name_suplente': 'José Luis Lima González',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=105'},
#  {'legislatura': 63,
#   'id_legislador': '70d23f46-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Benítez Tiburcio Mariana',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Oaxaca',
#   'distrito': '3',
#   'curul': 'H-266',
#   'suplente_propietario': 'P',
#   'name_suplente': 'María Esther Fragoso Terán',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=394'},
#  {'legislatura': 63,
#   'id_legislador': '70f62c8a-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Bernal Casique Iveth',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'México',
#   'distrito': '36',
#   'curul': 'K-408',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Laura Beatriz Hernández Tapia',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=161'},
#  {'legislatura': 63,
#   'id_legislador': '711fb9ec-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Sylvana Beltrones Sánchez',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Sonora',
#   'distrito': '1',
#   'curul': 'B-041',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Bojórquez Castillo Martha Julisa',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=821'},
#  {'legislatura': 63,
#   'id_legislador': '712de6ac-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Bojórquez Castillo Martha Julisa',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Sonora',
#   'distrito': '1',
#   'curul': 'B-041',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=821'},
#  {'legislatura': 63,
#   'id_legislador': '714f67d2-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Boone Godoy Ana María',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Coahuila',
#   'distrito': '2',
#   'curul': 'M-466',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Santos Garza Herrera',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=38'},
#  {'legislatura': 63,
#   'id_legislador': '7170d2c8-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Yolanda De la Torre Valdez',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Chihuahua',
#   'distrito': '1',
#   'curul': 'F-170',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Borunda Espinoza Brenda',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=819'},
#  {'legislatura': 63,
#   'id_legislador': '717c4b80-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Borunda Espinoza Brenda',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Chihuahua',
#   'distrito': '1',
#   'curul': 'F-170',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=819'},
#  {'legislatura': 63,
#   'id_legislador': '719e0aea-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Botello Santibáñez María Bárbara',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Guanajuato',
#   'distrito': '2',
#   'curul': 'I-311',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Yolanda Eugenia González Hernández',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=357'},
#  {'legislatura': 63,
#   'id_legislador': '71c97522-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'David Aguilar Robles',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Oaxaca',
#   'distrito': '3',
#   'curul': 'D-101',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Brito Herrera Gonzalo Rene',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=897'},
#  {'legislatura': 63,
#   'id_legislador': '71d6ed2e-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Brito Herrera Gonzalo Rene',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Oaxaca',
#   'distrito': '3',
#   'curul': 'D-101',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=897'},
#  {'legislatura': 63,
#   'id_legislador': '72043964-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Bugarín Rodríguez Jasmine María',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Nayarit',
#   'distrito': '3',
#   'curul': 'M-492',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Rubí Alejandra Cardoso Guzmán',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=185'},
#  {'legislatura': 63,
#   'id_legislador': '722c5e76-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Cabrera Ruiz José Hugo',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Querétaro',
#   'distrito': '1',
#   'curul': 'A-013',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Renato Dorantes Dorantes',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=225'},
#  {'legislatura': 63,
#   'id_legislador': '725165fe-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Camargo Félix María Esther Guadalupe',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Tamaulipas',
#   'distrito': '2',
#   'curul': 'M-494',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Magin Pereda Martínez',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=261'},
#  {'legislatura': 63,
#   'id_legislador': '72793e80-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Canales Najjar Tristán Manuel',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'México',
#   'distrito': '5',
#   'curul': 'H-267',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Gustavo Sotelo Villegas',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=472'},
#  {'legislatura': 63,
#   'id_legislador': '72a205ea-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Gabriel Casillas Zanatta',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'México',
#   'distrito': '37',
#   'curul': 'H-270',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Cardoso Estévez José Luis',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=662'},
#  {'legislatura': 63,
#   'id_legislador': '72b01f40-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Cardoso Estévez José Luis',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'México',
#   'distrito': '37',
#   'curul': 'H-270',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=662'},
#  {'legislatura': 63,
#   'id_legislador': '72d46f8a-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Carvallo Delfín Jorge Alejandro',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Veracruz',
#   'distrito': '19',
#   'curul': 'K-396',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Juan Carlos Perrotin Cadena',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=289'},
#  {'legislatura': 63,
#   'id_legislador': '72fe02be-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Marco Polo Aguirre Chávez',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Michoacán',
#   'distrito': '8',
#   'curul': 'J-336',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Castro Ventura Fernando',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=673'},
#  {'legislatura': 63,
#   'id_legislador': '730c9ebe-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Castro Ventura Fernando',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Michoacán',
#   'distrito': '8',
#   'curul': 'J-336',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=673'},
#  {'legislatura': 63,
#   'id_legislador': '732dc68e-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Cavazos Balderas Juan Manuel',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Nuevo León',
#   'distrito': '2',
#   'curul': 'M-475',
#   'suplente_propietario': 'P',
#   'name_suplente': 'José Filiberto Flores Elizondo',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=187'},
#  {'legislatura': 63,
#   'id_legislador': '7352b2a0-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Cavazos Cavazos Juana Aurora',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Nuevo León',
#   'distrito': '3',
#   'curul': 'K-376',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Martha Aidee Núñez Ramos',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=188'},
#  {'legislatura': 63,
#   'id_legislador': '73776672-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Ceja García Xitlalic',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Puebla',
#   'distrito': '6',
#   'curul': 'L-428',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Rosa Isela Rojas Luna',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=214'},
#  {'legislatura': 63,
#   'id_legislador': '739f5eca-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Chacón Morales Samuel Alexis',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Chiapas',
#   'distrito': '12',
#   'curul': 'I-295',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Arturo Miguel Pacheco Meza',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=27'},
#  {'legislatura': 63,
#   'id_legislador': '73c5df3c-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Felipe Cervera Hernández',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Yucatán',
#   'distrito': '5',
#   'curul': 'K-394',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Chan Magaña Rafael',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=796'},
#  {'legislatura': 63,
#   'id_legislador': '73d14fd4-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Chan Magaña Rafael',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Yucatán',
#   'distrito': '5',
#   'curul': 'K-394',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=796'},
#  {'legislatura': 63,
#   'id_legislador': '73f68fba-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Chávez Acosta Rosa Guadalupe',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Hidalgo',
#   'distrito': '2',
#   'curul': 'D-099',
#   'suplente_propietario': 'P',
#   'name_suplente': 'María Luisa Pérez Perrusquía',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=101'},
#  {'legislatura': 63,
#   'id_legislador': '741f8ece-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Cházaro Montalvo Oswaldo Guillermo',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Veracruz',
#   'distrito': '3',
#   'curul': 'M-487',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Manuel Adonay Vargas Cuevas',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=395'},
#  {'legislatura': 63,
#   'id_legislador': '7449ea2a-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Coheto Martínez Vitalico Cándido',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Oaxaca',
#   'distrito': '4',
#   'curul': 'C-068',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Adolfo García Morales',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=201'},
#  {'legislatura': 63,
#   'id_legislador': '746beeb8-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Córdova Hernández José Del Pilar',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Tabasco',
#   'distrito': '6',
#   'curul': 'L-458',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Rogelio Betancourt González',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=259'},
#  {'legislatura': 63,
#   'id_legislador': '74910ab8-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Córdova Morán Hersilia Onfalia Adamina',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Puebla',
#   'distrito': '4',
#   'curul': 'M-469',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Georgina Adriana Pulido García',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=434'},
#  {'legislatura': 63,
#   'id_legislador': '74b60822-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Corella Platt Susana',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Sonora',
#   'distrito': '4',
#   'curul': 'B-040',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Rosa Haydee González González',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=250'},
#  {'legislatura': 63,
#   'id_legislador': '74d9944a-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Jesús Juan De La Garza Díaz Del Guante',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Tamaulipas',
#   'distrito': '4',
#   'curul': 'L-429',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Coronado Ayarzagoitia Pedro Luis',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=763'},
#  {'legislatura': 63,
#   'id_legislador': '74e4b456-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Coronado Ayarzagoitia Pedro Luis',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Tamaulipas',
#   'distrito': '4',
#   'curul': 'L-429',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=763'},
#  {'legislatura': 63,
#   'id_legislador': '750af2ba-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Pablo Gamboa Miner',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Yucatán',
#   'distrito': '3',
#   'curul': 'K-393',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Corzo Olán Omar',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=794'},
#  {'legislatura': 63,
#   'id_legislador': '7517f578-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Corzo Olán Omar',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Yucatán',
#   'distrito': '3',
#   'curul': 'K-393',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=794'},
#  {'legislatura': 63,
#   'id_legislador': '75396ea6-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Covarrubias Anaya Martha Lorena',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Jalisco',
#   'distrito': '17',
#   'curul': 'M-481',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Priscilla Sahagún Salinas',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=123'},
#  {'legislatura': 63,
#   'id_legislador': '75605e58-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Cristopulos Ríos Héctor Ulises',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Sonora',
#   'distrito': '5',
#   'curul': 'C-070',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Ariel Burgos Ochoa',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=251'},
#  {'legislatura': 63,
#   'id_legislador': '75833266-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Cirilo Vázquez Parissi',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Veracruz',
#   'distrito': '21',
#   'curul': 'H-257',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Cruz Campos Victorino',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=791'},
#  {'legislatura': 63,
#   'id_legislador': '758d0fd4-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Cruz Campos Victorino',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Veracruz',
#   'distrito': '21',
#   'curul': 'H-257',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=791'},
#  {'legislatura': 63,
#   'id_legislador': '75ad5820-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Dávila Flores Jorge Enrique',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Coahuila',
#   'distrito': '2',
#   'curul': 'G-225',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Juan Manuel Gómez Morales',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=356'},
#  {'legislatura': 63,
#   'id_legislador': '75d27eca-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'De León Maza Sofía Del Sagrario',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Veracruz',
#   'distrito': '1',
#   'curul': 'L-446',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Rocío Guzmán De Paz',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=271'},
#  {'legislatura': 63,
#   'id_legislador': '75f77518-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Díaz Montoya Rocío',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'México',
#   'distrito': '28',
#   'curul': 'F-183',
#   'suplente_propietario': 'P',
#   'name_suplente': 'María Teresa Sánchez Ruíz Esparza',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=153'},
#  {'legislatura': 63,
#   'id_legislador': '7620f0be-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Domínguez Domínguez Cesar Alejandro',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Chihuahua',
#   'distrito': '8',
#   'curul': 'F-172',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Francisco Javier Salcido Lozoya',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=35'},
#  {'legislatura': 63,
#   'id_legislador': '7647182a-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Escobar Manjarrez Germán',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Sinaloa',
#   'distrito': '6',
#   'curul': 'K-400',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Salvador Félix Reyes',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=244'},
#  {'legislatura': 63,
#   'id_legislador': '766e8e32-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Escobedo Villegas Francisco',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Zacatecas',
#   'distrito': '2',
#   'curul': 'L-455',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Aurelio Argüelles Martínez',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=298'},
#  {'legislatura': 63,
#   'id_legislador': '76928e5e-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'María Del Rocío Rebollo Mendoza',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Durango',
#   'distrito': '2',
#   'curul': 'E-143',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Espinoza Meraz Ma. Idalia del Socorro',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=574'},
#  {'legislatura': 63,
#   'id_legislador': '769df280-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Espinoza Meraz Ma. Idalia del Socorro',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Durango',
#   'distrito': '2',
#   'curul': 'E-143',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=574'},
#  {'legislatura': 63,
#   'id_legislador': '76c32d98-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Esquivel Hernández Olga María',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'México',
#   'distrito': '40',
#   'curul': 'I-313',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Idania Itzel García Salgado',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=165'},
#  {'legislatura': 63,
#   'id_legislador': '76e98b32-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Estefan Chidiac Charbel Jorge',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Puebla',
#   'distrito': '14',
#   'curul': 'J-354',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Marcelino Rutilio Alamirra Muñoz',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=222'},
#  {'legislatura': 63,
#   'id_legislador': '770f0740-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Etcheverry Aranda Azul',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Guanajuato',
#   'distrito': '2',
#   'curul': 'K-379',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Griselda Dávila Beaz',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=359'},
#  {'legislatura': 63,
#   'id_legislador': '7733fe4c-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Félix Niebla Gloria Himelda',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Sinaloa',
#   'distrito': '1',
#   'curul': 'I-308',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Gloria González Burboa',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=239'},
#  {'legislatura': 63,
#   'id_legislador': '7756f424-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Fernández Márquez Julieta',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Guerrero',
#   'distrito': '4',
#   'curul': 'L-426',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Lilia Escobar Ávila',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=94'},
#  {'legislatura': 63,
#   'id_legislador': '777ad2ae-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Gaeta Esparza Hugo Daniel',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Jalisco',
#   'distrito': '1',
#   'curul': 'L-440',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Alberto Pulido Cornejo',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=107'},
#  {'legislatura': 63,
#   'id_legislador': '77a043ae-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Gamboa Martínez Alicia Guadalupe',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Durango',
#   'distrito': '4',
#   'curul': 'E-141',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Gabriela Hernández López',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=76'},
#  {'legislatura': 63,
#   'id_legislador': '77c452ee-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Rosa Elena Millán Bueno',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Sinaloa',
#   'distrito': '7',
#   'curul': 'K-397',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Gárate Valenzuela Paola Iveth',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=745'},
#  {'legislatura': 63,
#   'id_legislador': '77d3a190-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Gárate Valenzuela Paola Iveth',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Sinaloa',
#   'distrito': '7',
#   'curul': 'K-397',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=745'},
#  {'legislatura': 63,
#   'id_legislador': '77f222b4-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'García Ayala Marco Antonio',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Baja California',
#   'distrito': '1',
#   'curul': 'K-462',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Ricardo Navarrete Reyes',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=320'},
#  {'legislatura': 63,
#   'id_legislador': '78178afe-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'García Barrón Óscar',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Durango',
#   'distrito': '3',
#   'curul': 'E-144',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Maximiliano Silerio Díaz',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=75'},
#  {'legislatura': 63,
#   'id_legislador': '783a43aa-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'García Portilla Ricardo David',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Tlaxcala',
#   'distrito': '3',
#   'curul': 'J-353',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Teodardo Muñoz Torres',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=270'},
#  {'legislatura': 63,
#   'id_legislador': '785ff50a-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Giorgana Jiménez Víctor Manuel',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Puebla',
#   'distrito': '12',
#   'curul': 'I-312',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Ramón Fernández Solana',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=220'},
#  {'legislatura': 63,
#   'id_legislador': '7883e618-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'González Calderón Martha Hilda',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'México',
#   'distrito': '34',
#   'curul': 'H-268',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Paola Jiménez Hernández',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=159'},
#  {'legislatura': 63,
#   'id_legislador': '78a6456e-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Raúl Domínguez Rex',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'México',
#   'distrito': '2',
#   'curul': 'J-359',
#   'suplente_propietario': 'P',
#   'name_suplente': 'González Rojas Aarón',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=627'},
#  {'legislatura': 63,
#   'id_legislador': '78b13c1c-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'González Rojas Aarón',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'México',
#   'distrito': '2',
#   'curul': 'J-359',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=627'},
#  {'legislatura': 63,
#   'id_legislador': '78ce7fa2-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'González Salum Miguel Ángel',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Tamaulipas',
#   'distrito': '5',
#   'curul': 'L-431',
#   'suplente_propietario': 'P',
#   'name_suplente': 'José Ángel Cárdenas Castillejos',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=264'},
#  {'legislatura': 63,
#   'id_legislador': '78ee0994-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Guerra Urbiola Braulio Mario',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Querétaro',
#   'distrito': '2',
#   'curul': 'A-014',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Raymundo Muñoz Leyva',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=366'},
#  {'legislatura': 63,
#   'id_legislador': '79121e56-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Guerrero Aguilar Fabiola',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'San Luis Potosí',
#   'distrito': '3',
#   'curul': 'H-253',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Margarita Huerta García',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=234'},
#  {'legislatura': 63,
#   'id_legislador': '7937c282-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Guerrero Coronado Delia',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'San Luis Potosí',
#   'distrito': '2',
#   'curul': 'H-254',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Laura Angélica Herrera Márquez',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=361'},
#  {'legislatura': 63,
#   'id_legislador': '795d57c2-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Guerrero Esquivel Araceli',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Zacatecas',
#   'distrito': '4',
#   'curul': 'L-453',
#   'suplente_propietario': 'P',
#   'name_suplente': 'María Dolores Serna Ibarra',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=300'},
#  {'legislatura': 63,
#   'id_legislador': '798584ea-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Guevara Cobos Luis Alejandro',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Tamaulipas',
#   'distrito': '6',
#   'curul': 'K-385',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Julio César Portales Martínez',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=265'},
#  {'legislatura': 63,
#   'id_legislador': '79af6c10-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Guillén Vicente Mercedes Del Carmen',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Tamaulipas',
#   'distrito': '8',
#   'curul': 'K-388',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Elsa María Tamayo Cárdenas',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=267'},
#  {'legislatura': 63,
#   'id_legislador': '79d61536-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Gutiérrez Ramírez Virginia Nallely',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'México',
#   'distrito': '10',
#   'curul': 'J-357',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Patricia Elizabeth Ramírez Mata',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=135'},
#  {'legislatura': 63,
#   'id_legislador': '79fdcf86-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Guzmán Lagunes Noemí Zoila',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Veracruz',
#   'distrito': '9',
#   'curul': 'M-486',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Linda Rubí Martínez Díaz',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=279'},
#  {'legislatura': 63,
#   'id_legislador': '7a219484-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Guzmán Vázquez Laura Valeria',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Jalisco',
#   'distrito': '4',
#   'curul': 'M-482',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Andrea Margarita Márquez Villarreal',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=110'},
#  {'legislatura': 63,
#   'id_legislador': '7a45c0ca-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Hermosillo Arteaga Carlos Gerardo (DECESO)',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Chihuahua',
#   'distrito': '9',
#   'curul': 'H-251',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Antonio Enrique Tarín García',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=36'},
#  {'legislatura': 63,
#   'id_legislador': '7a6d525c-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Hernández Madrid María Gloria',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Hidalgo',
#   'distrito': '7',
#   'curul': 'H-264',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Sylvia López González',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=106'},
#  {'legislatura': 63,
#   'id_legislador': '7a9258cc-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'César Camacho',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'México',
#   'distrito': '5',
#   'curul': 'G-224',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Huicochea Alanís Arturo',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=970'},
#  {'legislatura': 63,
#   'id_legislador': '7a9eee16-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Huicochea Alanís Arturo',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'México',
#   'distrito': '5',
#   'curul': 'G-224',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=970'},
#  {'legislatura': 63,
#   'id_legislador': '7ac7ffe0-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Ibarra Hinojosa Álvaro',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Nuevo León',
#   'distrito': '2',
#   'curul': 'M-476',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Ricardo Gamundi Rosas',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=364'},
#  {'legislatura': 63,
#   'id_legislador': '7af17aa0-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Ibarra Otero Próspero Manuel',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Sonora',
#   'distrito': '7',
#   'curul': 'B-038',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Jorge Luis Arellano Cruz',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=253'},
#  {'legislatura': 63,
#   'id_legislador': '7b13f1c0-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Ibarra Rangel Miriam Dennis',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Aguascalientes',
#   'distrito': '2',
#   'curul': 'M-497',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Blanca Aurelia Anzaldua Nájera',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=365'},
#  {'legislatura': 63,
#   'id_legislador': '7b35d7f4-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Iriarte Mercado Carlos',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'México',
#   'distrito': '5',
#   'curul': 'I-309',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Edgardo Rebollar Pérez',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=474'},
#  {'legislatura': 63,
#   'id_legislador': '7b5a4468-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Ixtlahuac Orihuela Juan Antonio',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Michoacán',
#   'distrito': '3',
#   'curul': 'J-339',
#   'suplente_propietario': 'P',
#   'name_suplente': 'José Luis Baeza Rojas',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=168'},
#  {'legislatura': 63,
#   'id_legislador': '7b823a5e-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Jackson Ramírez Jesús Enrique',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Sinaloa',
#   'distrito': '1',
#   'curul': 'J-351',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Enrique Díaz López',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=316'},
#  {'legislatura': 63,
#   'id_legislador': '7bb0e160-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Jiménez Jiménez Flor Ángel',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Chiapas',
#   'distrito': '4',
#   'curul': 'I-296',
#   'suplente_propietario': 'P',
#   'name_suplente': '--- --- ---',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=19'},
#  {'legislatura': 63,
#   'id_legislador': '7bd4406a-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'David Ricardo Sánchez Guevara',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'México',
#   'distrito': '24',
#   'curul': 'F-187',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Juraidini Villaseñor Alejandro',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=649'},
#  {'legislatura': 63,
#   'id_legislador': '7be1eb66-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Juraidini Villaseñor Alejandro',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'México',
#   'distrito': '24',
#   'curul': 'F-187',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=649'},
#  {'legislatura': 63,
#   'id_legislador': '7c02c5f2-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Kuri Grajales Fidel',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Veracruz',
#   'distrito': '15',
#   'curul': 'L-452',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Víctor Manuel García Figueiras',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=285'},
#  {'legislatura': 63,
#   'id_legislador': '7c294006-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Lagos Hernández Erick Alejandro',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Veracruz',
#   'distrito': '20',
#   'curul': 'L-443',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Víctor Manuel Pavón Ríos',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=290'},
#  {'legislatura': 63,
#   'id_legislador': '7c518002-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Le Baron González Alex',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Chihuahua',
#   'distrito': '7',
#   'curul': 'G-214',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Rafael Martínez Pérez',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=34'},
#  {'legislatura': 63,
#   'id_legislador': '7c7729d8-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Leyva García Leydi Fabiola',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'México',
#   'distrito': '35',
#   'curul': 'H-271',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Thania Valdez Monroy',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=160'},
#  {'legislatura': 63,
#   'id_legislador': '7c9fa502-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'María Verónica Muñoz Parra',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Guerrero',
#   'distrito': '6',
#   'curul': 'L-427',
#   'suplente_propietario': 'P',
#   'name_suplente': 'López Galicia Olivia',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=596'},
#  {'legislatura': 63,
#   'id_legislador': '7cb0d462-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'López Galicia Olivia',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Guerrero',
#   'distrito': '6',
#   'curul': 'L-427',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=596'},
#  {'legislatura': 63,
#   'id_legislador': '7cd1145c-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'López Gutiérrez David Epifanio',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Sinaloa',
#   'distrito': '1',
#   'curul': 'K-395',
# ...
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=182'},
#  {'legislatura': 63,
#   'id_legislador': 'b965a7e8-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'González Luna Josefina',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Jalisco',
#   'distrito': '1',
#   'curul': 'A-010',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Laura Beatríz Noelia Reynoso González',
#   'partido': 'alianza',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=1007'},
#  {'legislatura': 63,
#   'id_legislador': 'b98941b2-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Manuel Alexander Zetina Aguiluz',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Quintana Roo',
#   'distrito': '3',
#   'curul': 'C-064',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Gutiérrez García Carlos',
#   'partido': 'alianza',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=914'},
#  {'legislatura': 63,
#   'id_legislador': 'b99356b6-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Gutiérrez García Carlos',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Quintana Roo',
#   'distrito': '3',
#   'curul': 'C-064',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'alianza',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=914'},
#  {'legislatura': 63,
#   'id_legislador': 'b9b0fe82-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'José Bernardo Quezada Salas',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Ciudad de México',
#   'distrito': '4',
#   'curul': 'A-009',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Hernández León Luis Manuel',
#   'partido': 'encuentro social',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=949'},
#  {'legislatura': 63,
#   'id_legislador': 'b9bc06ba-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Hernández León Luis Manuel',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Ciudad de México',
#   'distrito': '4',
#   'curul': 'A-009',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'encuentro social',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=949'},
#  {'legislatura': 63,
#   'id_legislador': 'b9e36962-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Méndez Salas Jesús Rafael',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Tamaulipas',
#   'distrito': '2',
#   'curul': 'C-063',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Mariano Lara Salazar',
#   'partido': 'encuentro social',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=377'},
#  {'legislatura': 63,
#   'id_legislador': 'ba0e6f22-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Ocampo Bedolla María Eugenia',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Morelos',
#   'distrito': '4',
#   'curul': 'B-034',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Alejandra Domínguez Narváez',
#   'partido': 'encuentro social',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=450'},
#  {'legislatura': 63,
#   'id_legislador': 'ba3e229e-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Palomares Ramírez Elvia Graciela',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Puebla',
#   'distrito': '11',
#   'curul': 'E-140',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Anel Fernández Zempoalteca',
#   'partido': 'encuentro social',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=219'},
#  {'legislatura': 63,
#   'id_legislador': 'ba64f9b4-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Jorge Gaviño Ambriz',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Colima',
#   'distrito': '5',
#   'curul': 'B-035',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Pinto Torres Francisco Javier',
#   'partido': 'encuentro social',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=994'},
#  {'legislatura': 63,
#   'id_legislador': 'ba71af1a-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Pinto Torres Francisco Javier',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Colima',
#   'distrito': '5',
#   'curul': 'B-035',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'encuentro social',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=994'},
#  {'legislatura': 63,
#   'id_legislador': 'ba97784e-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Reyes Ávila Angélica',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Michoacán',
#   'distrito': '5',
#   'curul': 'B-036',
#   'suplente_propietario': 'P',
#   'name_suplente': 'María Elvia Bárcenas Torres',
#   'partido': 'encuentro social',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=493'},
#  {'legislatura': 63,
#   'id_legislador': 'babf114c-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Soralla Bañuelos de la Torre',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Nuevo León',
#   'distrito': '2',
#   'curul': 'A-011',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Saldívar Paz Mirna Isabel',
#   'partido': 'encuentro social',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=876'},
#  {'legislatura': 63,
#   'id_legislador': 'bac9b3cc-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Saldívar Paz Mirna Isabel',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Nuevo León',
#   'distrito': '2',
#   'curul': 'A-011',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'encuentro social',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=876'},
#  {'legislatura': 63,
#   'id_legislador': 'bae7f47c-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Sánchez Ruiz Karina',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Oaxaca',
#   'distrito': '3',
#   'curul': 'C-065',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Rosa Amalia Lozano Silva',
#   'partido': 'encuentro social',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=413'},
#  {'legislatura': 63,
#   'id_legislador': 'bb0c673a-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Torres Sandoval Melissa',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Ciudad de México',
#   'distrito': '4',
#   'curul': 'C-066',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Damaris Farelas Pacheco',
#   'partido': 'encuentro social',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=460'},
#  {'legislatura': 63,
#   'id_legislador': 'bb309ed4-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Valles Mendoza Luis Alfredo',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Durango',
#   'distrito': '1',
#   'curul': 'B-037',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Miguel Ramírez Sánchez',
#   'partido': 'encuentro social',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=335'},
#  {'legislatura': 63,
#   'id_legislador': 'bb565bf6-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Cruz Hernández Abel',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Hidalgo',
#   'distrito': '5',
#   'curul': 'I-317',
#   'suplente_propietario': 'P',
#   'name_suplente': 'José Luis Barradas Rodríguez',
#   'partido': 'encuentro social',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=1005'},
#  {'legislatura': 63,
#   'id_legislador': 'bb7ad90e-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Hugo Eric Flores Cervantes',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Ciudad de México',
#   'distrito': '4',
#   'curul': 'I-318',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Escobedo Miramontes Justo Federico',
#   'partido': 'sin partido',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=959'},
#  {'legislatura': 63,
#   'id_legislador': 'bb8645aa-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Escobedo Miramontes Justo Federico',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Ciudad de México',
#   'distrito': '4',
#   'curul': 'I-318',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'sin partido',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=959'},
#  {'legislatura': 63,
#   'id_legislador': 'bba603cc-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Ferreiro Velazco José Alfredo',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Baja California',
#   'distrito': '1',
#   'curul': 'J-360',
#   'suplente_propietario': 'P',
#   'name_suplente': 'José Carlos Sandoval Pérez',
#   'partido': 'sin partido',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=339'},
#  {'legislatura': 63,
#   'id_legislador': 'bbe2a462-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'García Soberanes Cynthia Gissel',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Baja California',
#   'distrito': '1',
#   'curul': 'G-236',
#   'suplente_propietario': 'P',
#   'name_suplente': 'María Teresa Fuentes Escalante',
#   'partido': 'sin partido',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=329'},
#  {'legislatura': 63,
#   'id_legislador': 'bc1d006c-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Garzón Canchola Refugio Trinidad',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Sonora',
#   'distrito': '1',
#   'curul': 'M-500',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Lydia Negrete Salazar',
#   'partido': 'sin partido',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=333'},
#  {'legislatura': 63,
#   'id_legislador': 'bc598e60-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Guízar Valladares Gonzalo',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Veracruz',
#   'distrito': '3',
#   'curul': 'M-499',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Juan José García Espinosa',
#   'partido': 'sin partido',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=420'},
#  {'legislatura': 63,
#   'id_legislador': 'bc8531c8-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Sasil Dora Luz De León Villard',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Chiapas',
#   'distrito': '6',
#   'curul': 'J-363',
#   'suplente_propietario': 'P',
#   'name_suplente': 'López Ruiz Nancy',
#   'partido': 'sin partido',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=521'},
#  {'legislatura': 63,
#   'id_legislador': 'bc917438-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'López Ruiz Nancy',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Chiapas',
#   'distrito': '6',
#   'curul': 'J-363',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'sin partido',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=521'},
#  {'legislatura': 63,
#   'id_legislador': 'bcb206e4-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Martínez Guzmán Norma Edith',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Jalisco',
#   'distrito': '1',
#   'curul': 'J-364',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Laura Isalinda López López',
#   'partido': 'sin partido',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=340'},
#  {'legislatura': 63,
#   'id_legislador': 'bcdde7dc-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Perea Santos Ana Guadalupe',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Hidalgo',
#   'distrito': '5',
#   'curul': 'K-235',
#   'suplente_propietario': 'P',
#   'name_suplente': '',
#   'partido': 'sin partido',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=500'},
#  {'legislatura': 63,
#   'id_legislador': 'bd01d2b4-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Pineda Morín Abdies',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Tamaulipas',
#   'distrito': '2',
#   'curul': 'I-319',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Ricardo Quintanilla Leal',
#   'partido': 'sin partido',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=380'},
#  {'legislatura': 63,
#   'id_legislador': 'bd293d18-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Sarur Torre Adriana',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Veracruz',
#   'distrito': '3',
#   'curul': 'H-263',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Ana Cecilia Zamora Falcón',
#   'partido': 'sin partido',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=407'},
#  {'legislatura': 63,
#   'id_legislador': 'bd4b31de-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Manuel Jesús Clouthier Carrillo',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Sinaloa',
#   'distrito': '5',
#   'curul': 'K-405',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Zazueta Osuna María del Rocío',
#   'partido': 'sin partido',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=743'},
#  {'legislatura': 63,
#   'id_legislador': 'bd579a64-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Zazueta Osuna María del Rocío',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Sinaloa',
#   'distrito': '5',
#   'curul': 'K-405',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'sin partido',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=743'},
#  {'legislatura': 63,
#   'id_legislador': 'bd7bd028-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Espino Manuel de Jesús',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'México',
#   'distrito': '5',
#   'curul': 'F-196',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Samuel Ramírez Hernández',
#   'partido': 'sin partido',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=491'},
#  {'legislatura': 63,
#   'id_legislador': 'bda3f3be-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Flores Sosa Cesar',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Coahuila',
#   'distrito': '2',
#   'curul': 'L-417',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Jesús Marcelino Buendía Rosas',
#   'partido': 'sin partido',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=347'},
#  {'legislatura': 63,
#   'id_legislador': 'bdc9e146-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Guerrero García Javier',
#   'tipo_legislador': 'Representación proporcional',
#   'entidad': 'Coahuila',
#   'distrito': '2',
#   'curul': 'J-354',
#   'suplente_propietario': 'P',
#   'name_suplente': 'David Boone de la Garza',
#   'partido': 'sin partido',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=360'},
#  {'legislatura': 63,
#   'id_legislador': 'bded66f2-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Martínez Neri Francisco',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Oaxaca',
#   'distrito': '8',
#   'curul': 'E-151',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Heriberto Varela Colmenares',
#   'partido': 'sin partido',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=205'},
#  {'legislatura': 63,
#   'id_legislador': 'be0f6518-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Spinoso Carrera Edgar',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Veracruz',
#   'distrito': '7',
#   'curul': 'H-255',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Gustavo Moreno Ramos',
#   'partido': 'sin partido',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=277'},
#  {'legislatura': 63,
#   'id_legislador': 'be3d284a-fcf8-11ea-83d8-acde48001122',
#   'nombre_completo': 'Toledo Medina José Luis',
#   'tipo_legislador': 'Mayoría Relativa',
#   'entidad': 'Quintana Roo',
#   'distrito': '1',
#   'curul': 'F-174',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Juan Pablo Guillermo Molina',
#   'partido': 'sin partido',
#   'link_curricula': 'http://sitllxiii.diputados.gob.mx/curricula.php?dipt=229'}]

# %%
for i in data_id:
    print(i['suplente'])
# Out:
# Claudia Janeth Ochoa Iñiguez
# Carlos Joaquín Sosa López
# Jesús Antonio Hazouri Mansur
# Raymundo Moreno Ibáñez
# Ma. Guadalupe Calderón Medina
# Marco Antonio Barranco Sánchez
# Jorge Carlos Ramírez Marín  (ficha curricular)
# Sinthia Del Carmen Alvarado Canche
# Fabiola Rosas Cuautle
# Pablo Casas Jaime
# Elizabeth Hernández Calderón
# Eduardo Herrera Calixto
# Verónica Boreque Martínez González
# José Lucas Vallarta Chan
# Juana Leticia Hernández Armas
# Pablo Basáñez García  (ficha curricular)
# Rogelio López Angulo
# Ana Yolanda Esquivel Jaramillo
# César Alfonso Padilla Vázquez
# Carlos Rangel Aquino
# José Luis Lima González
# María Esther Fragoso Terán
# Laura Beatriz Hernández Tapia
# Sylvana Beltrones Sánchez  (ficha curricular)
# Santos Garza Herrera
# Yolanda De la Torre Valdez  (ficha curricular)
# Yolanda Eugenia González Hernández
# David Aguilar Robles  (ficha curricular)
# Rubí Alejandra Cardoso Guzmán
# Renato Dorantes Dorantes
# Magin Pereda Martínez
# Gustavo Sotelo Villegas
# Gabriel Casillas Zanatta  (ficha curricular)
# Juan Carlos Perrotin Cadena
# Marco Polo Aguirre Chávez  (ficha curricular)
# José Filiberto Flores Elizondo
# Martha Aidee Núñez Ramos
# Rosa Isela Rojas Luna
# Arturo Miguel Pacheco Meza
# Felipe Cervera Hernández  (ficha curricular)
# María Luisa Pérez Perrusquía
# Manuel Adonay Vargas Cuevas
# Adolfo García Morales
# Rogelio Betancourt González
# Georgina Adriana Pulido García
# Rosa Haydee González González
# Jesús Juan De La Garza Díaz Del Guante  (ficha curricular)
# Pablo Gamboa Miner  (ficha curricular)
# Priscilla Sahagún Salinas
# Ariel Burgos Ochoa
# Cirilo Vázquez Parissi  (ficha curricular)
# Juan Manuel Gómez Morales
# Rocío Guzmán De Paz
# María Teresa Sánchez Ruíz Esparza
# Francisco Javier Salcido Lozoya
# Salvador Félix Reyes
# Aurelio Argüelles Martínez
# María Del Rocío Rebollo Mendoza  (ficha curricular)
# Idania Itzel García Salgado
# Marcelino Rutilio Alamirra Muñoz
# Griselda Dávila Beaz
# Gloria González Burboa
# Lilia Escobar Ávila
# Alberto Pulido Cornejo
# Gabriela Hernández López
# Rosa Elena Millán Bueno  (ficha curricular)
# Ricardo Navarrete Reyes
# Maximiliano Silerio Díaz
# Teodardo Muñoz Torres
# Ramón Fernández Solana
# Paola Jiménez Hernández
# Raúl Domínguez Rex  (ficha curricular)
# José Ángel Cárdenas Castillejos
# Raymundo Muñoz Leyva
# Margarita Huerta García
# Laura Angélica Herrera Márquez
# María Dolores Serna Ibarra
# Julio César Portales Martínez
# Elsa María Tamayo Cárdenas
# Patricia Elizabeth Ramírez Mata
# Linda Rubí Martínez Díaz
# Andrea Margarita Márquez Villarreal
# Antonio Enrique Tarín García
# Sylvia López González
# César Camacho  (ficha curricular)
# Ricardo Gamundi Rosas
# Jorge Luis Arellano Cruz
# Blanca Aurelia Anzaldua Nájera
# Edgardo Rebollar Pérez
# José Luis Baeza Rojas
# Enrique Díaz López
# --- --- ---
# David Ricardo Sánchez Guevara  (ficha curricular)
# Víctor Manuel García Figueiras
# Víctor Manuel Pavón Ríos
# Rafael Martínez Pérez
# Thania Valdez Monroy
# María Verónica Muñoz Parra  (ficha curricular)
# Víctor Manuel Godoy Angulo
# Ascención Reyes Santiago
# José Inocencio Aguirre Willars
# Norma Cecilia Reyes Guerrero
# Tila Del Rosario Hernández Javier
# Juan Pablo Montiel De La Paz
# Yerico Abramo Masso  (ficha curricular)
# Ileana María Quintero García
# Agustina Toledo Hernández
# José Luis Velázquez González
# Jaime Ríos Velasco Grajeda
# Ernesto Gabriel Robinson Terán
# José Antonio Albores Trujillo
# Luis Miguel López Díaz
# Daniel Rolando Jiménez Rojo
# Ivonne Aracelly Ortega Pacheco  (ficha curricular)
# María Hadad Castillo
# Beatriz Mercedes Corona Mercado
# Ma. Marcela González Salas y Petricioli  (ficha curricular)
# Jaime Martínez Tapia
# Rogelio Ayala Palomino
# Manuel Montaño Gutiérrez
# Telésforo García Carreón  (ficha curricular)
# Rosaura Ayala Hernández
# José Fernando Peña Garavito
# José Odilón Ruiz Sánchez
# Ramiro Solorio Almazán
# Ernesto Vázquez Baca
# Edgar Castillo Martínez  (ficha curricular)
# - - -
# Patricia Marcela González Valencia
# Ramiro Jr Farías Martínez
# Dulce María Cervera Cetina
# Jeany Fernández Jiménez
# Edna Ileana Dávalos Elizondo
# Carolina Monroy Del Mazo  (ficha curricular)
# Giovanni Andrei Ramírez Buendía
# Bernardino Antelo Esper  (ficha curricular)
# Rosalba Santiago Escobar
# Cesar Alberto Cruz Ortíz
# Francisca Ana Krauss Velarde
# Antonio Cabrera Villalba
# Camila García Castells Alanis
# Clementino Morales Vásquez
# Víctor Manuel Rodríguez Santibáñez
# Fidel Cristóbal Serrato
# Alfredo Del Mazo Maza  (ficha curricular)
# Perla Pérez Reyes
# Graciela Fernández Almaraz
# Antonio Amaro Cancino  (ficha curricular)
# Jovita Ortiz Benítez
# Ma. Eugenia Rojas González
# Maricela Serrano Hernández  (ficha curricular)
# Elizabeth Adriana Flores Torres
# Daniel Torres Cantú  (ficha curricular)
# Florencio Rodríguez Luna
# Herminio Cahue Calderón
# Baltazar Manuel Hinojosa Ochoa  (ficha curricular)
# Esteban De La Portilla Flores
# Erenoldo González Rivera
# Gonzalo Fabián Muñoz
# Cristina del Carmen Alcerreca Manzanero
# Sandra Méndez Hernández  (ficha curricular)
# Rafael Callejas Ochoa
# Victoria Nataly Olmedo Basilio
# Neftalí Ortiz Velázquez
# María Cristina Ramos Reyes
# Luz Ana García Alarcón
# Olga Erika Espinosa Álvarez
# José Roberto Ramírez Urbán
# Herón Bulos Lárraga
# Claudia Pimentel Villalpa
# Eligio Valencia López
# Manuel León Chávez
# Guillermo Ruíz Guerra
# Ofelia Socorro Jasso Nieto
# Pablo Elizondo García  (ficha curricular)
# Paulino Alberto Vázquez Villalobos
# J. Jesús Hernández Peña
# Alejandra Gutiérrez Macías
# José Lorenzo Rivera Sosa  (ficha curricular)
# Roberto Sales Rosado
# Miguel Angel Piña Garibay
# María Lorena Pérez Olivas
# Mayra Herrera Saynes
# Ana Laura Rodela Soto
# Isabel Cristina Rueda Leyva
# Leopoldo Juárez Colorado
# Juan Ubaldo Benavente Bermúdez
# Abraham López Martínez
# Marco Antonio Velásquez Valencia
# Edgar Federico Guerrero Martínez
# Sergio Hernández Bennettz
# Claudia Beltrán Salas
# Pedro Tec Tun
# Brenda Lizette Flores Franco
# Rodolfo Longoria García
# Modesta Yolanda Pacheco Olivares
# Arnulfo Torres Aguilar
# Georgina Trujillo Zentella  (ficha curricular)
# Juan Carlos Villarreal Salazar
# Gloria Viviana Juárez Fierro
# Maricela Espinoza Silva
# Víctor Manuel Aldrete Tejeda
# Mónica Rodríguez Della Vecchia  (ficha curricular)
# Alfa Talia Mendieta González
# Constantino Aparicio Isidro
# María del Socorro Patiño Alonso
# Diana Patricia Alanis Barroso
# Corina Trenti Lara
# Víctor Manuel Torres Herrera
# Annia Alicia García García
# Armando Terán Corella
# José Pablo Rétiz Gutiérrez
# Israel Amador Serrano
# Adrián Gutiérrez Morales
# Daniel Ignacio Olivas Gutiérrez
# Daniel Ortega Flores
# Obdulia del Carmen Solís Gómez
# Hipólito Deschamps Espino Barros
# Joaquín Jesús Díaz Mena  (ficha curricular)
# Jorge Ramos Hernández  (ficha curricular)
# José Gustavo Botello Montes
# José Cabalan Macari Álvaro
# Jisela Paes Martínez  (ficha curricular)
# José Carmen Anceno Rivas
# José Eduardo Ojeda Guerrero
# Miguel Ángel Luna Velázquez
# Jorge Roldán Pérez
# Juan Antonio Valadez Sánchez
# Oscar Cuevas Corona
# Carlos Francisco Castelazo Mendoza
# José Luis Sainz Guerrero
# Mine Valeria Mares Villaseñor
# Mario Alberto Cantú Gutiérrez
# Oscar Daniel Hernández Morales
# Martha Tamara Rodríguez Melesio
# Patricia García García  (ficha curricular)
# Rolando Hervert Lara
# Norma Angélica Zacaula Martínez
# Pedro Javier Payan Gomez
# Cristina Fernández De Cevallos Y Chavarría
# José Gaudencio Víctor León Castañeda
# Francisco Javier Medina Mendoza
# Nicolás Quintero Russel
# Jesús Reynaldo Ramos Alvarado
# Angelina Lizeth Arcos Villalva
# Paola Dayanara Caraza Ortega
# Juan Manuel De Unanue Abascal
# Adriana Gabriela Ceballos Hernández
# Ricardo Del Rivero Martínez
# Sergio Moreno Valle Germán
# Irma Patricia Leal Islas
# María Guadalupe Murguía Gutiérrez  (ficha curricular)
# Ricardo García Ramírez
# Pedro Garza Treviño  (ficha curricular)
# Liliana Armendáriz Granados
# Francisco Ricardo Sheffield Padilla  (ficha curricular)
# María Marcia Durazo Cortez
# Hernán Méndez Caballero
# Víctor Odín Castillo Ávila
# Juan Luis De Anda Mata
# José Refugio Chávez Rodríguez
# Josefina Rueda Rosado
# Jaime Mauricio Rojas Silva
# Tomas David Macías Canales
# Francisco Tarín Perisky
# Rubén Romeo Sumano García
# Elsa Del Socorro Sánchez Arjona
# José Antonio Salas Valencia  (ficha curricular)
# Gustavo Enrique Madero Muñoz  (ficha curricular)
# Alba María Milán Lara
# Cynthia Susana Zaragoza Galván
# Mirna Cecilia Rincón Vargas
# Andrés Ramírez Nenninger
# Úrsula Cariño Estrada Lomelí
# Katia Berenice Burguete Zúñiga
# Mónica Ruelas Sánchez
# Jaime Llaven Martínez
# Margarita Mercado Medina
# Gina Andrea Cruz Blackledge  (ficha curricular)
# Blas Jorge Garcilazo Alcantara
# Odín Ramses Ramírez Núñez
# María del Rosario Vera
# Carlos Dávila Meza
# Hortensia De La Concepción Orozco Tejeda
# Ricardo Martínez Rojas Rustrian
# Rocío Leticia Zavala García
# Luis Alberto Ramírez Almaguer
# Lucina Rodríguez Martínez
# Luis Fernando Sánchez Lara
# María Fernanda Huerta López
# Rafael Alejandro Serna Vega
# José de Jesús Valdez Gómez
# Alejandro Arena Barroso
# Mayuli Latifa Martínez Simón
# Francisca Sandoval Marez
# Corina López Páez
# Marisol González Martínez
# Alejandro Méndez González
# Rosa Isela Martínez Díaz
# Cleo Patricia Treviño Tamez
# Víctor Ernesto Ibarra Montoya  (ficha curricular)
# Jacobo Soto Pizano
# Guillermo Octavio Huerta Ling
# Marco Antonio Cambero Gómez
# Jessica Janeth Pérez Bautista
# Nadia Flores Meléndez
# Celia Castro Torres
# Josefina Cantú Benavides
# Mayra Angélica Enríquez Vanderkam  (ficha curricular)
# José Arreola Contreras
# Eduardo Moraila Morales
# Nicanor Martínez Olguin
# María Guadalupe Aragón Castillo
# Alma Guadalupe Vázquez Chairez
# Jorge Alberto Allec Maciel
# Fernando Galván Martínez
# Criselda Santos Guzmán
# Abelardo Zurita Solano
# Waldo Fernández González  (ficha curricular)
# Candy Araceli Gallardo Cardona
# Hilda Miranda Miranda
# Marisol Ayala Ambrosio
# Flora Gutiérrez Gutiérrez
# Antonino Morales Toledo
# Leonides Fernández Cruz
# Dimna Guadalupe Salgado Apatiga
# Martha Eugenia Albores Loeza
# Alberto Ojeda Ojeda
# Reyna Ma Beatriz Barrón Pacheco
# Adrian Maldonado Campanor
# Jesús Alexey Martínez Cedano
# Hugo Eduardo Martínez Padilla
# José María Arroyo Juárez
# Bertha Alicia Martínez Vargas
# Jorge Martínez Villavicencio
# Norma Alicia Salazar Esteban
# Roberto Sergio Morales Noble
# José Soto Medina
# José Carlos Camacho Díaz
# Jairo Felipe Valdez
# Juan Manuel Orozco Carmona
# José Hugo Ángel Olvera
# Bertha Andrea Ramos Rojas
# Luis José Sánchez Torres
# Gilberto De La Cruz Domínguez
# Eulalia López Gutiérrez
# María Isabel Romero Javier
# Francisco Javier Niño Hernández
# Abraham Rojas Martínez
# José Gabriel Gutiérrez Ávila
# Eduardo Santana Alfaro
# Eduardo Villafuerte García
# Karina Miranda Becerra
# Edgar Jonathan Pérez Ávila
# María Cristina Teresa García Bravo
# Elías Ojeda Aquino
# Miriam Tinoco Soto  (ficha curricular)
# Erick Arturo Figueroa Ovando
# Oracio Flores Ruiz
# Cristian Israel Valiente Delgado
# Luis Fernando Jara Vargas
# Gabriela Osorio Hernández
# Gerardo Galicia Juárez
# José Rodrigo Ávila Carrasco
# Ricardo Ernesto López Priego
# Tania Elizabeth Ramos Beltrán
# Bennelly Jocabeth Hernández Ruedas
# Everardo Medina Ruiz
# Jesús Casillas Álvarez
# Julio César Tinoco Oros
# Maricela Corona Ambriz
# María Teresa Hernández López
# Mario David Mex Albornoz
# Eugenio Cardoso Mercado
# Gonzalo Fabián Medina Hernández
# Alejandra Morales Novoa
# Liliana Sarahi Hernández Domínguez
# Irma Arcos Ortiz
# María del Rosario Palacios Alejo
# Diana Marcela Márquez Canales
# Elia Martínez Sánchez
# María De Lourdes González Hernández
# Ramiro Blancas Toledo
# Sergio René Cancino Barffuson
# José Ángel Beltrán Félix
# María Del Carmen Piña Martínez
# Magdalena Moreno Vega
# Ángel Romero Morales
# Araceli Berenice Hernández Calderón
# María Magdalena del Carmen Cornelio García
# Alonso Ortega Gamboa
# Guillermo Jorge Sánchez González
# Saraí Avilés Cadena
# Luis Jorge Mayorga Godínez
# José Ramón Enríquez Herrera
# Pedro Mayen Luna
# Lorena Plata González
# Juan Manuel Gamiñio Benz
# Alejandra Fernández Ramírez
# Justina del Carmen Luna Pérez
# Daniel Salazar Núñez
# Vidal Llerenas Morales  (ficha curricular)
# Liliana Herrera Hernández
# Sandra Luz Falcón Venegas  (ficha curricular)
# Daniel Parra Huerta
# Samuel Abraham Torres Méndez
# Leonardo Gahona Pérez
# Martha Julia Rodríguez Acosta
# Vladimir Luna Porquillo
# Marisela Aguilar Villaseñor
# Jesús Herbey Arredondo Díaz
# Juana Medina Mosqueda
# Víctor Carlos Armas Zagoya
# Genny Janeth López Valenzuela
# Elena Yaneth Romo Pérez
# Carlos Silviano Bejar Rueda
# Sandra Alejandrina Herrera Álvarez
# Marcelino Cisneros Ramírez
# Elieser Casiano Popocatl Castillo
# Armida Hernández Vidrio
# María Guadalupe Soto Cota
# Félix Martínez Olivares
# María Carmen Velásquez Mejía
# Carlos Miguel Pérez Ancona
# Clara Martínez Aguirre
# Quirino Ordaz Coppel  (ficha curricular)
# Wendolin Toledo Aceves  (ficha curricular)
# Jorgina Gaxiola Lezama  (ficha curricular)
# María Isabel Zamora Falcón
# Jorge Álvarez López  (ficha curricular)
# Mirna Karina Martínez Jara
# Ricardo López Montejo
# Roberto Sánchez y Escalante
# Verónica Guadalupe Brunt González
# Luis Ignacio Avendaño Bermúdez  (ficha curricular)
# Remberto Estrada Barba  (ficha curricular)
# Fernando Pérez Rodríguez
# Sergio Adán Flores Armenta
# Ricardo Guillen Rivera
# Jesús Gerardo Izquierdo Rojas  (ficha curricular)
# Pablo Mauricio Gutiérrez Robles
# Fernando Villarreal Cuellar
# Arturo Navarrete Escobar
# José Eduardo Ruíz Chimal
# Fernando José Vega Espinosa
# Daniela De Los Santos Torres  (ficha curricular)
# Maraí Padilla Martínez
# Ángel Santis Espinoza
# Miguel Alberto Vallejo Lozano
# Verónica Delgadillo García  (ficha curricular)
# Daniel Adrián Sosa Carpio
# Salvador Zamora Zamora  (ficha curricular)
# Mayra Daniela Parra Montejo
# Daniella Judith Hernández Flores
# Luis Ernesto Munguía González  (ficha curricular)
# José Clemente Castañeda Hoeflich  (ficha curricular)
# José Rodrigo Ramírez Mojarro
# María Luisa Xolalpa Molina
# María Martha Palencia Núñez
# Jonadab Martínez García  (ficha curricular)
# Sara Leticia Prado Blagg
# Daniel Landgrave Castillo
# Sandra Pompeya Aceves Tejeda
# Porfirio Encarnación Camba
# Diana Melissa Martínez Lucio
# María Elena Orantes López  (ficha curricular)
# Gabriel Real Huizar
# Esteban Petersen Cortes
# Janet Jiménez Solano
# Gilberto Toledano Sánchez
# Laura Beatríz Noelia Reynoso González
# Manuel Alexander Zetina Aguiluz  (ficha curricular)
# José Bernardo Quezada Salas  (ficha curricular)
# Mariano Lara Salazar
# Alejandra Domínguez Narváez
# Anel Fernández Zempoalteca
# Jorge Gaviño Ambriz  (ficha curricular)
# María Elvia Bárcenas Torres
# Soralla Bañuelos de la Torre  (ficha curricular)
# Rosa Amalia Lozano Silva
# Damaris Farelas Pacheco
# Miguel Ramírez Sánchez
# José Luis Barradas Rodríguez
# Hugo Eric Flores Cervantes  (ficha curricular)
# José Carlos Sandoval Pérez
# María Teresa Fuentes Escalante
# Lydia Negrete Salazar
# Juan José García Espinosa
# Sasil Dora Luz De León Villard  (ficha curricular)
# Laura Isalinda López López
#
# Ricardo Quintanilla Leal
# Ana Cecilia Zamora Falcón
# Manuel Jesús Clouthier Carrillo  (ficha curricular)
# Samuel Ramírez Hernández
# Jesús Marcelino Buendía Rosas
# David Boone de la Garza
# Heriberto Varela Colmenares
# Gustavo Moreno Ramos
# Juan Pablo Guillermo Molina

# %%
len(data_id)
# Out:
# 500

# %%
mapping_id_cand = {}
for i in data_id:
    mapping_id_cand[i['nombre_completo']] = i['id_legislador']

# %%
import unidecode

# %%
for i in data_id:
    i['nombre_completo'] = unidecode.unidecode(i['nombre_completo'])
    i['tipo_legislador'] = unidecode.unidecode(i['tipo_legislador'])
    i['suplente'] = unidecode.unidecode(i['suplente'])
    i['entidad'] = unidecode.unidecode(i['entidad'])

# %%
with open('/Users/cblanesg/cam.blanes Dropbox/Camila Blanes/floor-speechMX/data/diputados/id_data/legislatura63.json', 'w') as json_file:
    json.dump(data_id, json_file)

# %% [markdown]
# ## Listado de Legislaturas

# %%
driver.get('http://gaceta.diputados.gob.mx/SIL/Legislaturas/Listados.html')

# %%
def obtain_tipo_legislador(i):
    if any(re.findall('[0-9]+', i.find_element_by_class_name('col5').text)):
        return('Mayoria Relativa')
    else:
        return('Representacion Proporcional')

# %%
def cric_to_number(x):
    if x == 'Primera':
        return(1)
    elif x == 'Segunda':
        return(2)
    elif x == 'Tercera':
        return(3)
    elif x == 'Cuarta':
        return(4)
    elif x == 'Quinta':
        return(5)
    else:
        return(x)

# %%
def data_legislatura(leg, i):
    dict_id = {}
    dict_id['legislatura'] = leg
    dict_id['id_legislador'] = str(uuid.uuid1())
    dict_id['first_name'] = re.sub('^[ ]+', '', unidecode.unidecode(i.find_element_by_class_name('col1').text.split(',')[1]))
    dict_id['last_name'] = re.sub('^[ ]+', '', unidecode.unidecode(i.find_element_by_class_name('col1').text.split(',')[0]))
    dict_id['name_inc'] = re.sub('[,]', '', unidecode.unidecode(i.find_element_by_class_name('col1').text))
    dict_id['tipo_legislador'] = obtain_tipo_legislador(i)
    dict_id['entidad'] = unidecode.unidecode(i.find_element_by_class_name('col4').text)
    dict_id['distrito'] = cric_to_number(i.find_element_by_class_name('col5').text)
    dict_id['partido'] = unidecode.unidecode(i.find_element_by_class_name('col3').text)
    dict_id['propietario_suplente'] = unidecode.unidecode(i.find_element_by_class_name('col2').text)
    return(dict_id)

# %%
driver.get('http://gaceta.diputados.gob.mx/SIL/Legislaturas/Listados.html')

# %%
info_legisladores = []

# %%
for i in tqdm(driver.find_elements_by_class_name('tr0')):
    info_legisladores.append(data_legislatura(60, i))
for i in tqdm(driver.find_elements_by_class_name('tr1')):
    info_legisladores.append(data_legislatura(60, i))
# Out:
# 100%|██████████| 301/301 [01:13<00:00,  4.12it/s]
# 100%|██████████| 300/300 [01:38<00:00,  3.03it/s]

# %%
len(info_legisladores)
# Out:
# 2364

# %%
h = 0
for i in info_legisladores:
    if i['propietario_suplente'] == 'P':
        h += 1
    else:
        continue

# %%
df = pd.DataFrame(info_legisladores)

# %%
df[df['propietario_suplente'] == 'P'][['id_legislador', 'legislatura']].groupby(['legislatura']).count()
# Out:
#              id_legislador
# legislatura
# 60                     501
# 61                     502
# 62                     500
# 63                     498

# %%
df[['propietario_suplente','id_legislador', 'legislatura']].groupby(['legislatura', 'propietario_suplente']).count()
# Out:
#                                   id_legislador
# legislatura propietario_suplente
# 60          P                               501
#             S                               100
# 61          P                               502
#             S                               130
# 62          P                               500
#             S                               131
# 63          P                               498
#             S                                 2

# %%
len(driver.find_elements_by_class_name('tr0'))
# Out:
# 250

# %%
len(driver.find_elements_by_class_name('tr1'))
# Out:
# 250

# %%
for i in driver.find_elements_by_class_name('tr0'):
    if i.find_element_by_class_name('col2').text != 'P':
        print(i.find_element_by_class_name('col1').text)
# Out:
# Juraidini Villaseñor, Alejandro

# %%
with open('/Users/cblanesg/cam.blanes Dropbox/Camila Blanes/floor-speechMX/data/diputados/id_data/listado_legislaturas.json', 'w') as json_file:
    json.dump(info_legisladores, json_file)

# %% [markdown]
# ## Add Legislatura 64 (different webpage)

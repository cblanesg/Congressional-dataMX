# %%
import pandas as pd
import json
from os import listdir
from tqdm import tqdm
import re
from unidecode import unidecode

# %%
path_speeches = '/Users/cblanesg/cam.blanes Dropbox/Camila Blanes/Congressional-dataMX/data/01-collection_data/01-floor_speech/01-id_speakers/'

with open(path_speeches + 'intervenciones_dip63.json') as f:
    data = json.load(f)

# %%
with open('../../../../data/01-collection_data/06-aggregated-data/id_data.json') as d:
    id_data = json.load(d)

# %%
id_data_df = pd.DataFrame(id_data)[pd.DataFrame(id_data)['legislatura'] == 63]

# %%
mapp_names = {}
for x, y in zip(id_data_df.nombre_completo, id_data_df.id_legislador):
    mapp_names[x.lower()] = y

# %%
data[0].keys()
# Out:
# dict_keys(['legislatura', 'year_session', 'year_speech', 'month_speech', 'day_speech', 'topic_speech', 'link_speech', 'inc_party', 'inc_name', 'id_speech', 'text_speech', 'id'])

# %%
with open(path_speeches + 'intervenciones_dip63.json', 'w') as f:
    json.dump(data, f)

# %% [markdown]
# ### Legislatura 60

# %%
path_speeches = '/Users/cblanesg/cam.blanes Dropbox/Camila Blanes/Congressional-dataMX/data/01-collection_data/01-floor_speech/01-id_speakers/'

with open(path_speeches + 'intervenciones_dip60.json') as f:
    data = json.load(f)

# %%
path_id = '/Users/cblanesg/cam.blanes Dropbox/Camila Blanes/Congressional-dataMX/data/01-collection_data/00-id_data/00-id/'
with open(path_id + 'id_legislatura60.json') as f:
    id60 = json.load(f)

# %%
mapping_names = {}
for i in id60:
    mapping_names[i['nombre_completo']] = i['id_legislador']

# %%
import uuid

# %%
str(uuid.uuid1())
# Out:
# '78f7d052-31f3-11eb-bad6-acde48001122'

# %%
missing_ids = []
for i in data:
    if i['id'] == '' and i['inc_name'] not in missing_ids:
        missing_ids.append(i['inc_name'])

# %%
len(missing_ids)
# Out:
# 0

# %%
data[0]
# Out:
# {'legislatura': 60,
#  'year_session': 'I',
#  'year_speech': 2006,
#  'month_speech': 9,
#  'day_speech': 5,
#  'topic_speech': 'FENOMENOS CLIMATOLOGICOS',
#  'link_speech': 'http://cronica.diputados.gob.mx:8080/exist/siid2/xQsiid2.xql?legis=LX&coleccion=/db/LX/A1/P1/Ord%20,/db/LX/A1/P1/CPerma%20,/db/LX/A1/P2/Ord%20,/db/LX/A2/P1/Ord%20,/db/LX/A2/P2/Ord%20,/db/LX/A2/P2/Extra%20,/db/LX/A3/P1/Ord%20&id=13&num=1386&fecha=20060905&tema=FENOMENOS%20CLIMATOLOGICOS',
#  'inc_party': 'Partido Acción Nacional',
#  'inc_name': 'Aranda Orozco Gerardo',
#  'id_speech': '9dc33716-c4ba-3546-9ee4-c5f83f9d4483',
#  'text_speech': 'Consideramos en el   Partido Accion Nacional En consecuencia, estamos de acuerdo con la propuesta del Partido del Trabajo en el exhorto que esta soberania puede hacer al Poder Ejecutivo, en una sana relacion de poderes y sin necesidad de estar denigrando, denostando o adjetivisando una situacion que a todos nos duele y lamentamos. Muchisimas gracias.',
# ...

# %%
path_speeches
# Out:
# '/Users/cblanesg/cam.blanes Dropbox/Camila Blanes/Congressional-dataMX/data/01-collection_data/01-floor_speech/01-id_speakers/'

# %%
with open(path_speeches + 'intervenciones_dip60.json', 'w') as f:
    json.dump(data, f)

# %% [markdown]
# ### Legislatura 61

# %%
path_speeches = '/Users/cblanesg/cam.blanes Dropbox/Camila Blanes/Congressional-dataMX/data/01-collection_data/01-floor_speech/01-id_speakers/'

with open(path_speeches + 'intervenciones_dip61.json') as f:
    data = json.load(f)

# %%
path_id = '/Users/cblanesg/cam.blanes Dropbox/Camila Blanes/Congressional-dataMX/data/01-collection_data/00-id_data/00-id/'
with open(path_id + 'id_legislatura61.json') as f:
    id60 = json.load(f)

# %%
mapping_names = {}
for i in id60:
    mapping_names[i['nombre_completo']] = i['id_legislador']

# %%
import uuid

# %%
missing_ids = []
for i in data:
    if i['id'] == '' and i['inc_name'] not in missing_ids:
        missing_ids.append(i['inc_name'])

# %%
len(missing_ids)
# Out:
# 0

# %%
for i in data:
    if i['inc_name'] == 'Flores Escalera Hilda Esthela':
        i['id'] = str(uuid.uuid1())
    elif i['inc_name'] == 'Garza Flores Noé Fernando':
        i['id'] = str(uuid.uuid1())

# %%
str(uuid.uuid1())
# Out:
# 'b1d67728-31f5-11eb-bad6-acde48001122'

# %%
list(mapping_names.keys())
# Out:
# ['Aguero Tovar José Manuel',
#  'Edith Flores Rodríguez',
#  'Aguilar González José Óscar',
#  'María Eugenia Cabrera Huerta',
#  ' Angélica del Rosario Araujo Lara',
#  'Aguilar Góngora Efraín Ernesto',
#  ' Beatríz Elena Paredes Rangel',
#  'Aguilar Álvarez y Mazarrasa Jaime',
#  'Aguirre Maldonado Ma. de Jesús (LICENCIA)',
#  'Patricia Aguirre González',
#  'Aguirre Romero Andrés (LICENCIA)',
#  'Benylu Joana García Rodríguez',
#  'Ahued Bardahuil Ricardo',
#  'Rosalba Aburto López',
#  'Albarrán Mendoza Esteban',
#  'Omar Jalil Flores Majul',
#  ' Felipe Cervera Hernández',
#  'Alonzo Morales María Ester',
#  'Alvarado Arroyo Fermín Gerardo',
#  'Óscar Ignacio Rangel Miravete',
#  ' José Tomás Carrillo Sánchez',
#  'Álvarez Martínez José Luis',
#  'Álvarez Santamaría Miguel',
#  'Elvira Rebeca Arenas Martínez',
#  'Ambrosio Cipriano Heriberto',
#  'Eva Diego Cruz',
#  'Arana Arana Jorge',
#  'Sugeil Fonseca Gómez',
#  ' Jorge Herrera Caldera',
#  'Ávila Nevárez Pedro',
# ...

# %%
with open(path_speeches + 'intervenciones_dip61.json', 'w') as f:
    json.dump(data, f)

# %% [markdown]
# ### Legislatura 62

# %%
path_speeches = '/Users/cblanesg/cam.blanes Dropbox/Camila Blanes/Congressional-dataMX/data/01-collection_data/01-floor_speech/01-id_speakers/'

with open(path_speeches + 'intervenciones_dip62.json') as f:
    data = json.load(f)

# %%
path_id = '/Users/cblanesg/cam.blanes Dropbox/Camila Blanes/Congressional-dataMX/data/01-collection_data/00-id_data/00-id/'
with open(path_id + 'id_legislatura62.json') as f:
    id60 = json.load(f)

# %%
mapping_names = {}
for i in id60:
    mapping_names[i['nombre_completo']] = i['id_legislador']

# %%
missing_ids = []
for i in data:
    if i['id'] == '' and i['inc_name'] not in missing_ids:
        missing_ids.append(i['inc_name'])

len(missing_ids)
# Out:
# 0

# %%
for i in data:
    if i['inc_name'] == 'Villaseñor Vargas María de la Paloma':
        i['id'] = mapping_names['Villaseñor Vargas Paloma']
    elif i['inc_name'] == 'Acosta Peña Brasil Alberto':
        i['id'] = str(uuid.uuid1())
    elif i['inc_name'] ==  'Cruz Morales Maricruz':
        i['id'] = str(uuid.uuid1())   
    elif i['inc_name'] ==  'Funes Velázquez Erika Yolanda':
        i['id'] = str(uuid.uuid1())

# %%
missing_ids
# Out:
# ['Acosta Peña Brasil Alberto',
#  'Cruz Morales Maricruz',
#  'Funes Velázquez Erika Yolanda',
#  'Villaseñor Vargas María de la Paloma']

# %%
with open(path_speeches + 'intervenciones_dip62.json', 'w') as f:
    json.dump(data, f)

# %% [markdown]
# ### Legislatura 64

# %%
path_speeches = '/Users/cblanesg/cam.blanes Dropbox/Camila Blanes/Congressional-dataMX/data/01-collection_data/01-floor_speech/01-id_speakers/'

with open(path_speeches + 'intervenciones_dip64.json') as f:
    data = json.load(f)

# %%
path_id = '/Users/cblanesg/cam.blanes Dropbox/Camila Blanes/Congressional-dataMX/data/01-collection_data/00-id_data/00-id/'
with open(path_id + 'id_legislatura64.json') as f:
    id60 = json.load(f)

# %%
mapping_names = {}
for i in id60:
    mapping_names[i['nombre_completo']] = i['id_legislador']

# %%
missing_ids = []
for i in data:
    if i['id'] == '' and i['inc_name'] not in missing_ids:
        missing_ids.append(i['inc_name'])

len(missing_ids)
# Out:
# 0

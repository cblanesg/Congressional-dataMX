# %%
import uuid

# %%
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver import Chrome
from selenium import webdriver
import re
import time
import pandas as pd
import datetime
from tqdm import tqdm
from datetime import date
from selenium.webdriver.chrome.options import Options

main_url = 'http://cronica.diputados.gob.mx:8080/exist/siid2/siid2.xql?legis=LXII#'

options = Options()
options.add_argument('--headless')
driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# [WDM] - Current google-chrome version is 85.0.4183
# [WDM] - Get LATEST driver version for 85.0.4183
# [WDM] - Driver [/Users/cblanesg/.wdm/drivers/chromedriver/mac64/85.0.4183.87/chromedriver] found in cache

# %% [markdown]
# ## Legislatura 64

# %%
with open('/Users/cblanesg/cam.blanes Dropbox/Camila Blanes/Congressional-dataMX/data/00-id_data/00-id/id_legislatura64.json') as d:
    data = json.load(d)

data_inc = []
for i in data:
    if i['suplente_propietario'] == 'P':
        data_inc.append(i)
len(data_inc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ff7f88fa7acf> in <module>
#       1 with open('/Users/cblanesg/cam.blanes Dropbox/Camila Blanes/Congressional-dataMX/data/00-id_data/00-id/id_legislatura64.json') as d:
# ----> 2     data = json.load(d)
#       3
#       4 data_inc = []
#       5 for i in data:
#
# NameError: name 'json' is not defined

# %%
main_url = 'http://sitl.diputados.gob.mx/LXIV_leg/listado_diputados_gpnp.php?tipot=TOTAL'
driver.get(main_url)

# %%
links_diputados = []
names_diputados = []
for i in tqdm(driver.find_elements_by_css_selector('a')):
    link = i.get_attribute('href')
    if any(re.findall('curricula', link)):
        links_diputados.append(link)
        names_diputados.append(re.sub('^[0-9]+ ', '', i.text))
        
    else:
        continue
# Out:
# 100%|██████████| 511/511 [00:16<00:00, 30.31it/s]

# %%
mapping_name_party = {}
for i in names_diputados[0:251]:
    mapping_name_party[i] = 'MORENA'
    
for i in names_diputados[251: 329]:
    mapping_name_party[i] = 'PAN'
    
for i in names_diputados[329:377]:
    mapping_name_party[i] = 'PRI'
    
for i in names_diputados[377:423]:
    mapping_name_party[i] = 'PT'
    
for i in names_diputados[423:450]:
    mapping_name_party[i] = 'MC'
    
for i in names_diputados[450:474]:
    mapping_name_party[i] = 'ES'
    
for i in names_diputados[474:486]:
    mapping_name_party[i] = 'PRD'
    
for i in names_diputados[486:497]:
    mapping_name_party[i] = 'PVEM'

for i in names_diputados[497:]:
    mapping_name_party[i] = 'NA'

# %%
len(mapping_name_party)
# Out:
# 500

# %%
def obtain_id_data(name, mapping_parties, link):
    suplente_propietario = unidecode.unidecode(driver.find_element_by_css_selector('body > div > table.cajasombra > tbody > tr > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(6) > td:nth-child(2)').text)
    
    if any(re.findall('ficha curricular', suplente_propietario)):
        dict_id = {}
        dict_id['legislatura'] = 64
        dict_id['id_legislador'] = str(uuid.uuid1())
        dict_id['nombre_completo'] = re.sub('[ ]+$', '', re.sub('[(]ficha curricular[)]', '', suplente_propietario))
        dict_id['tipo_legislador'] = unidecode.unidecode(driver.find_element_by_css_selector('body > div > table.cajasombra > tbody > tr > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(2) > td:nth-child(2) > strong').text)
        dict_id['entidad'] = unidecode.unidecode(driver.find_element_by_css_selector('body > div > table.cajasombra > tbody > tr > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(1)').text)
        dict_id['distrito'] = driver.find_element_by_css_selector('body > div > table.cajasombra > tbody > tr > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(3)').text
        dict_id['curul'] = driver.find_element_by_css_selector('body > div > table.cajasombra > tbody > tr > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(5)').text
        dict_id['suplente_propietario'] = 'P'
        dict_id['name_suplente'] = unidecode.unidecode(driver.find_element_by_css_selector('body > div > table.cajasombra > tbody > tr > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(6) > td:nth-child(2)').text)
        dict_id['partido'] = mapping_parties[name]
        dict_id['link_curricula'] = link
        
        
        dict_sup = {}
        dict_sup['legislatura'] = 64
        dict_sup['id_legislador'] = str(uuid.uuid1())
        dict_sup['nombre_completo'] = name
        dict_sup['tipo_legislador'] = unidecode.unidecode(driver.find_element_by_css_selector('body > div > table.cajasombra > tbody > tr > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(2) > td:nth-child(2) > strong').text)
        dict_sup['entidad'] = unidecode.unidecode(driver.find_element_by_css_selector('body > div > table.cajasombra > tbody > tr > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(1)').text)
        dict_sup['distrito'] = driver.find_element_by_css_selector('body > div > table.cajasombra > tbody > tr > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(3)').text
        dict_sup['curul'] = driver.find_element_by_css_selector('body > div > table.cajasombra > tbody > tr > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(5)').text
        dict_sup['suplente_propietario'] = 'S'
        dict_sup['name_suplente'] = ''
        dict_sup['partido'] = mapping_parties[name]
        dict_sup['link_curricula'] = link
        return([dict_id, dict_sup])
    else:
        dict_id = {}
        dict_id['legislatura'] = 64
        dict_id['id_legislador'] = str(uuid.uuid1())
        dict_id['nombre_completo'] = name
        dict_id['tipo_legislador'] = unidecode.unidecode(driver.find_element_by_css_selector('body > div > table.cajasombra > tbody > tr > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(2) > td:nth-child(2) > strong').text)
        dict_id['entidad'] = unidecode.unidecode(driver.find_element_by_css_selector('body > div > table.cajasombra > tbody > tr > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(1)').text)
        dict_id['distrito'] = driver.find_element_by_css_selector('body > div > table.cajasombra > tbody > tr > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(3)').text
        dict_id['curul'] = driver.find_element_by_css_selector('body > div > table.cajasombra > tbody > tr > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(5)').text
        dict_id['suplente_propietario'] = 'P'
        dict_id['name_suplente'] = suplente_propietario
        dict_id['partido'] = mapping_parties[name]
        dict_id['link_curricula'] = link
        
        
        dict_sup = {}
        dict_sup['legislatura'] = 64
        dict_sup['id_legislador'] = str(uuid.uuid1())
        dict_sup['nombre_completo'] = suplente_propietario
        dict_sup['tipo_legislador'] = unidecode.unidecode(driver.find_element_by_css_selector('body > div > table.cajasombra > tbody > tr > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(2) > td:nth-child(2) > strong').text)
        dict_sup['entidad'] = unidecode.unidecode(driver.find_element_by_css_selector('body > div > table.cajasombra > tbody > tr > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(1)').text)
        dict_sup['distrito'] = driver.find_element_by_css_selector('body > div > table.cajasombra > tbody > tr > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(3)').text
        dict_sup['curul'] = driver.find_element_by_css_selector('body > div > table.cajasombra > tbody > tr > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(5)').text
        dict_sup['suplente_propietario'] = 'S'
        dict_sup['name_suplente'] = ''
        dict_sup['partido'] = mapping_parties[name]
        dict_sup['link_curricula'] = link
        return([dict_id, dict_sup])

# %%
def obtain_id_data63(name, mapping_parties, link):
    suplente_propietario = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(6) > td:nth-child(2) > strong > font').text
    if any(re.findall('ficha curricular', suplente_propietario)):
        dict_prop = {}
        dict_prop['legislatura'] = 63
        dict_prop['id_legislador'] = str(uuid.uuid1())
        dict_prop['nombre_completo'] = re.sub('[ ]+$', '', re.sub('[(]ficha curricular[)]', '', suplente_propietario))
        dict_prop['tipo_legislador'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(2) > td:nth-child(2) > strong > font').text
        dict_prop['entidad'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(1) > font').text
        dict_prop['distrito'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(4) > font').text
        dict_prop['curul'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(7) > font').text
        dict_prop['suplente_propietario'] = 'P'
        dict_prop['name_suplente'] = name
        dict_prop['partido'] = mapping_parties[name]
        dict_prop['link_curricula'] = link
        
        
        dict_sup = {}
        dict_sup['legislatura'] = 63
        dict_sup['id_legislador'] = str(uuid.uuid1())
        dict_sup['nombre_completo'] = name
        dict_sup['tipo_legislador'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(2) > td:nth-child(2) > strong > font').text
        dict_sup['entidad'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(1) > font').text
        dict_sup['distrito'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(4) > font').text
        dict_sup['curul'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(7) > font').text
        dict_sup['suplente_propietario'] = 'S'
        dict_sup['name_suplente'] = ''
        dict_sup['partido'] = mapping_parties[name]
        dict_sup['link_curricula'] = link
        return([dict_prop, dict_sup])
    else:
    
        dict_prop = {}
        dict_prop['legislatura'] = 63
        dict_prop['id_legislador'] = str(uuid.uuid1())
        dict_prop['nombre_completo'] = name
        dict_prop['tipo_legislador'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(2) > td:nth-child(2) > strong > font').text
        dict_prop['entidad'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(1) > font').text
        dict_prop['distrito'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(4) > font').text
        dict_prop['curul'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(7) > font').text
        dict_prop['suplente_propietario'] = 'P'
        dict_prop['name_suplente'] = suplente_propietario
        dict_prop['partido'] = mapping_parties[name]
        dict_prop['link_curricula'] = link
        
        
        dict_sup = {}
        dict_sup['legislatura'] = 63
        dict_sup['id_legislador'] = str(uuid.uuid1())
        dict_sup['nombre_completo'] = suplente_propietario
        dict_sup['tipo_legislador'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(2) > td:nth-child(2) > strong > font').text
        dict_sup['entidad'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(1) > font').text
        dict_sup['distrito'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(4) > font').text
        dict_sup['curul'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(7) > font').text
        dict_sup['suplente_propietario'] = 'S'
        dict_sup['name_suplente'] = ''
        dict_sup['partido'] = mapping_parties[name]
        dict_sup['link_curricula'] = link
        
        return([dict_prop, dict_sup])

# %% [markdown]
# ## ID Data

# %%
data_id64 = []
for x, y in tqdm(zip(links_diputados, names_diputados), total = len(names_diputados)):
    driver.get(x)
    dicts = obtain_id_data(y, mapping_name_party, x)
    for j in dicts:
        data_id64.append(j)
# Out:
# 100%|██████████| 500/500 [09:48<00:00,  1.18s/it]

# %%
with open('/Users/cblanesg/cam.blanes Dropbox/Camila Blanes/floor-speechMX/data/diputados/id_data/legislatura64.json', 'w') as json_file:
    json.dump(data_id64, json_file)

# %%
names = []
for i in data_id64:
    if i['nombre_completo'].lower() not in names:
        names.append(i['nombre_completo'].lower())

# %%
names
# Out:
# ['aguilar castillo heriberto marcelo',
#  'ramon angel valdez mendoza',
#  'aguilar linda bonifacio',
#  'feliciano romero martinez',
#  'aguilar molina leticia arlett',
#  'liliana garcia albores',
#  'aguilera brenes sebastián',
#  'jorge ariff marave sanchez',
#  'aguilera chairez maribel',
#  'martha alicia arreola martinez',
#  'alfonso ramirez cuellar',
#  'aguirre valenciana javier uriel',
#  'alavez ruiz aleida',
#  'maria concepcion franco rodriguez',
#  'alegre salazar luis javier',
#  'wilbert alberto batun chulim',
#  'alejandro candelaria maximino',
#  'luis alfredo ortiz pantoja',
#  'alfaro morales maría isabel',
#  'ma. guadalupe loredo gonzales',
#  'almazán burgos karla yuritzi',
#  'maria imelda agustina yescas ruiz',
#  'alvarado moreno maría guillermina',
#  'rebeca lidia garcia vallejo',
#  'ambrocio gachuz josé guadalupe',
#  'oscar mejia garcia',
#  'andazola gómez socorro irma',
#  'carlota lara guzman',
#  'andrade zavala marco antonio',
#  'daniel castillo de la cruz',
#  'angeles mendoza julio césar',
#  'luis eduardo duran garcia',
#  'antonio altamirano carol',
#  'rigoberto quecha molina',
#  'javier julian castaneda pomposo',
#  'areizaga uribe erwin jorge',
#  'pedro mario zenteno santaella',
#  'arenas madrigal edgar eduardo',
#  'arrieta sánchez eleuterio',
#  'ramon pino mendez',
#  'arvizu de la luz felipe rafael',
#  'pedro antonio vera flores',
#  'ascencio ortega reyna celeste',
#  'carolina rangel gracida',
#  'flor ivone morales miranda',
#  'audiffred fernández karen ivette',
#  'avalos magaña laura patricia',
#  'maria luisa somellera corrales',
#  'avila vera mildred concepción',
#  'ruby marivel canto rosado',
#  'jose jaime montes salas',
#  'ayala bobadilla carlos iván',
#  'badillo moreno cuauhtli fernando',
#  'rene rogelio mantecon salas',
#  'bahena jiménez socorro',
#  'eugenia flores fuentes',
#  'barajas barajas esteban',
#  'indalecio cortes gamez',
#  'barrera badillo rocío',
#  'maria martha garcia flores',
#  'bautista bravo juan angel',
#  'jose guadalupe gonzalez vargas',
#  'bautista peláez maria del carmen',
#  'yesenia rios ruiz',
#  'bautista rivera david',
#  'benjamin garcia vazquez',
#  'indira vizcaino silva',
#  'bayardo cabrera rosa maría',
#  'blas lópez víctor',
#  'jorge cruz melendez',
#  'zoe alejandro robledo aburto',
#  'bonifaz moedano raúl eduardo',
#  'bonilla herrera raquel',
#  'maria guadalupe bello trejo',
#  'borrego adame francisco javier',
#  'jorge arturo valdes flores',
#  'briceño zuloaga maría wendy',
#  'lilian margarita navarro lucero',
#  'burelo cortazar teresa',
#  'maria reyna rangel izquierdo',
#  'calderón salas rodrigo',
#  'enrique capetillo gonzalez',
#  'cipriano charrez pedraza',
#  'callejas romero gustavo',
#  'campos equihua ignacio benjamín',
#  'jorge alberto mendoza reyes',
#  'cano gonzález susana',
#  'maria guadalupe roldan gonzalez',
#  'carbajal miranda marco antonio',
#  'j. felix vargas aldiano',
#  'carranza aréas julio',
#  'carlos alberto vega celorio',
#  'carrasco godínez nelly minerva',
#  'rosario cruz salinas',
#  'carrazco macías olegaria',
#  'amalia garcia martinez',
#  'carrillo luna juana',
#  'talia del carmen vazquez alatorre',
#  'carvajal hidalgo alejandro',
#  'iztac hernandez quiterio',
#  'castañeda ortiz maría guadalupe edith',
#  'viridiana rojas portuguez',
#  'castillo lozano katia alejandra',
#  'telma artemisa montano navarro',
#  'cayetano garcía rubén',
#  'gregorio ruano alcaraz',
#  'cazarez yañez martina',
#  'rosario guadalupe saenz alvizo',
#  'chávez pérez maría',
#  'ana santillan mendez',
#  'chico herrera miguel ángel',
#  'jose javier aguirre gallardo',
#  'clouthier carrillo tatiana',
#  'maria del carmen almeida navarro',
#  'contreras castillo armando',
#  'luis alberto sosa castillo',
#  'contreras montes gustavo',
#  'guillermo diaz gonzalez flores',
#  'cruz santos flora tania',
#  'celica segura toledo',
#  'cuaxiloa serrano susana beatriz',
#  'maria esther gonzalez avendano',
#  'cuevas barron gabriela',
#  'brenda estefan martinez',
#  'de jesús jiménez lucio',
#  'juan manuel hernandez cruz',
#  'de la cruz delucio patricia del carmen',
#  'yendi nayeli hernandez solorzano',
#  'del bosque villarreal diego eduardo',
#  'raul steel ramirez garza',
#  'del castillo ibarra erika vanessa',
#  'veronica bustamante martinez',
#  'delgado carrillo mario',
#  'oscar eugenio gutierrez camacho',
#  'delsol estrada josé ricardo',
#  'antolin guerrero marquez',
#  'díaz aguilar leticia',
#  'ana lilia flores galindo',
#  'miroslava carrillo martinez',
#  'díaz avilez maría guadalupe',
#  'diaz garcía maría elizabeth',
#  'gabriela hernandez cruz',
#  'domínguez flores rosalinda',
#  'maria antonia pineda ruiz',
#  'domínguez rodríguez roberto ángel',
#  'pedro eduardo pineda delgado',
#  'elizondo garrido francisco',
#  'arturo arroyo navarrete',
#  'elorza flores josé luis',
#  'jose alberto de sancristobal leon',
#  'espadas méndez gregorio efraín',
#  'roberto calix marin',
#  'espinosa de los monteros garcía adriana maría guadalupe',
#  'mariela santos rojo',
#  'espinoza lopez brenda',
#  'rocio carolina pozos ponce',
#  'espinoza segura maría bertha',
#  'santa veronica marquez dominguez',
#  'exsome zapata ricardo francisco',
#  'francisco javier lorenzo cabrera',
#  'farías zambrano melba nelia',
#  'angelica ledesma mesta',
#  'farrera esponda juan enrique',
#  'alvaro chanona borges',
#  'fernández cruz nayeli arlen',
#  'veronica guadalupe brunt gonzalez',
#  'flores anguiano feliciano',
#  'humberto soberano ramirez',
#  'flores olivo lucía',
#  'gisela barrera badillo',
#  'garcía anaya lidia',
#  'maria de la luz rubio gonzalez',
#  'garcía cayetano dorheny',
#  'clementina salazar cruz',
#  'garcía corpus teófilo manuel',
#  'luis octavio murat macias',
#  'garcía guardado ma. de jesús',
#  'ma. guadalupe adabache reyes',
#  'garcía rosales edith',
#  'susana lili marquez pineda',
#  'garcía rubio agustín',
#  'gustavo arciga torres',
#  'garcía soto ulises',
#  'cesar omar pena ibarbol',
#  'garcía vidaña martha olivia',
#  'maria ernestina sarmiento guevara',
#  'garcía zepeda julieta',
#  'isaina sarahi renteria infante',
#  'gómez ventura manuel',
#  'raul athie cisneros',
#  'gómez álvarez pablo',
#  'sandino luna almeida',
#  'gonzález castañeda sandra paola',
#  'perla elizabeth carrizales cardenas',
#  'gonzález reyes marco antonio',
#  'raul diaz jimenez',
#  'gonzález robledo erasmo',
#  'juan dionisio cruz guerrero',
#  'humberto pedrero moreno',
#  'gordillo moreno alfredo antonio',
#  'guerra mena juanita',
#  'erika hernandez gordillo',
#  'guerra méndez lizeth amayrani',
#  'velia laura landeros garcia',
#  'xochitl nashielly zagal ramirez',
#  'guerra navarro laura mónica',
#  'guerrero barrera yolanda',
#  'giselle garcia ibarra',
#  'guillén quiroz ana lilia',
#  'ruth yolotli manriquez lopez',
#  'gutiérrez gutiérrez daniel',
#  'azael jacinto garcia',
#  'horacio duarte olivares',
#  'gutiérrez luna sergio carlos',
#  'guzmán de la torre francisco javier',
#  'neri eduardo maciel hernandez',
#  'hernández pérez césar agustín',
#  'juan gabriel mendez gonzalez',
#  'hernández pérez maría eugenia',
#  'natalia benitez torres',
#  'hernández tapia arturo roberto',
#  'felipe vidal gomez',
#  'hernández villalpando rafael',
#  'guillermo fernandez sanchez',
#  'herrera chávez samuel',
#  'rumaldo ortiz herrera',
#  'herrera pérez gonzalo',
#  'miguel angel cuin simon',
#  'hidalgo ponce javier ariel',
#  'luis daniel reyes amezaga',
#  'huerta corona benjamín saúl',
#  'mario enrique aguilar caldelas',
#  'huerta gonzález agustín reynaldo',
#  'juan pablo gonzalez lima',
#  'huerta del río maría de los ángeles',
#  'korina angelica esquinca gonzalez',
#  'roger herve (deceso) aguilar salazar',
#  'interian gallegos limbert iván de jesús',
#  'jarero velázquez miguel pavel',
#  'francisco jimenez lopez',
#  'jáuregui montes de oca miguel ángel',
#  'gerardo vallejo rodriguez',
#  'jiménez andrade lorena del socorro',
#  'ma. esperanza ortiz rodriguez',
#  'jiménez y meneses héctor guillermo de jesús',
#  'julian pena hidalgo',
#  'juan carlos irma',
#  'maria fernanda barbosa sosa',
#  'lamarque cano carlos javier',
#  'fernando gonzalez meza',
#  'lópez aparicio delfino',
#  'silvestre lopez cornejo',
#  'lópez castillo manuel',
#  'esteban cabrera meda',
#  'lópez chávez maria beatriz',
#  'mercedes sanchez garcia',
#  'lópez pérez maría teresa',
#  'leticia perez rodriguez',
#  'lópez rayón claudia',
#  'gabriela romero martinez',
#  'lópez rodríguez abelina',
#  'leticia lozano zavala',
#  'maldonado tapia mirna zabeida',
#  'amalia roman longoria',
#  'manzano salazar javier',
#  'fredy de jesus castro guevara',
#  'márquez gonzález miguel ángel',
#  'jose manuel martin gomez',
#  'martínez aguilar emeteria claudia',
#  'damaris del rocio vera lara',
#  'martínez aké carlos enrique',
#  'daniel jesus gomez vargas',
#  'martínez flores juan',
#  'jose ignacio vazquez sanchez',
#  'martínez gonzález laura',
#  'maria hilda penaloza martinez',
#  'maya martínez hirepan',
#  'miguel angel sandoval rodriguez',
#  'mayer bretón sergio',
#  'oscar bernache dominguez',
#  'medel palma carmen',
#  'mariela hernandez garcia',
#  'medina pérez marco antonio',
#  'genaro ibanez martinez',
#  'mejía cruz maria esther',
#  'elizabeth guzman argueta',
#  'mercado torres edith marisol',
#  'yuridia elizabeth castillo correa',
#  'merino garcía virginia',
#  '--- --- ---',
#  'merlín garcía maría del rosario',
#  'joaquina hernandez aguero',
#  'mier velazco moisés ignacio',
#  'jose alfonso suarez del real y aguilera',
#  'minor mora jesús salvador',
#  'juan melendrez espinoza',
#  'mojica toledo alejandro',
#  'omar alfonso barrera hernandez',
#  'mojica wences víctor adolfo',
#  'mario hector mojica escalante',
#  'molina espinoza irineo',
#  'jorge luis estrada rodriguez',
#  'alma marina vitela rodriguez',
#  'montes hernández maría de lourdes',
#  'montes nieves jorge luis',
#  'rogelio resendiz acevedo',
#  'mora garcía carmen',
#  'maria laura garcia gomez',
#  'mora ríos maría teresa rebeca rosa',
#  'juana berenice montoya marquez',
#  'morales elvira erik isaac',
#  'armando teran corella',
#  'moreno gil mario ismael',
#  'luis javier algorri franco',
#  'murguía soto ulises',
#  'jose daniel alfonso hernandez ramirez',
#  'muñoz ledo porfirio',
#  'jose agustin ortiz pinchetti',
#  'navarrete rivera alma delia',
#  'teresa escobar briones',
#  'marina del pilar avila olmeda',
#  'noriega galaz martha lizeth',
#  'novella macías oscar rafael',
#  'hugo adrian felix pichardo',
#  'núñez alvarez estela',
#  'dolores del carmen zubieta ruiz',
#  'obrador narváez manuela del carmen',
#  'rebeca arcos sanchez',
#  'ocampo manzanares araceli',
#  'elizabeth figueroa elguera',
#  'ochoa valdivia zaira',
#  'martha rosa morales romero',
#  'olvera bautista simey',
#  'carina lopez ayala',
#  'onofre vázquez vicente alberto',
#  'gabriel torres duenas',
#  'orihuela nava david',
#  'nivardo torres siles',
#  'ortega nájera hilda patricia',
#  'lidia beatriz herrera romero',
#  'padierna luna dolores',
#  'montserrat navarro perez',
#  'palacios cordero lucio ernesto',
#  'jose alejandro esquivel diaz',
#  'palma olvera carmen patricia',
#  'erika edith lopez lara',
#  'pani barragán alejandra',
#  'esmeralda flores carranza',
#  'parra juárez inés',
#  'maria isabel torres bravo',
#  'peralta de la peña ana patricia',
#  'paola de la concepcion palma vazquez',
#  'jose guillermo arechiga santamaria',
#  'pérez arroyo alfonso',
#  'pérez bernabe jaime humberto',
#  'ricardo cabanas vazquez',
#  'pérez hernández sergio',
#  'ventura garcia hernandez',
#  'pérez lópez beatriz dominga',
#  'virginia merino garcia',
#  'pérez mackintosh miriam citlally',
#  'claudia ramona moreno salas',
#  'lorena cuellar cisneros',
#  'pérez rodríguez claudia',
#  'pérez segura laura imelda',
#  'socorro lopez martinez',
#  'pérez negrón ruiz iván arturo',
#  'jose misael lopez diaz',
#  'piña bernal adela',
#  'esther giles morales',
#  'ponce cobos alejandro',
#  'jose amador izundegui ordonez',
#  'ponce méndez maría geraldine',
#  'africa azucena sanchez hernandez',
#  'prado de los santos miguel',
#  'gonzalo de jesus moguel rincon',
#  'adriana aguilar vazquez',
#  'quiroz rodríguez maría del carmen',
#  'rabelo velasco roque luis',
#  'fidencio castanon reyes',
#  'ramírez lucero martha patricia',
#  'izhaleth ireri angulo castaneda',
#  'ramírez navarrete francisco javier',
#  'isaias gomez vences',
#  'ramos cruz verónica',
#  'rosa maria cardona alegria',
#  'ramos ruiz juan israel',
#  'jaime fernando guerrero gonzalez',
#  'ramos sotelo guadalupe',
#  'lucero ramirez ramirez',
#  'regalado mardueño carmina yadira',
#  'maria de jesus aguirre barradas',
#  'reyes carmona emmanuel',
#  'ramiro zaragoza ramirez',
#  'reyes colín marco antonio',
#  'adrian estrada arriaga',
#  'reyes lópez valentín',
#  'abel maza dominguez',
#  'reyes miguel idalia',
#  'nachelli soria morales',
#  'ríos fararoni eulalio juan',
#  'hermilo arista bonilla',
#  'rivera castillo fortunato',
#  'gelacio velazquez hernandez',
#  'robles gutiérrez beatriz silvia',
#  'adelina alcantara plata',
#  'robles ortiz martha',
#  'gabriela guadalupe martinez maldonado',
#  'rocha vega efraín',
#  'jorge valdez anaya',
#  'rodríguez arellano ediltrudis',
#  'cecileyvis perez portela',
#  'rodríguez gonzález manuel',
#  'luis arcadio gutierrez leon',
#  'rodríguez ruiz ana maría',
#  'maria del rosario rojas martinez',
#  'rojas martínez beatriz',
#  'erika nayat montes casillas',
#  'román ávila maría guadalupe',
#  'katia gonzalez hernandez',
#  'rosas martínez luz estefanía',
#  'gabriela scarlett perez perez',
#  'rosas uribe erika mariana',
#  'mariana cosio valdes',
#  'ruiz lustre hugo rafael',
#  'alejandro canek vazquez gongora',
#  'salazar fernández luis fernando',
#  'ulises guadalupe hernandez torres',
#  'salinas narváez javier',
#  'efrain garcia becerra',
#  'sánchez barrios carlos',
#  'bulmaro muniz olmedo',
#  'sánchez castro anita',
#  'maria de jesus juarez garcia',
#  'sánchez galván miroslava',
#  'edna laura huerta ruiz',
#  'sánchez ortiz graciela',
#  'brenda anahi garcia diaz',
#  'sánchez rodríguez juan pablo',
#  'luis miguel rodriguez hernandez',
#  'sandoval soberanes lucinda',
#  'damaris osuna zavala',
#  'santiago chepi azael',
#  'joel javier nicolas',
#  'santiago manuel iran',
#  'francisco salinas bautista',
#  'santiago marcos nancy yadira',
#  'guadalupe raquel de la paz aguirre',
#  'santos díaz edelmiro santiago',
#  'jose antonio leal doria',
#  'ciro sales ruiz',
#  'sibaja mendoza jorge ángel',
#  'solís barrera maría marivel',
#  'tellez infante jannet',
#  'flora cervantes reyes',
#  'tello espinosa claudia',
#  'tenorio adame paola',
#  'andrea doria ortiz aguirre',
#  'terán águila rubén',
#  'luis antonio herrera perez',
#  'torres piña carlos',
#  'alejandro mendoza olvera',
#  'valencia cruz rosalba',
#  'alma valdivieso medina',
#  'valles sampedro lorenia iveth',
#  'marina gomez sanchez',
#  'varela lópez víctor gabriel',
#  'salvador montes villalba',
#  'vargas hernández lidia nallely',
#  'alejandra ramirez rodriguez',
#  'vargas meraz teresita de jesús',
#  'yalia naharai romero chavez',
#  'vazquez vazquez alfredo',
#  'manuel torres hernandez',
#  'veloz silva maría luisa',
#  'adela celeste arthur vivanco',
#  'vences valencia julieta kristal',
#  'marisol prieto avendano',
#  'viedma velázquez alejandro',
#  'emilio acosta martinez',
#  'villa villegas alberto',
#  'ismael miranda ornelas',
#  'villalvazo amaya mirtha iliana',
#  'anabel margarita guerrero benitez',
#  'villarauz martínez rocío del pilar',
#  'juan carlos loera de la rosa',
#  'villarreal pasaret francisco jorge',
#  'villavicencio ayala silvia lorena',
#  'alicia torres san juan',
#  'villegas guarneros dulce maría corina',
#  'nury yareli aguilar morales',
#  'villegas sánchez merary',
#  'ana alicia cervantes contreras',
#  'yáñez centeno y cabrera claudia valeria',
#  'sara rizzo garcia',
#  'zamora valdez casimiro',
#  'jose de jesus pacheco ruiz',
#  'zavaleta sánchez graciela',
#  'concepcion sanchez bartolo',
#  'adame castillo marco antonio',
#  'andres diaz larios',
#  'aguilar vega marcos',
#  'jorge luis alarcon neve',
#  'alemán hernández nohemí',
#  'priscilla haydee lagunas cuellar',
#  'arriaga rojas justino eugenio',
#  'cesar raymundo gomez garcia',
#  'ascencio barba sergio fernando',
#  'ricardo andres herrejon catala',
#  'ayala díaz ma. de los ángeles',
#  'blanca marcia chacon hernandez',
#  'azuara zúñiga xavier',
#  'adrian sanchez ramiro',
#  'bonnafoux alcaraz madeleine',
#  'brenda lizeth cordova buzani',
#  'cambero pérez josé ramón',
#  'fernando jesus sanchez zatarain',
#  'carreón mejía carlos',
#  'raymundo bolanos azocar',
#  'castaños valenzuela carlos humberto',
#  'jose de jesus rojas rivera',
#  'juan carlos munoz marquez',
#  'cinta rodríguez carlos elhier',
#  'dávila fernández adriana',
#  'bibian eunice ordaz llanes',
#  'díaz jiménez antonia natividad',
#  'laura leticia mendez reyes',
#  'espadas galván jorge arturo',
#  'marco antonio hernandez arellano',
#  'espinosa rivas ma. eugenia leticia',
#  'guadalupe monserrat mendoza cano',
#  'flores suárez ricardo',
#  'julio cesar alvarado mendoza',
#  'garcía escalante ricardo',
#  'alvaro soto martinez',
#  'garcía gómez martha elena',
#  'mayela leonila godinez alarcon',
#  'garcía morlan dulce alejandra',
#  'irasema aquino gonzalez',
#  'garcía ochoa absalón',
#  'francisco perales jacobo',
#  'garcía rojas mariana dunyaska',
#  'ana gabriela pantoja andrade',
#  'garfias cedillo sylvia violeta',
#  'maria fernanda de la torre delgado',
#  'garza galván silvia guadalupe',
#  'concepcion balderas y robles',
#  'gómez cárdenas annia sarahí',
#  'alejandra soria gutierrez',
#  'gómez quej josé del carmen',
#  'mario enrique pacheco ceballos',
#  'gonzález estrada martha elisa',
#  'claudia patricia torres lopez',
#  'gonzález márquez karen michel',
#  'lucia mendez navarro',
#  'gracia guzmán raúl',
#  'tomas david macias canales',
#  'guerra villarreal isabel margarita',
#  'cecilia sofia robledo suarez',
#  'gutiérrez valdez maría de los angeles',
#  'sinai del rocio sanchez huerta',
#  'guzmán avilés jesús',
#  'armando fernandez de la cruz',
#  'guzmán avilés maría del rosario',
#  'noelia garcia escalante',
#  'lixa abimerhi josé elías',
#  'mario enmanuel aragon castillo',
#  'lópez birlain ana paola',
#  'gabriela castro jasso',
#  'lópez cisneros josé martín',
#  'juan martin garcia marquez',
#  'luévano núñez francisco javier',
#  'gustavo armendariz viramontes',
#  'macías olvera felipe fernando',
#  'raul jaime perez',
#  'mares aguilar josé rigoberto',
#  'armando fidel castro trasvina',
#  'martínez juárez jacquelina',
#  'soledad barrios venegas',
#  'martínez terrazas oscar daniel',
#  'angelo gutierrez hernandez',
#  'mata carrasco mario',
#  'luis carlos gonzalez nunez',
#  'mata lozano lizbeth',
#  'monica janette palomarez ching',
#  'mendoza acevedo luis alberto',
#  'victor manuel mendoza acevedo',
#  'murillo chávez janet melanie',
#  'susana bermudez cano',
#  'núñez cerón sarai',
#  'maria eugenia mosqueda nieto',
#  'ortega martínez ma. del pilar',
#  'adriana alejandra del rio hinojosa',
#  'patrón laviada cecilia anunciación',
#  'maria cristina castillo espinosa',
#  'pérez díaz víctor manuel',
#  'eugenio bueno lozano',
#  'preciado rodríguez jorge luis',
#  'oscar carlos zurroza barrera',
#  'ramírez barba éctor jaime',
#  'ismael sanchez hernandez',
#  'ramos tamez mario alberto',
#  'juan alejandro rivera torres',
#  'riggs baeza miguel alonso',
#  'jaime ricardo fernandez horcasitas',
#  'rivera hernández marcelino',
#  'juan marcos garcia hernandez',
#  'robledo leal ernesto alfonso',
#  'rafael alejandro serna vega',
#  'rocha acosta sonia',
#  'gricelda otero hernandez',
#  'rodríguez rivera iván arturo',
#  'mario manuel sanchez villafuerte',
#  'rojas hernández laura angélica',
#  'beatriz balanzar sanchez',
#  'romero herrera jorge',
#  'mario enrique sanchez flores',
#  'romero hicks juan carlos',
#  'jose ricardo narvaez martinez',
#  'romero león gloria',
#  'gloria isabel vite cruz',
#  'romo cuéllar martha estela',
#  'maria del refugio oros reyes',
#  'romo romo guadalupe',
#  'marco antonio isaac gonzalez',
#  'rosas quintanilla josé salvador',
#  'manuel canales bermea',
#  'ruffo appel ernesto guillermo',
#  'victor ivan lujano sarabia',
#  'salazar báez josefina',
#  'zaira rivera hervert',
#  'salinas wolberg hernán',
#  'jorge alberto arrambide montemayor',
#  'sandoval mendoza maría liduvina',
#  'elena gabriela ocon corona',
#  'sobrado rodríguez verónica maría',
#  'yolanda rodriguez de jesus',
#  'tejeda cid armando',
#  'j. jesus mendoza torres',
#  'terrazas baca patricia',
#  'perla paola adame torres',
#  'torres graciano fernando',
#  'edgardo chaire chavero',
#  'torres peimbert maría marcela',
#  'maria fernanda gatica garza',
#  'torres ramírez adolfo',
#  'armando aviles garcia',
#  'trejo reyes josé isabel',
#  'gabriel rodriguez medina',
#  'valenzuela gonzález carlos alberto',
#  'jose ricardo medina hernandez',
#  'verastegui ostos vicente javier',
#  'eloy martinez carrizales',
#  'villarreal garcía ricardo',
#  'osvaldo garcia arteaga',
#  'acosta peña brasil alberto',
#  'santiago alberto ruiz francisco',
#  'aguilar castillo ricardo',
#  'rogelio enrique valdez valdez',
#  'alcántara núñez jesús sergio',
#  'fernando danel villareal',
#  'alemán muñoz castillo maría',
#  'sonia martha lopez villarreal',
#  'alonzo morales maría ester',
#  'guadalupe elizabeth zapata gonzalez',
#  'álvarez garcía ivonne liliana',
#  'rosa elia morales tijerina',
#  'angulo briceño pablo guillermo',
#  'vicente exiquio cruz ramirez',
#  'azuara yarzábal frinné',
#  'eugenia guadalupe aboytes gonzalez',
#  'barrera fortoul laura',
#  'brenda liz palomares mendez',
#  'bautista villegas oscar',
#  'rodolfo isaac monsivais morquecho',
#  'campos córdova lenin nelson',
#  'ramiro miguel hernandez',
#  'canul pérez juan josé',
#  'wilberth antonio cach yah',
#  'córdova morán luis eleusis leónidas',
#  'eduardo zarate salgado',
#  'de las fuentes hernández fernando donato',
#  'sergio armando sisbeles alvarado',
#  'espinoza eguia juan francisco',
#  'jesus guillermo aguilar gonzalez',
#  'flores sánchez margarita',
#  'miriam del sol merino cuevas',
#  'galindo favela fernando',
#  'luis madrazo lajous',
#  'garay cadena martha hortencia',
#  'cynthia del carmen molano serna',
#  'gonzález cuevas isaías',
#  'jose david alfaro pagaza',
#  'guel saldívar norma',
#  'lily fabiola de la rosa cortes',
#  'hernández deras ismael alfredo',
#  'cristopher daniel james barousse',
#  'herrera anzaldo ana lilia',
#  'laura isabel hernandez pichardo',
#  'ingram vallines anilú',
#  'mayusa isolina gonzalez cauich',
#  'juárez cisneros rene',
#  'paul ospital carrera',
#  'limón hernández manuel',
#  'jose julio espinosa morales',
#  'lópez castro cynthia iliana',
#  'jessica camarero morales',
#  'medina herrera benito',
#  'diego aguilar',
#  'miranda nava luis enrique',
#  'paulo cesar juarez segura',
#  'moreira valdez rubén ignacio',
#  'ramon verduzco gonzalez',
#  'nemer alvarez ernesto javier',
#  'oscar jimenez rayon',
#  'noroña quezada hortensia maría luisa',
#  'guadalupe janneth moreno arguelles',
#  'ochoa reza enrique',
#  'fernando elias calles alvarez',
#  'ortiz guarneros juan',
#  'alejandro jesus ceron molina',
#  'pastor badilla claudia',
#  'myrna yvet torres camacho',
#  'pavón campos carlos',
#  'alberto lugo ledesma',
#  'pérez munguía soraya',
#  'paloma alejandra franco lopez',
#  'puente de la mora ximena',
#  'viviana cristal mondragon lazo',
#  'roa sánchez cruz juvenal',
#  'rigoberto lopez rivera',
#  'rocha medina ma. sara',
#  'maria del carmen mata valenzuela',
#  'rodríguez mier y terán mariana',
#  'delia margarita siller zuniga',
#  'saldaña pérez maría lucero',
#  'iris orihuela perez',
#  'sánchez martínez lourdes erika',
#  'reynalda berenice alcalde castro',
#  'sauri riancho dulce maría',
#  'julieta famania ruiz',
#  'treviño villarreal pedro pablo',
#  'sigfrido macias perez',
#  'velasco gonzález marcela guillermina',
#  'ma. dina herrera soto',
#  'villegas arreola alfredo',
#  'ricardo barroso agramont',
#  'yunes landa héctor',
#  'edmundo martinez zaleta',
#  'zarzosa sánchez eduardo',
#  'jesus wenceslao rangel de la o',
#  'abasolo sánchez pedro daniel',
#  'carlos alejandro mendoza alvarez',
#  'barroso chávez alejandro',
#  'paulino olivier montero',
#  'ana gabriela guevara espinoza',
#  'bernal camarena ana laura',
#  'bernal martínez mary carmen',
#  'rosa mayra garcia arellano',
#  'dekker gómez clementina marta',
#  'flor de maria gonzalez perez',
#  'domínguez vázquez claudia angélica',
#  'karla paola peniche rodriguez',
#  'elizondo guerra olga juliana',
#  'zoraida lara cruz',
#  'favela peñuñuri francisco',
#  'apolinar zuniga quijada',
#  'femat bañuelos alfredo',
#  'miguel jaquez salazar',
#  'fernández noroña gerardo',
#  'balfre vargas cortez',
#  'garay ulloa silvano',
#  'garcía duque josé luis',
#  'juan hugo lopez flores',
#  'garcía garcía margarita',
#  'dalia leticia lopez herrera',
#  'garcía grande ana ruth',
#  'yolanda jimenez espinoza',
#  'garcía hernández jesús fernando',
#  'willian demirel salazar serrano',
#  'gonzález morales hildelisa',
#  'rosa carmina ruiz millan',
#  'gonzález soto santiago',
#  'pedro vazquez gonzalez',
#  'gonzález yáñez óscar',
#  'luis osvaldo lopez dotor',
#  'huacus esquivel francisco javier',
#  'genaro maya talavera',
#  'lizeth sanchez garcia',
#  'huerta hernández martha',
#  'huerta martínez manuel',
#  'vicente paul espinosa guadarrama',
#  'jiménez pérez maría roselia',
#  'sonia edith arevalo flores',
#  'lastra muñoz claudia elena',
#  'daniela beatriz cabrera fernandez',
#  'maceda carrera nelly',
#  'carolina gaspar ramirez',
#  'manzanilla téllez emilio',
#  'jose antonio garcia hernandez',
#  'martínez ruiz maribel',
#  'lucy hernandez perez',
#  'martínez ventura luis enrique',
#  'jaime gonzalo vargas alvarez',
#  'marú mejía maría teresa',
#  'maria de lourdes rios garcia',
#  'montalvo luna josé luis',
#  'ivan morales velasco',
#  'maximiliano (deceso) ruiz arias',
#  'osuna medina josé mario',
#  'pérez hernández josé ángel',
#  'jesus gerardo puentes balderas',
#  'porras domínguez alfredo',
#  'marco antonio cesena sandoval',
#  'reyes ledesma armando',
#  'christian hiram dunn fitch',
#  'roblero gordillo maricruz',
#  'gladys mejia rodriguez',
#  'robles montoya benjamín',
#  'gonzalo jesus aquino ramirez',
#  'rodríguez gómez eraclio',
#  'luis armando dominguez prado',
#  'rojo pimentel ana karina',
#  'maribel flores garcia',
#  'rosete maría',
#  'eloisa micaela montano covarrubias',
#  'sánchez barrales zavalza raúl ernesto',
#  'jose francisco lara hernandez',
#  'sandoval flores reginaldo',
#  'serrano cortes héctor',
#  'lauro antonio martinez salas',
#  'sosa salinas josé de la luz',
#  'juan antonio martinez ceron',
#  'toledo gutiérrez mauricio alonso',
#  'benito ocampo olivares',
#  'torres díaz elba lorena',
#  'haydee hernandez munoz',
#  'vázquez garcía dionicia',
#  'elena laura flores martinez',
#  'zertuche zuani armando javier',
#  'fernando lopez gomez',
#  'bravo padilla itzcóatl tonatiuh',
#  'enrique israel medina torres',
#  'cheja alfaro jacobo david',
#  'erick jair miranda hernandez',
#  'contreras gonzález lourdes celenia',
#  'violeta mariana parra garcia',
#  'alberto esquer gutierrez',
#  'del toro pérez higinio',
#  'espinoza cárdenas juan martín',
#  'santiago ledezma orozco',
#  'falomir saenz alan jesús',
#  'eduardo humberto gameros gardea',
#  'garcía lara jorge alcibíades',
#  'diego mejia ibanez',
#  'gómez maldonado maiella martha gabriela',
#  'maricela gonzalez juarez',
#  'gonzález anaya maría libier',
#  'elvia yolanda martinez cosio',
#  'gonzález garcía ana priscila',
#  'maria del refugio alvarado romo',
#  'herrera vega geraldina isabel',
#  'paz rebeca padilla jimenez',
#  'ku escalante kehila abigail',
#  'irma sanchez manzo',
#  'loya hernández fabiola raquel guadalupe',
#  'elsa noemi mayorga ochoa',
#  'lozano mac donald pilar',
#  'maximina gutierrez tavares',
#  'macías rábago julieta',
#  'mariana ivonne breton hernandez',
#  'medina ortíz adriana gabriela',
#  'maria asencion alvarez solis',
#  'méndez de la luz dauzón dulce maría',
#  'mayra angelica amador perez',
#  'prudencio gonzález carmen julia',
#  'irene garcia martinez',
#  'ramírez salcido juan francisco',
#  'humberto ramon jarero cornejo',
#  'rodríguez carrillo mario alberto',
#  'salvador garcia arenas',
#  'rodríguez vázquez ariel',
#  'pedro arredondo munoz',
#  'ron ramos eduardo',
#  'luis enrique vargas diaz',
#  'russo salido jorge eugenio',
#  'jose eduardo esquer escobar',
#  'salinas reyes ruth',
#  'miriam alejandra cedillo conde',
#  'tagle martínez martha',
#  'lucia alejandra puente garcia',
#  'villarreal salazar juan carlos',
#  'jose carlos marroquin gomez',
#  'zamudio macias martha angélica',
#  'michelle estefania murguia puga',
#  'acundo gonzález miguel',
#  'jose francisco esquitin alonso',
#  'argüelles victorero jorge arturo',
#  'alejandro rondin cruz',
#  'báez ruiz claudia',
#  'esther martinez romano',
#  'baldenebro arredondo manuel de jesus',
#  'abraham david mier nogales',
#  'buenfil díaz irasema del carmen',
#  'azalia del carmen kuri garcia',
#  'cabrera lagunas ma. del carmen',
#  'coyolxauhqui soria morales',
#  'calderón medina samuel',
#  'amando embarcadero perez',
#  'cruz aparicio héctor rené',
#  'alfredo rivas aispuro',
#  'de la peña marshall ricardo',
#  'david eduardo leon romero',
#  'garcía aguilar carolina',
#  'karla ivette calva aleman',
#  'garza gutiérrez laura erika de jesús',
#  'febe priscila benavides lozano',
#  'gonzález escoto armando',
#  'juan javier calva hernandez',
#  'guzmán valdéz edgar',
#  'eloy acata martinez',
#  'lozano rodríguez adriana',
#  'erika georgina lara vazquez',
#  'manzanilla prieto fernando luis',
#  'eudoxio morales flores',
#  'moreno medina esmeralda de los angeles',
#  'maria del pilar terron ramirez',
#  'reséndiz hernández nancy claudia',
#  'diana laura zamora orihuela',
#  'saldivar camacho francisco javier',
#  'andres amador navarro',
#  'salvatori bojalil nayeli',
#  'esperanza estela chilaca munoz',
#  'sosa ruíz olga patricia',
#  'alba silvia garcia paredes',
#  'teissier zavala adriana paulina',
#  'isela betzabe zetina molina',
#  'terán villalobos irma maría',
#  'jeanette arrizon marina',
#  'vargas contreras ernesto',
#  'jose rolando benavides mendiola',
#  'villegas gonzález héctor joel',
#  'silvestre resendez munoz',
#  'aguilera rojas josé guadalupe',
#  'marco antonio bastida bastida',
#  'alcalá padilla abril',
#  'susana priscila alvarez hernandez',
#  'almaguer pardo ma. guadalupe',
#  'leticia martinez gomez',
#  'almeida lópez mónica',
#  'karem zobeida vargas pelayo',
#  'bautista rodríguez mónica',
#  'maria isabel monroy garcia',
#  'esparza márquez frida alejandra',
#  'maria guadalupe martinez arias',
#  'garcía gutiérrez raymundo',
#  'jorge casarrubias vazquez',
#  'juárez piña verónica beatriz',
#  'beatriz selene zamora romero',
#  'ortega martínez antonio',
#  'jesus josue hernandez medina',
#  'pool moo jesús de los ángeles',
#  'victor gilberto aguilar espinosa',
#  'reyes montiel claudia',
#  'maria gisela alejandra parra flores',
#  'rodríguez zamora norma azucena',
#  'perla eugenia rodriguez silva',
#  'bugarín cortés lyndiana elizabeth',
#  'ana yajaira felix rivera',
#  'jorge emilio gonzalez martinez',
#  'corona méndez jorge francisco',
#  'escobar y vega arturo',
#  'omar sesai jimenez santos',
#  'beatriz manrique guevara',
#  'espinoza mata zulma',
#  'gallardo cardona josé ricardo',
#  'raul ivan lopez guzman',
#  'gómez alcantar marco antonio',
#  'misael sanchez sanchez',
#  'gómez ordaz leticia mariana',
#  'martha ramirez bravo',
#  'puente salas carlos alberto',
#  'enrique fanjon gonzalez',
#  'rubio montejo roberto antonio',
#  'rogelio rayo martinez',
#  'vidal peniche jesús carlos',
#  'sergio enrrique chale cauich',
#  'villafuerte zavala lilia',
#  'adriana bustos rodriguez',
#  'morales vázquez carlos alberto',
#  'pedro ameth navarro lara',
#  'pérez rivera evaristo lenin',
#  'sergio borja castillo',
#  'riojas martínez ana lucia',
#  'imelda noemi gonzalez barreras']

# %%
mapping_id_cand = {}
for i in data_id:
    mapping_id_cand[i['nombre_completo']] = i['id_legislador']

# %%
pd.DataFrame(data_id).to_csv('/Users/cblanesg/cam.blanes Dropbox/Camila Blanes/floor-speechMX/data/diputados/id_data/id_data.csv', encoding = 'utf-8')

# %%
df_mapping_id_cand = pd.DataFrame()
df_mapping_id_cand['name'] = list(mapping_id_cand.keys())
df_mapping_id_cand['id'] = list(mapping_id_cand.values())

# %%
df_mapping_id_cand.to_csv('/Users/cblanesg/cam.blanes Dropbox/Camila Blanes/floor-speechMX/data/diputados/id_data/mapping_id_incumbent.csv', encoding = 'utf-8')

# %%
import json

# %%
with open('/Users/cblanesg/cam.blanes Dropbox/Camila Blanes/floor-speechMX/data/diputados/id_data/legislatura64.json', 'w') as json_file:
    json.dump(data_id, json_file)

# %% [markdown]
# ## Legislatura 63

# %%
main_url = 'http://sitllxiii.diputados.gob.mx/listado_diputados_gpnp.php?tipot=TOTAL'
driver.get(main_url)

# %%
def obtain_id_data63(name, mapping_parties, link):
    suplente_propietario = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(6) > td:nth-child(2) > strong > font').text
    if any(re.findall('ficha curricular', suplente_propietario)):
        dict_prop = {}
        dict_prop['legislatura'] = 63
        dict_prop['id_legislador'] = str(uuid.uuid1())
        dict_prop['nombre_completo'] = re.sub('[ ]+$', '', re.sub('[(]ficha curricular[)]', '', suplente_propietario))
        dict_prop['tipo_legislador'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(2) > td:nth-child(2) > strong > font').text
        dict_prop['entidad'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(1) > font').text
        dict_prop['distrito'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(4) > font').text
        dict_prop['curul'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(7) > font').text
        dict_prop['suplente_propietario'] = 'P'
        dict_prop['name_suplente'] = name
        dict_prop['partido'] = mapping_parties[name]
        dict_prop['link_curricula'] = link
        
        
        dict_sup = {}
        dict_sup['legislatura'] = 63
        dict_sup['id_legislador'] = str(uuid.uuid1())
        dict_sup['nombre_completo'] = name
        dict_sup['tipo_legislador'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(2) > td:nth-child(2) > strong > font').text
        dict_sup['entidad'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(1) > font').text
        dict_sup['distrito'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(4) > font').text
        dict_sup['curul'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(7) > font').text
        dict_sup['suplente_propietario'] = 'S'
        dict_sup['name_suplente'] = ''
        dict_sup['partido'] = mapping_parties[name]
        dict_sup['link_curricula'] = link
        return([dict_prop, dict_sup])
    else:
    
        dict_prop = {}
        dict_prop['legislatura'] = 63
        dict_prop['id_legislador'] = str(uuid.uuid1())
        dict_prop['nombre_completo'] = name
        dict_prop['tipo_legislador'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(2) > td:nth-child(2) > strong > font').text
        dict_prop['entidad'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(1) > font').text
        dict_prop['distrito'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(4) > font').text
        dict_prop['curul'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(7) > font').text
        dict_prop['suplente_propietario'] = 'P'
        dict_prop['name_suplente'] = suplente_propietario
        dict_prop['partido'] = mapping_parties[name]
        dict_prop['link_curricula'] = link
        
        
        dict_sup = {}
        dict_sup['legislatura'] = 63
        dict_sup['id_legislador'] = str(uuid.uuid1())
        dict_sup['nombre_completo'] = suplente_propietario
        dict_sup['tipo_legislador'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(2) > td:nth-child(2) > strong > font').text
        dict_sup['entidad'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(1) > font').text
        dict_sup['distrito'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(4) > font').text
        dict_sup['curul'] = driver.find_element_by_css_selector('body > table:nth-child(1) > tbody > tr:nth-child(3) > td > table > tbody > tr > td:nth-child(3) > table > tbody > tr:nth-child(3) > td:nth-child(2) > strong:nth-child(7) > font').text
        dict_sup['suplente_propietario'] = 'S'
        dict_sup['name_suplente'] = ''
        dict_sup['partido'] = mapping_parties[name]
        dict_sup['link_curricula'] = link
        
        return([dict_prop, dict_sup])

# %%
links_diputados = []
names_diputados = []
for i in tqdm(driver.find_elements_by_css_selector('a')):
    link = i.get_attribute('href')
    if any(re.findall('curricula', link)):
        links_diputados.append(link)
        names_diputados.append(re.sub('^[0-9]+ ', '', i.text))
        
    else:
        continue
# Out:
# 100%|██████████| 511/511 [00:12<00:00, 40.26it/s]

# %%
mapping_name_party = {}
for i in names_diputados[0:202]:
    mapping_name_party[i] = 'pri'
    
for i in names_diputados[202: 309]:
    mapping_name_party[i] = 'pan'
    
for i in names_diputados[309:360]:
    mapping_name_party[i] = 'prd'
    
for i in names_diputados[360:410]:
    mapping_name_party[i] = 'morena'
    
for i in names_diputados[410:448]:
    mapping_name_party[i] = 'partido verde ecologista'
    
for i in names_diputados[448:469]:
    mapping_name_party[i] = 'movimiento ciudadano'
    
for i in names_diputados[469:472]:
    mapping_name_party[i] = 'alianza'
    
for i in names_diputados[472:483]:
    mapping_name_party[i] = 'encuentro social'

for i in names_diputados[483:]:
    mapping_name_party[i] = 'sin partido'

# %%
len(mapping_name_party)
# Out:
# 500

# %% [markdown]
# ## Legislatura 62

# %%
main_url = 'http://sitllxii.diputados.gob.mx/listado_diputados_gpnp.php?tipot=TOTAL'
driver.get(main_url)

# %%
driver.find_element_by_css_selector('body > table > tbody > tr:nth-child(3) > td > table:nth-child(2) > tbody > tr:nth-child(2) > td:nth-child(2)').text
# Out:
# 'Representación proporcional'

# %%
def obtain_id_data62(name, mapping_parties, link):
    suplente_propietario = driver.find_element_by_css_selector('body > table > tbody > tr:nth-child(3) > td > table:nth-child(2) > tbody > tr:nth-child(7) > td > span').text
    
    tipo_inc = unidecode.unidecode(driver.find_element_by_css_selector('body > table > tbody > tr:nth-child(3) > td > table:nth-child(2) > tbody > tr:nth-child(2) > td:nth-child(2)').text)
    estado = unidecode.unidecode(driver.find_element_by_css_selector('body > table > tbody > tr:nth-child(3) > td > table:nth-child(2) > tbody > tr:nth-child(3) > td:nth-child(2)').text)
    distrito = unidecode.unidecode(driver.find_element_by_css_selector('body > table > tbody > tr:nth-child(3) > td > table:nth-child(2) > tbody > tr:nth-child(4) > td:nth-child(2)').text)
    curul = unidecode.unidecode(driver.find_element_by_css_selector('body > table > tbody > tr:nth-child(3) > td > table:nth-child(2) > tbody > tr:nth-child(6) > td:nth-child(2)').text)
    
    
    if any(re.findall('Suplente de:', suplente_propietario)):
        dict_prop = {}
        dict_prop['legislatura'] = 63
        dict_prop['id_legislador'] = str(uuid.uuid1())
        dict_prop['nombre_completo'] = re.sub('[ ]+$', '', re.sub('Suplente de[:]', '', suplente_propietario))
        dict_prop['tipo_legislador'] = tipo_inc
        dict_prop['entidad'] = estado
        dict_prop['distrito'] = distrito
        dict_prop['curul'] = curul
        dict_prop['suplente_propietario'] = 'P'
        dict_prop['name_suplente'] = name
        dict_prop['partido'] = mapping_parties[name]
        dict_prop['link_curricula'] = link
        
        
        dict_sup = {}
        dict_sup['legislatura'] = 63
        dict_sup['id_legislador'] = str(uuid.uuid1())
        dict_sup['nombre_completo'] = name
        dict_sup['tipo_legislador'] = tipo_inc
        dict_sup['entidad'] = estado
        dict_sup['distrito'] = distrito
        dict_sup['curul'] = curul
        dict_sup['suplente_propietario'] = 'S'
        dict_sup['name_suplente'] = ''
        dict_sup['partido'] = mapping_parties[name]
        dict_sup['link_curricula'] = link
        return([dict_prop, dict_sup])
    else:
    
        dict_prop = {}
        dict_prop['legislatura'] = 63
        dict_prop['id_legislador'] = str(uuid.uuid1())
        dict_prop['nombre_completo'] = name
        dict_prop['tipo_legislador'] = tipo_inc
        dict_prop['entidad'] = estado
        dict_prop['distrito'] = distrito
        dict_prop['curul'] = curul
        dict_prop['suplente_propietario'] = 'P'
        dict_prop['name_suplente'] = re.sub('[ ]+$', '', re.sub('Suplente de[:]', '', suplente_propietario))
        dict_prop['partido'] = mapping_parties[name]
        dict_prop['link_curricula'] = link
        
        
        dict_sup = {}
        dict_sup['legislatura'] = 63
        dict_sup['id_legislador'] = str(uuid.uuid1())
        dict_sup['nombre_completo'] = re.sub('[ ]+$', '', re.sub('Suplente de[:]', '', suplente_propietario))
        dict_sup['tipo_legislador'] = tipo_inc
        dict_sup['entidad'] = estado
        dict_sup['distrito'] = distrito
        dict_sup['curul'] = curul
        dict_sup['suplente_propietario'] = 'S'
        dict_sup['name_suplente'] = ''
        dict_sup['partido'] = mapping_parties[name]
        dict_sup['link_curricula'] = link
        
        return([dict_prop, dict_sup])

# %%
links_diputados = []
names_diputados = []
for i in tqdm(driver.find_elements_by_css_selector('a')):
    link = i.get_attribute('href')
    if any(re.findall('curricula', link)):
        links_diputados.append(link)
        names_diputados.append(re.sub('^[0-9]+ ', '', i.text))
        
    else:
        continue
# Out:
# 100%|██████████| 512/512 [00:08<00:00, 63.38it/s]

# %%
len(names_diputados)
# Out:
# 500

# %%
mapping_name_party = {}
for i in names_diputados[0:214]:
    mapping_name_party[i] = 'pri'
    
for i in names_diputados[214: 327]:
    mapping_name_party[i] = 'pan'
    
for i in names_diputados[327:426]:
    mapping_name_party[i] = 'prd'
    
for i in names_diputados[426:453]:
    mapping_name_party[i] = 'pve'
    
for i in names_diputados[453:465]:
    mapping_name_party[i] = 'mc'
    
for i in names_diputados[465:476]:
    mapping_name_party[i] = 'pt'
    
for i in names_diputados[476:486]:
    mapping_name_party[i] = 'alianza'
    
for i in names_diputados[486:498]:
    mapping_name_party[i] = 'morenal'

for i in names_diputados[498:]:
    mapping_name_party[i] = 'sin partido'

# %%
len(mapping_name_party)
# Out:
# 500

# %%
import unidecode

# %%
data_id62 = []
for x, y in tqdm(zip(links_diputados, names_diputados), total = len(names_diputados)):
    driver.get(x)
    dicts = obtain_id_data62(y, mapping_name_party, x)
    for i in  dicts:
        data_id62.append(i)
# Out:
# 100%|██████████| 500/500 [02:35<00:00,  3.21it/s]

# %%
re.sub('Suplente: ', '', 'Suplente: Luis Fernando Mancilla Fuentes')
# Out:
# 'Luis Fernando Mancilla Fuentes'

# %%
data_id62_clean = []
for i in data_id62:
    i['nombre_completo'] = re.sub('Suplente: ', '', i['nombre_completo'])
    i['name_suplente'] = re.sub('Suplente: ', '', i['name_suplente'])
    data_id62_clean.append(i)

# %%
len(data_id62_clean)
# Out:
# 1000

# %%
with open('/Users/cblanesg/cam.blanes Dropbox/Camila Blanes/Congressional-dataMX/data/00-id_data/id_legislatura62.json', 'w') as json_file:
    json.dump(data_id62_clean, json_file)

# %% [markdown]
# ## Legislatura 61

# %%
main_url = 'http://sitllxi.diputados.gob.mx/listado_diputados_gpnp.php?tipot=TOTAL'
driver.get(main_url)

# %%
links_diputados = []
names_diputados = []
for i in tqdm(driver.find_elements_by_css_selector('a')):
    link = i.get_attribute('href')
    if any(re.findall('curricula', link)):
        links_diputados.append(link)
        names_diputados.append(re.sub('^[0-9]+ ', '', i.text))
        
    else:
        continue
# Out:
# 100%|██████████| 512/512 [00:08<00:00, 57.74it/s]

# %%
len(names_diputados)
# Out:
# 500

# %%
mapping_name_party = {}
for i in names_diputados[0:242]:
    mapping_name_party[i] = 'pri'
    
for i in names_diputados[242: 384]:
    mapping_name_party[i] = 'pan'
    
for i in names_diputados[384:447]:
    mapping_name_party[i] = 'prd'
    
for i in names_diputados[447:469]:
    mapping_name_party[i] = 'pve'
    
for i in names_diputados[469:483]:
    mapping_name_party[i] = 'pt'
    
for i in names_diputados[483:491]:
    mapping_name_party[i] = 'alianza'
    
for i in names_diputados[491:497]:
    mapping_name_party[i] = 'mc'
    
for i in names_diputados[497:]:
    mapping_name_party[i] = 'sin partido'

# %%
len(mapping_name_party)
# Out:
# 500

# %%
import unidecode

# %%
data_id62 = []
for x, y in tqdm(zip(links_diputados, names_diputados), total = len(names_diputados)):
    driver.get(x)
    dicts = obtain_id_data62(y, mapping_name_party, x)
    for i in  dicts:
        data_id62.append(i)
# Out:
# 100%|██████████| 500/500 [02:52<00:00,  2.91it/s]

# %%
data_id62_clean = []
for i in data_id62:
    i['nombre_completo'] = re.sub('Suplente: ', '', i['nombre_completo'])
    i['name_suplente'] = re.sub('Suplente: ', '', i['name_suplente'])
    data_id62_clean.append(i)

len(data_id62_clean)
# Out:
# 1000

# %%
data_id62_clean
# Out:
# [{'legislatura': 63,
#   'id_legislador': 'e9957eae-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Aguero Tovar José Manuel',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Morelos',
#   'distrito': '2',
#   'curul': 'L-445',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Edith Flores Rodríguez',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=179'},
#  {'legislatura': 63,
#   'id_legislador': 'e9957ff8-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Edith Flores Rodríguez',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Morelos',
#   'distrito': '2',
#   'curul': 'L-445',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=179'},
#  {'legislatura': 63,
#   'id_legislador': 'e9d6a474-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Aguilar González José Óscar',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Puebla',
#   'distrito': '4',
#   'curul': 'J-344',
#   'suplente_propietario': 'P',
#   'name_suplente': 'María Eugenia Cabrera Huerta',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=212'},
#  {'legislatura': 63,
#   'id_legislador': 'e9d6a5b4-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'María Eugenia Cabrera Huerta',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Puebla',
#   'distrito': '4',
#   'curul': 'J-344',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=212'},
#  {'legislatura': 63,
#   'id_legislador': 'ea148140-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': ' Angélica del Rosario Araujo Lara',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Yucatan',
#   'distrito': '3',
#   'curul': 'L-433',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Aguilar Góngora Efraín Ernesto',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=794'},
#  {'legislatura': 63,
#   'id_legislador': 'ea14830c-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Aguilar Góngora Efraín Ernesto',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Yucatan',
#   'distrito': '3',
#   'curul': 'L-433',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=794'},
#  {'legislatura': 63,
#   'id_legislador': 'ea4e3390-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': ' Beatríz Elena Paredes Rangel',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Ciudad de Mexico',
#   'distrito': '4',
#   'curul': 'H-264',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Aguilar Álvarez y Mazarrasa Jaime',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=933'},
#  {'legislatura': 63,
#   'id_legislador': 'ea4e3516-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Aguilar Álvarez y Mazarrasa Jaime',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Ciudad de Mexico',
#   'distrito': '4',
#   'curul': 'H-264',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=933'},
#  {'legislatura': 63,
#   'id_legislador': 'ea7fef70-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Aguirre Maldonado Ma. de Jesús (LICENCIA)',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Nuevo Leon',
#   'distrito': '8',
#   'curul': 'H-267',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Patricia Aguirre González',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=193'},
#  {'legislatura': 63,
#   'id_legislador': 'ea7ff13c-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Patricia Aguirre González',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Nuevo Leon',
#   'distrito': '8',
#   'curul': 'H-267',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=193'},
#  {'legislatura': 63,
#   'id_legislador': 'eaac6280-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Aguirre Romero Andrés (LICENCIA)',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Mexico',
#   'distrito': '39',
#   'curul': 'J-366',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Benylu Joana García Rodríguez',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=164'},
#  {'legislatura': 63,
#   'id_legislador': 'eaac651e-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Benylu Joana García Rodríguez',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Mexico',
#   'distrito': '39',
#   'curul': 'J-366',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=164'},
#  {'legislatura': 63,
#   'id_legislador': 'ead7a7ec-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Ahued Bardahuil Ricardo',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Veracruz',
#   'distrito': '10',
#   'curul': 'K-409',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Rosalba Aburto López',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=280'},
#  {'legislatura': 63,
#   'id_legislador': 'ead7a922-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Rosalba Aburto López',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Veracruz',
#   'distrito': '10',
#   'curul': 'K-409',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=280'},
#  {'legislatura': 63,
#   'id_legislador': 'eb07c08a-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Albarrán Mendoza Esteban',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Guerrero',
#   'distrito': '2',
#   'curul': 'L-458',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Omar Jalil Flores Majul',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=92'},
#  {'legislatura': 63,
#   'id_legislador': 'eb07c224-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Omar Jalil Flores Majul',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Guerrero',
#   'distrito': '2',
#   'curul': 'L-458',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=92'},
#  {'legislatura': 63,
#   'id_legislador': 'eb3b4e50-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': ' Felipe Cervera Hernández',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Yucatan',
#   'distrito': '2',
#   'curul': 'L-436',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Alonzo Morales María Ester',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=793'},
#  {'legislatura': 63,
#   'id_legislador': 'eb3b4f68-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Alonzo Morales María Ester',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Yucatan',
#   'distrito': '2',
#   'curul': 'L-436',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=793'},
#  {'legislatura': 63,
#   'id_legislador': 'eb715ec8-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Alvarado Arroyo Fermín Gerardo',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Guerrero',
#   'distrito': '9',
#   'curul': 'M-496',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Óscar Ignacio Rangel Miravete',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=99'},
#  {'legislatura': 63,
#   'id_legislador': 'eb715fea-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Óscar Ignacio Rangel Miravete',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Guerrero',
#   'distrito': '9',
#   'curul': 'M-496',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=99'},
#  {'legislatura': 63,
#   'id_legislador': 'eba5d662-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': ' José Tomás Carrillo Sánchez',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Veracruz',
#   'distrito': '17',
#   'curul': 'K-405',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Álvarez Martínez José Luis',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=787'},
#  {'legislatura': 63,
#   'id_legislador': 'eba5d78e-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Álvarez Martínez José Luis',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Veracruz',
#   'distrito': '17',
#   'curul': 'K-405',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=787'},
#  {'legislatura': 63,
#   'id_legislador': 'ebdb49dc-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Álvarez Santamaría Miguel',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Guerrero',
#   'distrito': '4',
#   'curul': 'M-499',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Elvira Rebeca Arenas Martínez',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=436'},
#  {'legislatura': 63,
#   'id_legislador': 'ebdb4c16-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Elvira Rebeca Arenas Martínez',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Guerrero',
#   'distrito': '4',
#   'curul': 'M-499',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=436'},
#  {'legislatura': 63,
#   'id_legislador': 'ec0e9012-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Ambrosio Cipriano Heriberto',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Oaxaca',
#   'distrito': '4',
#   'curul': 'M-466',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Eva Diego Cruz',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=201'},
#  {'legislatura': 63,
#   'id_legislador': 'ec0e913e-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Eva Diego Cruz',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Oaxaca',
#   'distrito': '4',
#   'curul': 'M-466',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=201'},
#  {'legislatura': 63,
#   'id_legislador': 'ec462400-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Arana Arana Jorge',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Jalisco',
#   'distrito': '7',
#   'curul': 'M-486',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Sugeil Fonseca Gómez',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=113'},
#  {'legislatura': 63,
#   'id_legislador': 'ec46252c-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Sugeil Fonseca Gómez',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Jalisco',
#   'distrito': '7',
#   'curul': 'M-486',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=113'},
#  {'legislatura': 63,
#   'id_legislador': 'ec7ec51c-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': ' Jorge Herrera Caldera',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Durango',
#   'distrito': '4',
#   'curul': 'B-041',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Ávila Nevárez Pedro',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=576'},
#  {'legislatura': 63,
#   'id_legislador': 'ec7ec648-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Ávila Nevárez Pedro',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Durango',
#   'distrito': '4',
#   'curul': 'B-041',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=576'},
#  {'legislatura': 63,
#   'id_legislador': 'ecb9772a-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Aysa Bernat José Antonio',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Tabasco',
#   'distrito': '1',
#   'curul': 'L-440',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Anahí Lastiri Falcón',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=254'},
#  {'legislatura': 63,
#   'id_legislador': 'ecb979d2-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Anahí Lastiri Falcón',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Tabasco',
#   'distrito': '1',
#   'curul': 'L-440',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=254'},
#  {'legislatura': 63,
#   'id_legislador': 'ecee2ba0-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Báez Pinal Armando Jesús',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Ciudad de Mexico',
#   'distrito': '4',
#   'curul': 'M-490',
#   'suplente_propietario': 'P',
#   'name_suplente': 'María del Rosario Elena Guerra Díaz',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=434'},
#  {'legislatura': 63,
#   'id_legislador': 'ecee2ccc-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'María del Rosario Elena Guerra Díaz',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Ciudad de Mexico',
#   'distrito': '4',
#   'curul': 'M-490',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=434'},
#  {'legislatura': 63,
#   'id_legislador': 'ed1f1166-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Bailey Elizondo Eduardo Alonso',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Nuevo Leon',
#   'distrito': '3',
#   'curul': 'M-477',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Maribel Valdez Olivares',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=188'},
#  {'legislatura': 63,
#   'id_legislador': 'ed1f1300-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Maribel Valdez Olivares',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Nuevo Leon',
#   'distrito': '3',
#   'curul': 'M-477',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=188'},
#  {'legislatura': 63,
#   'id_legislador': 'ed512430-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Bautista Concepción Sabino',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'San Luis Potosi',
#   'distrito': '7',
#   'curul': 'J-370',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Ermentina Lara Pérez',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=238'},
#  {'legislatura': 63,
#   'id_legislador': 'ed512552-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Ermentina Lara Pérez',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'San Luis Potosi',
#   'distrito': '7',
#   'curul': 'J-370',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=238'},
#  {'legislatura': 63,
#   'id_legislador': 'ed81c112-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Bellizia Aboaf Nicolás Carlos',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Tabasco',
#   'distrito': '5',
#   'curul': 'L-336',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Elsy del Carmen Magaña Madrigal',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=258'},
#  {'legislatura': 63,
#   'id_legislador': 'ed81c2a2-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Elsy del Carmen Magaña Madrigal',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Tabasco',
#   'distrito': '5',
#   'curul': 'L-336',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=258'},
#  {'legislatura': 63,
#   'id_legislador': 'edb4407e-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Benítez Lucho Antonio',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Veracruz',
#   'distrito': '21',
#   'curul': 'K-407',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Emigdio Heliodoro Enríquez Merlín',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=291'},
#  {'legislatura': 63,
#   'id_legislador': 'edb4425e-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Emigdio Heliodoro Enríquez Merlín',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Veracruz',
#   'distrito': '21',
#   'curul': 'K-407',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=291'},
#  {'legislatura': 63,
#   'id_legislador': 'edeb8c00-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': ' Mario Moreno Arcos',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Guerrero',
#   'distrito': '7',
#   'curul': 'M-498',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Benítez Navarrete María del Socorro',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=597'},
#  {'legislatura': 63,
#   'id_legislador': 'edeb8dcc-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Benítez Navarrete María del Socorro',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Guerrero',
#   'distrito': '7',
#   'curul': 'M-498',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=597'},
#  {'legislatura': 63,
#   'id_legislador': 'ee1df91a-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Benítez Treviño Víctor Humberto',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Mexico',
#   'distrito': '5',
#   'curul': 'F-182',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Norma Silvia López Cano Aveleyra',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=473'},
#  {'legislatura': 63,
#   'id_legislador': 'ee1dfbd6-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Norma Silvia López Cano Aveleyra',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Mexico',
#   'distrito': '5',
#   'curul': 'F-182',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=473'},
#  {'legislatura': 63,
#   'id_legislador': 'ee4f55e6-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Bojórquez Gutiérrez Rolando',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Sinaloa',
#   'distrito': '3',
#   'curul': 'D-102',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Rosa del Carmen Casillas Alvarado',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=241'},
#  {'legislatura': 63,
#   'id_legislador': 'ee4f5726-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Rosa del Carmen Casillas Alvarado',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Sinaloa',
#   'distrito': '3',
#   'curul': 'D-102',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=241'},
#  {'legislatura': 63,
#   'id_legislador': 'ee8194ca-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Borja Texocotitla Felipe',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Mexico',
#   'distrito': '5',
#   'curul': 'G-228',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Flor Orlanda Delgado del Valle',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=130'},
#  {'legislatura': 63,
#   'id_legislador': 'ee819600-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Flor Orlanda Delgado del Valle',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Mexico',
#   'distrito': '5',
#   'curul': 'G-228',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=130'},
#  {'legislatura': 63,
#   'id_legislador': 'eeaf7c96-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Cadena Morales Manuel',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Mexico',
#   'distrito': '38',
#   'curul': 'F-183',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Paola Barrera Mazon',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=163'},
#  {'legislatura': 63,
#   'id_legislador': 'eeaf7db8-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Paola Barrera Mazon',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Mexico',
#   'distrito': '38',
#   'curul': 'F-183',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=163'},
#  {'legislatura': 63,
#   'id_legislador': 'eee2b408-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Callejas Arroyo Juan Nicolás',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Veracruz',
#   'distrito': '3',
#   'curul': 'M-492',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Alicia González Cerecedo',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=396'},
#  {'legislatura': 63,
#   'id_legislador': 'eee2b52a-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Alicia González Cerecedo',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Veracruz',
#   'distrito': '3',
#   'curul': 'M-492',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=396'},
#  {'legislatura': 63,
#   'id_legislador': 'ef18a234-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': ' José Luis Marcos León Perea',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Sonora',
#   'distrito': '4',
#   'curul': 'K-392',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Calles Villegas Patricia',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=750'},
#  {'legislatura': 63,
#   'id_legislador': 'ef18a360-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Calles Villegas Patricia',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Sonora',
#   'distrito': '4',
#   'curul': 'K-392',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=750'},
#  {'legislatura': 63,
#   'id_legislador': 'ef4b1714-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Campos Villegas Luis Carlos',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Chihuahua',
#   'distrito': '9',
#   'curul': 'K-382',
#   'suplente_propietario': 'P',
#   'name_suplente': 'David Balderrama Quintana',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=45'},
#  {'legislatura': 63,
#   'id_legislador': 'ef4b1886-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'David Balderrama Quintana',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Chihuahua',
#   'distrito': '9',
#   'curul': 'K-382',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=45'},
#  {'legislatura': 63,
#   'id_legislador': 'ef80065e-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Cano Ricaud Alejandro',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Chihuahua',
#   'distrito': '8',
#   'curul': 'K-381',
#   'suplente_propietario': 'P',
#   'name_suplente': 'María Adela Soto Martínez',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=44'},
#  {'legislatura': 63,
#   'id_legislador': 'ef800794-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'María Adela Soto Martínez',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Chihuahua',
#   'distrito': '8',
#   'curul': 'K-381',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=44'},
#  {'legislatura': 63,
#   'id_legislador': 'efb8cafc-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Cano Vélez Jesús Alberto',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Sonora',
#   'distrito': '1',
#   'curul': 'K-395',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Iris Fernanda Sánchez Chiu',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=323'},
#  {'legislatura': 63,
#   'id_legislador': 'efb8cc32-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Iris Fernanda Sánchez Chiu',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Sonora',
#   'distrito': '1',
#   'curul': 'K-395',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=323'},
#  {'legislatura': 63,
#   'id_legislador': 'efede714-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': ' Rodolfo Torre Cantú',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Tamaulipas',
#   'distrito': '5',
#   'curul': 'I-301',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Canseco Gómez Morelos Jaime Carlos (LICENCIA)',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=764'},
#  {'legislatura': 63,
#   'id_legislador': 'efedeae8-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Canseco Gómez Morelos Jaime Carlos (LICENCIA)',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Tamaulipas',
#   'distrito': '5',
#   'curul': 'I-301',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=764'},
#  {'legislatura': 63,
#   'id_legislador': 'f0253b6a-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': ' Rogelio Manuel Díaz Brown Ramsburgh',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Sonora',
#   'distrito': '6',
#   'curul': 'K-391',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Caraveo Galindo Teresita',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=752'},
#  {'legislatura': 63,
#   'id_legislador': 'f0253cb4-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Caraveo Galindo Teresita',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Sonora',
#   'distrito': '6',
#   'curul': 'K-391',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=752'},
#  {'legislatura': 63,
#   'id_legislador': 'f0540832-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Casique Vences Guillermina (LICENCIA)',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Mexico',
#   'distrito': '36',
#   'curul': 'I-324',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Apolinar Montañez Martínez',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=161'},
#  {'legislatura': 63,
#   'id_legislador': 'f054097c-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Apolinar Montañez Martínez',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Mexico',
#   'distrito': '36',
#   'curul': 'I-324',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=161'},
#  {'legislatura': 63,
#   'id_legislador': 'f0849c40-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Castillo Ruz Martín Enrique',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Yucatan',
#   'distrito': '5',
#   'curul': 'L-435',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Marco Alonso Vela Reyes',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=296'},
#  {'legislatura': 63,
#   'id_legislador': 'f0849d6c-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Marco Alonso Vela Reyes',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Yucatan',
#   'distrito': '5',
#   'curul': 'L-435',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=296'},
#  {'legislatura': 63,
#   'id_legislador': 'f0b2450a-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Castro Ríos Sofía',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Oaxaca',
#   'distrito': '5',
#   'curul': 'M-468',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Jorge Zarif Zetuna Curioca',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=202'},
#  {'legislatura': 63,
#   'id_legislador': 'f0b24636-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Jorge Zarif Zetuna Curioca',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Oaxaca',
#   'distrito': '5',
#   'curul': 'M-468',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=202'},
#  {'legislatura': 63,
#   'id_legislador': 'f0e2b3ca-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Ceballos Llerenas Hilda',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Colima',
#   'distrito': '5',
#   'curul': 'K-378',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Maríano Ruíz Zubieta',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=481'},
#  {'legislatura': 63,
#   'id_legislador': 'f0e2b582-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Maríano Ruíz Zubieta',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Colima',
#   'distrito': '5',
#   'curul': 'K-378',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=481'},
#  {'legislatura': 63,
#   'id_legislador': 'f10db3a4-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Cerda Pérez Rogelio',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Nuevo Leon',
#   'distrito': '12',
#   'curul': 'M-471',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Álvaro Ibarra Hinojosa',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=197'},
#  {'legislatura': 63,
#   'id_legislador': 'f10db4da-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Álvaro Ibarra Hinojosa',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Nuevo Leon',
#   'distrito': '12',
#   'curul': 'M-471',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=197'},
#  {'legislatura': 63,
#   'id_legislador': 'f13ec372-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Chirinos del Ángel Patricio',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Veracruz',
#   'distrito': '1',
#   'curul': 'M-494',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Nora Irma Escalante Zapata',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=271'},
#  {'legislatura': 63,
#   'id_legislador': 'f13ec548-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Nora Irma Escalante Zapata',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Veracruz',
#   'distrito': '1',
#   'curul': 'M-494',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=271'},
#  {'legislatura': 63,
#   'id_legislador': 'f171477a-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Chuayffet Chemor Emilio',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Mexico',
#   'distrito': '3',
#   'curul': 'G-224',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Marisol del Socorro Arias Flores',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=128'},
#  {'legislatura': 63,
#   'id_legislador': 'f17148a6-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Marisol del Socorro Arias Flores',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Mexico',
#   'distrito': '3',
#   'curul': 'G-224',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=128'},
#  {'legislatura': 63,
#   'id_legislador': 'f1a08f6c-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Clariond Reyes Retana Benjamín',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Nuevo Leon',
#   'distrito': '2',
#   'curul': 'M-472',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Antonia Mónica García Velázquez',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=365'},
#  {'legislatura': 63,
#   'id_legislador': 'f1a09098-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Antonia Mónica García Velázquez',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Nuevo Leon',
#   'distrito': '2',
#   'curul': 'M-472',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=365'},
#  {'legislatura': 63,
#   'id_legislador': 'f1d12384-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Concha Arellano Elpidio Desiderio',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Oaxaca',
#   'distrito': '2',
#   'curul': 'L-425',
#   'suplente_propietario': 'P',
#   'name_suplente': 'David Leyva García',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=199'},
#  {'legislatura': 63,
#   'id_legislador': 'f1d124a6-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'David Leyva García',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Oaxaca',
#   'distrito': '2',
#   'curul': 'L-425',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=199'},
#  {'legislatura': 63,
#   'id_legislador': 'f20339fa-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Contreras García Germán',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Sinaloa',
#   'distrito': '6',
#   'curul': 'D-103',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Araceli Millán Velarde',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=244'},
#  {'legislatura': 63,
#   'id_legislador': 'f2033bc6-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Araceli Millán Velarde',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Sinaloa',
#   'distrito': '6',
#   'curul': 'D-103',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=244'},
#  {'legislatura': 63,
#   'id_legislador': 'f230319e-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Córdova Hernández José del Pilar',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Tabasco',
#   'distrito': '6',
#   'curul': 'L-442',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Miguel Cachón Álvarez',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=259'},
#  {'legislatura': 63,
#   'id_legislador': 'f23032f2-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Miguel Cachón Álvarez',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Tabasco',
#   'distrito': '6',
#   'curul': 'L-442',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=259'},
#  {'legislatura': 63,
#   'id_legislador': 'f264fb0e-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Corona Rivera Armando',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Mexico',
#   'distrito': '12',
#   'curul': 'G-234',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Concepción Varela Espinoza',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=137'},
#  {'legislatura': 63,
#   'id_legislador': 'f264fc3a-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Concepción Varela Espinoza',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Mexico',
#   'distrito': '12',
#   'curul': 'G-234',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=137'},
#  {'legislatura': 63,
#   'id_legislador': 'f2977520-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Cota Jiménez Manuel Humberto',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Nayarit',
#   'distrito': '1',
#   'curul': 'J-359',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Fátima del Sol Gómez Montero',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=183'},
#  {'legislatura': 63,
#   'id_legislador': 'f2977642-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Fátima del Sol Gómez Montero',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Nayarit',
#   'distrito': '1',
#   'curul': 'J-359',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=183'},
#  {'legislatura': 63,
#   'id_legislador': 'f2c7e23c-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Cruz Mendoza Carlos',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Colima',
#   'distrito': '2',
#   'curul': 'K-377',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Patricia Carlos Pérez',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=24'},
#  {'legislatura': 63,
#   'id_legislador': 'f2c7e37c-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Patricia Carlos Pérez',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Colima',
#   'distrito': '2',
#   'curul': 'K-377',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=24'},
#  {'legislatura': 63,
#   'id_legislador': 'f2fa4db2-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': ' Óscar Román Rosas González',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Campeche',
#   'distrito': '2',
#   'curul': 'K-411',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Curmina Cervera Margarita Beatríz de la Candelaria',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=515'},
#  {'legislatura': 63,
#   'id_legislador': 'f2fa50a0-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Curmina Cervera Margarita Beatríz de la Candelaria',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Campeche',
#   'distrito': '2',
#   'curul': 'K-411',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=515'},
#  {'legislatura': 63,
#   'id_legislador': 'f3287c14-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'David David Sami',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Chiapas',
#   'distrito': '12',
#   'curul': 'I-311',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Alejandra Cruz Toledo Zebadúa',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=36'},
#  {'legislatura': 63,
#   'id_legislador': 'f3287d4a-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Alejandra Cruz Toledo Zebadúa',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Chiapas',
#   'distrito': '12',
#   'curul': 'I-311',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=36'},
#  {'legislatura': 63,
#   'id_legislador': 'f353ed04-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'De Esesarte Pesqueira Manuel Esteban',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Oaxaca',
#   'distrito': '8',
#   'curul': 'L-422',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Paola España López',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=205'},
#  {'legislatura': 63,
#   'id_legislador': 'f353ee26-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Paola España López',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Oaxaca',
#   'distrito': '8',
#   'curul': 'L-422',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=205'},
#  {'legislatura': 63,
#   'id_legislador': 'f3804886-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'De Lucas Hopkins Ernesto',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Sonora',
#   'distrito': '3',
#   'curul': 'K-390',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Cecilia Encinas Parra',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=249'},
#  {'legislatura': 63,
#   'id_legislador': 'f38049bc-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Cecilia Encinas Parra',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Sonora',
#   'distrito': '3',
#   'curul': 'K-390',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=249'},
#  {'legislatura': 63,
#   'id_legislador': 'f3abac4c-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'De la Fuente Dagdug María Estela',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Tabasco',
#   'distrito': '2',
#   'curul': 'L-441',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Eladio (DECESO) De la Cruz Maldonado',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=255'},
#  {'legislatura': 63,
#   'id_legislador': 'f3abae0e-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Eladio (DECESO) De la Cruz Maldonado',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Tabasco',
#   'distrito': '2',
#   'curul': 'L-441',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=255'},
#  {'legislatura': 63,
#   'id_legislador': 'f3dc99ba-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': ' Héctor Franco López',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Coahuila',
#   'distrito': '7',
#   'curul': 'C-068',
#   'suplente_propietario': 'P',
#   'name_suplente': 'De la Rosa Cortés Lily Fabiola',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=522'},
#  {'legislatura': 63,
#   'id_legislador': 'f3dc9ae6-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'De la Rosa Cortés Lily Fabiola',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Coahuila',
#   'distrito': '7',
#   'curul': 'C-068',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=522'},
#  {'legislatura': 63,
#   'id_legislador': 'f4121310-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'De la Torre Valdez Yolanda',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Durango',
#   'distrito': '1',
#   'curul': 'A-016',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Ismael Orozco Loreto',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=322'},
#  {'legislatura': 63,
#   'id_legislador': 'f4121450-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Ismael Orozco Loreto',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Durango',
#   'distrito': '1',
#   'curul': 'A-016',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=322'},
#  {'legislatura': 63,
#   'id_legislador': 'f4447c88-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Díaz Escárraga Heliodoro Carlos',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Oaxaca',
#   'distrito': '6',
#   'curul': 'M-469',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Elizabeth Hernández Reyes',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=203'},
#  {'legislatura': 63,
#   'id_legislador': 'f4447db4-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Elizabeth Hernández Reyes',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Oaxaca',
#   'distrito': '6',
#   'curul': 'M-469',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=203'},
#  {'legislatura': 63,
#   'id_legislador': 'f473eebe-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Díaz Salazar María Cristina',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Nuevo Leon',
#   'distrito': '11',
#   'curul': 'M-475',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Gabriel Tlaloc Cantú Cantú',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=196'},
#  {'legislatura': 63,
#   'id_legislador': 'f473efea-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Gabriel Tlaloc Cantú Cantú',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Nuevo Leon',
#   'distrito': '11',
#   'curul': 'M-475',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=196'},
#  {'legislatura': 63,
#   'id_legislador': 'f4a88ef8-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': ' Genaro Mejía de la Merced',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Veracruz',
#   'distrito': '2',
#   'curul': 'J-363',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Díaz Azuara Norberta Adalmira',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=772'},
#  {'legislatura': 63,
#   'id_legislador': 'f4a8907e-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Díaz Azuara Norberta Adalmira',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Veracruz',
#   'distrito': '2',
#   'curul': 'J-363',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=772'},
#  {'legislatura': 63,
#   'id_legislador': 'f4e0f392-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Domínguez Arvizu María Hilaria',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Nayarit',
#   'distrito': '1',
#   'curul': 'J-358',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Ricardo Pedro Chávez Pérez',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=324'},
#  {'legislatura': 63,
#   'id_legislador': 'f4e0f4be-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Ricardo Pedro Chávez Pérez',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Nayarit',
#   'distrito': '1',
#   'curul': 'J-358',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=324'},
#  {'legislatura': 63,
#   'id_legislador': 'f513261e-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Domínguez Rex Raúl',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Mexico',
#   'distrito': '2',
#   'curul': 'K-294',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Juanita de Jesús Santillán Hernández',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=127'},
#  {'legislatura': 63,
#   'id_legislador': 'f5132768-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': 'Juanita de Jesús Santillán Hernández',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Mexico',
#   'distrito': '2',
#   'curul': 'K-294',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pri',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=127'},
#  {'legislatura': 63,
#   'id_legislador': 'f545c362-fe1d-11ea-95ca-acde48001122',
#   'nombre_completo': ' Sergio Mancilla Zayas',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Mexico',
#   'distrito': '24',
#   'curul': 'G-223',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Durán Ortíz Estefanía',
# ...
#   'distrito': '5',
#   'curul': 'D-118',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pt',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=494'},
#  {'legislatura': 63,
#   'id_legislador': '4b7fed52-fe1e-11ea-95ca-acde48001122',
#   'nombre_completo': ' Anel Patricia Nava Pérez',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Durango',
#   'distrito': '1',
#   'curul': 'C-081',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Ríos Vázquez Alfonso Primitivo',
#   'partido': 'pt',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=834'},
#  {'legislatura': 63,
#   'id_legislador': '4b7fef0a-fe1e-11ea-95ca-acde48001122',
#   'nombre_completo': 'Ríos Vázquez Alfonso Primitivo',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Durango',
#   'distrito': '1',
#   'curul': 'C-081',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pt',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=834'},
#  {'legislatura': 63,
#   'id_legislador': '4bc4cb3e-fe1e-11ea-95ca-acde48001122',
#   'nombre_completo': 'Vázquez González Pedro',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Nuevo Leon',
#   'distrito': '2',
#   'curul': 'D-115',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Héctor Quiroz García',
#   'partido': 'pt',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=373'},
#  {'legislatura': 63,
#   'id_legislador': '4bc4ccd8-fe1e-11ea-95ca-acde48001122',
#   'nombre_completo': 'Héctor Quiroz García',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Nuevo Leon',
#   'distrito': '2',
#   'curul': 'D-115',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pt',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=373'},
#  {'legislatura': 63,
#   'id_legislador': '4c12ed46-fe1e-11ea-95ca-acde48001122',
#   'nombre_completo': 'Kahwagi Macari Jorge Antonio',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Ciudad de Mexico',
#   'distrito': '4',
#   'curul': 'D-100',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Deyanira Georgge Pérez',
#   'partido': 'alianza',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=459'},
#  {'legislatura': 63,
#   'id_legislador': '4c12eec2-fe1e-11ea-95ca-acde48001122',
#   'nombre_completo': 'Deyanira Georgge Pérez',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Ciudad de Mexico',
#   'distrito': '4',
#   'curul': 'D-100',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'alianza',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=459'},
#  {'legislatura': 63,
#   'id_legislador': '4c50f546-fe1e-11ea-95ca-acde48001122',
#   'nombre_completo': 'Martínez Peña Elsa María',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Coahuila',
#   'distrito': '2',
#   'curul': 'C-065',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Gloria Angélica Medina Morales',
#   'partido': 'alianza',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=380'},
#  {'legislatura': 63,
#   'id_legislador': '4c50f76c-fe1e-11ea-95ca-acde48001122',
#   'nombre_completo': 'Gloria Angélica Medina Morales',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Coahuila',
#   'distrito': '2',
#   'curul': 'C-065',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'alianza',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=380'},
#  {'legislatura': 63,
#   'id_legislador': '4c917d00-fe1e-11ea-95ca-acde48001122',
#   'nombre_completo': ' Reyes S. Tamez Guerra',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Nuevo Leon',
#   'distrito': '2',
#   'curul': 'D-096',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Meza Elizondo José Isabel',
#   'partido': 'alianza',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=879'},
#  {'legislatura': 63,
#   'id_legislador': '4c917e9a-fe1e-11ea-95ca-acde48001122',
#   'nombre_completo': 'Meza Elizondo José Isabel',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Nuevo Leon',
#   'distrito': '2',
#   'curul': 'D-096',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'alianza',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=879'},
#  {'legislatura': 63,
#   'id_legislador': '4cce090a-fe1e-11ea-95ca-acde48001122',
#   'nombre_completo': 'Orozco Torres Norma Leticia',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Guanajuato',
#   'distrito': '10',
#   'curul': 'H-260',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Miguel González Martínez',
#   'partido': 'alianza',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=86'},
#  {'legislatura': 63,
#   'id_legislador': '4cce0a7c-fe1e-11ea-95ca-acde48001122',
#   'nombre_completo': 'Miguel González Martínez',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Guanajuato',
#   'distrito': '10',
#   'curul': 'H-260',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'alianza',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=86'},
#  {'legislatura': 63,
#   'id_legislador': '4d055bd0-fe1e-11ea-95ca-acde48001122',
#   'nombre_completo': 'Pérez de Alva Blanco Roberto',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Baja California',
#   'distrito': '1',
#   'curul': 'D-099',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Isabel Cristina Nevarez Pulido',
#   'partido': 'alianza',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=339'},
#  {'legislatura': 63,
#   'id_legislador': '4d055dc4-fe1e-11ea-95ca-acde48001122',
#   'nombre_completo': 'Isabel Cristina Nevarez Pulido',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Baja California',
#   'distrito': '1',
#   'curul': 'D-099',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'alianza',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=339'},
#  {'legislatura': 63,
#   'id_legislador': '4d3f7162-fe1e-11ea-95ca-acde48001122',
#   'nombre_completo': 'Pinedo Alonso Cora',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Nayarit',
#   'distrito': '1',
#   'curul': 'D-098',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Dora María Guadalupe Talamante Lemas',
#   'partido': 'alianza',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=340'},
#  {'legislatura': 63,
#   'id_legislador': '4d3f72d4-fe1e-11ea-95ca-acde48001122',
#   'nombre_completo': 'Dora María Guadalupe Talamante Lemas',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Nayarit',
#   'distrito': '1',
#   'curul': 'D-098',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'alianza',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=340'},
#  {'legislatura': 63,
#   'id_legislador': '4d7c2102-fe1e-11ea-95ca-acde48001122',
#   'nombre_completo': 'Torre Canales María del Pilar',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Mexico',
#   'distrito': '5',
#   'curul': 'C-063',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Gabriel Romero Vázquez',
#   'partido': 'alianza',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=420'},
#  {'legislatura': 63,
#   'id_legislador': '4d7c2274-fe1e-11ea-95ca-acde48001122',
#   'nombre_completo': 'Gabriel Romero Vázquez',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Mexico',
#   'distrito': '5',
#   'curul': 'C-063',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'alianza',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=420'},
#  {'legislatura': 63,
#   'id_legislador': '4daf0edc-fe1e-11ea-95ca-acde48001122',
#   'nombre_completo': 'Villarreal Benassini Karla Daniella',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Ciudad de Mexico',
#   'distrito': '4',
#   'curul': 'C-064',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Gerardo Del Mazo Morales',
#   'partido': 'alianza',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=460'},
#  {'legislatura': 63,
#   'id_legislador': '4daf104e-fe1e-11ea-95ca-acde48001122',
#   'nombre_completo': 'Gerardo Del Mazo Morales',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Ciudad de Mexico',
#   'distrito': '4',
#   'curul': 'C-064',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'alianza',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=460'},
#  {'legislatura': 63,
#   'id_legislador': '4de3873e-fe1e-11ea-95ca-acde48001122',
#   'nombre_completo': 'Álvarez Cisneros Jaime',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Morelos',
#   'distrito': '4',
#   'curul': 'H-279',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Guillermo Garduño Aguilar',
#   'partido': 'mc',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=457'},
#  {'legislatura': 63,
#   'id_legislador': '4de388ba-fe1e-11ea-95ca-acde48001122',
#   'nombre_completo': 'Guillermo Garduño Aguilar',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Morelos',
#   'distrito': '4',
#   'curul': 'H-279',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'mc',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=457'},
#  {'legislatura': 63,
#   'id_legislador': '4e17069a-fe1e-11ea-95ca-acde48001122',
#   'nombre_completo': 'Arizmendi Campos Laura (LICENCIA)',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Guerrero',
#   'distrito': '4',
#   'curul': 'G-236',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Claudia Walton Álvarez',
#   'partido': 'mc',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=458'},
#  {'legislatura': 63,
#   'id_legislador': '4e17087a-fe1e-11ea-95ca-acde48001122',
#   'nombre_completo': 'Claudia Walton Álvarez',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Guerrero',
#   'distrito': '4',
#   'curul': 'G-236',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'mc',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=458'},
#  {'legislatura': 63,
#   'id_legislador': '4e5499e2-fe1e-11ea-95ca-acde48001122',
#   'nombre_completo': 'García Almanza María Guadalupe',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Oaxaca',
#   'distrito': '3',
#   'curul': 'G-235',
#   'suplente_propietario': 'P',
#   'name_suplente': 'José Soto Martínez',
#   'partido': 'mc',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=378'},
#  {'legislatura': 63,
#   'id_legislador': '4e549b72-fe1e-11ea-95ca-acde48001122',
#   'nombre_completo': 'José Soto Martínez',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Oaxaca',
#   'distrito': '3',
#   'curul': 'G-235',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'mc',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=378'},
#  {'legislatura': 63,
#   'id_legislador': '4e8edd1e-fe1e-11ea-95ca-acde48001122',
#   'nombre_completo': 'Gertz Manero Alejandro',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Mexico',
#   'distrito': '5',
#   'curul': 'H-277',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Paulino Gerardo Tapia Latisnere',
#   'partido': 'mc',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=498'},
#  {'legislatura': 63,
#   'id_legislador': '4e8ede86-fe1e-11ea-95ca-acde48001122',
#   'nombre_completo': 'Paulino Gerardo Tapia Latisnere',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Mexico',
#   'distrito': '5',
#   'curul': 'H-277',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'mc',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=498'},
#  {'legislatura': 63,
#   'id_legislador': '4ec97b68-fe1e-11ea-95ca-acde48001122',
#   'nombre_completo': 'Jiménez León Pedro',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Tabasco',
#   'distrito': '3',
#   'curul': 'H-278',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Ricardo Coronado Sangines',
#   'partido': 'mc',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=418'},
#  {'legislatura': 63,
#   'id_legislador': '4ec97cd0-fe1e-11ea-95ca-acde48001122',
#   'nombre_completo': 'Ricardo Coronado Sangines',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Tabasco',
#   'distrito': '3',
#   'curul': 'H-278',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'mc',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=418'},
#  {'legislatura': 63,
#   'id_legislador': '4f04157a-fe1e-11ea-95ca-acde48001122',
#   'nombre_completo': 'Ochoa Mejía Ma. Teresa Rosaura',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Mexico',
#   'distrito': '5',
#   'curul': 'G-237',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Zuleyma Huidobro González',
#   'partido': 'mc',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=499'},
#  {'legislatura': 63,
#   'id_legislador': '4f0416f6-fe1e-11ea-95ca-acde48001122',
#   'nombre_completo': 'Zuleyma Huidobro González',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Mexico',
#   'distrito': '5',
#   'curul': 'G-237',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'mc',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=499'},
#  {'legislatura': 63,
#   'id_legislador': '4f3d2784-fe1e-11ea-95ca-acde48001122',
#   'nombre_completo': 'Serrano Jiménez Emilio',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Ciudad de Mexico',
#   'distrito': '13',
#   'curul': 'D-113',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Angélica Adriana Díaz Bustamante',
#   'partido': 'sin partido',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=58'},
#  {'legislatura': 63,
#   'id_legislador': '4f3d28ec-fe1e-11ea-95ca-acde48001122',
#   'nombre_completo': 'Angélica Adriana Díaz Bustamante',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Ciudad de Mexico',
#   'distrito': '13',
#   'curul': 'D-113',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'sin partido',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=58'},
#  {'legislatura': 63,
#   'id_legislador': '4f98bacc-fe1e-11ea-95ca-acde48001122',
#   'nombre_completo': 'Torres Abarca O. Magdalena',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Chiapas',
#   'distrito': '3',
#   'curul': 'D-108',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Elvira de Jesús Pola Figueroa',
#   'partido': 'sin partido',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=408'},
#  {'legislatura': 63,
#   'id_legislador': '4f98bc52-fe1e-11ea-95ca-acde48001122',
#   'nombre_completo': 'Elvira de Jesús Pola Figueroa',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Chiapas',
#   'distrito': '3',
#   'curul': 'D-108',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'sin partido',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=408'},
#  {'legislatura': 63,
#   'id_legislador': '4fdec030-fe1e-11ea-95ca-acde48001122',
#   'nombre_completo': 'Vázquez Aguilar Jaime Arturo',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Mexico',
#   'distrito': '5',
#   'curul': 'C-066',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Sarbelio Augusto Molina Vélez',
#   'partido': 'sin partido',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=500'},
#  {'legislatura': 63,
#   'id_legislador': '4fdec206-fe1e-11ea-95ca-acde48001122',
#   'nombre_completo': 'Sarbelio Augusto Molina Vélez',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Mexico',
#   'distrito': '5',
#   'curul': 'C-066',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'sin partido',
#   'link_curricula': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=500'}]

# %%
with open('/Users/cblanesg/cam.blanes Dropbox/Camila Blanes/Congressional-dataMX/data/00-id_data/id_legislatura61.json', 'w') as json_file:
    json.dump(data_id62_clean, json_file)

# %% [markdown]
# ## Legislatura 60

# %%
main_url = 'http://sitllx.diputados.gob.mx/listado_diputados_gpnp.php?tipot=TOTAL'
driver.get(main_url)

# %%
links_diputados = []
names_diputados = []
for i in tqdm(driver.find_elements_by_css_selector('a')):
    link = i.get_attribute('href')
    if any(re.findall('curricula', link)):
        links_diputados.append(link)
        names_diputados.append(re.sub('^[0-9]+ ', '', i.text))
        
    else:
        continue
# Out:
# 100%|██████████| 512/512 [00:08<00:00, 58.83it/s]

# %%
len(names_diputados)
# Out:
# 500

# %%
mapping_name_party = {}
for i in names_diputados[0:206]:
    mapping_name_party[i] = 'pan'
    
for i in names_diputados[206: 331]:
    mapping_name_party[i] = 'prd'
    
for i in names_diputados[331:437]:
    mapping_name_party[i] = 'pri'
    
for i in names_diputados[437:455]:
    mapping_name_party[i] = 'mc'
    
for i in names_diputados[455:472]:
    mapping_name_party[i] = 'pve'
    
for i in names_diputados[472:483]:
    mapping_name_party[i] = 'pt'
    
for i in names_diputados[483:492]:
    mapping_name_party[i] = 'alianza'
    
for i in names_diputados[492:497]:
    mapping_name_party[i] = 'psd'
for i in names_diputados[497:]:
    mapping_name_party[i] = 'sin partido'

# %%
len(mapping_name_party)
# Out:
# 500

# %%
import unidecode

# %%
def obtain_id_data60(name, mapping_parties, link):
    suplente_propietario = driver.find_element_by_css_selector('body > table > tbody > tr:nth-child(3) > td > table > tbody > tr:nth-child(8) > td > span').text
    
    tipo_inc = unidecode.unidecode(driver.find_element_by_css_selector('body > table > tbody > tr:nth-child(3) > td > table > tbody > tr:nth-child(3) > td:nth-child(2)').text)
    estado = unidecode.unidecode(driver.find_element_by_css_selector('body > table > tbody > tr:nth-child(3) > td > table > tbody > tr:nth-child(4) > td:nth-child(2)').text)
    distrito = unidecode.unidecode(driver.find_element_by_css_selector('body > table > tbody > tr:nth-child(3) > td > table > tbody > tr:nth-child(5) > td:nth-child(2)').text)
    curul = unidecode.unidecode(driver.find_element_by_css_selector('body > table > tbody > tr:nth-child(3) > td > table > tbody > tr:nth-child(7) > td:nth-child(2)').text)
    
    
    if any(re.findall('Suplente de:', suplente_propietario)):
        dict_prop = {}
        dict_prop['legislatura'] = 63
        dict_prop['id_legislador'] = str(uuid.uuid1())
        dict_prop['nombre_completo'] = re.sub('[ ]+$', '', re.sub('Suplente de[:]', '', suplente_propietario))
        dict_prop['tipo_legislador'] = tipo_inc
        dict_prop['entidad'] = estado
        dict_prop['distrito'] = distrito
        dict_prop['curul'] = curul
        dict_prop['suplente_propietario'] = 'P'
        dict_prop['name_suplente'] = name
        dict_prop['partido'] = mapping_parties[name]
        dict_prop['link_curricula'] = link
        
        
        dict_sup = {}
        dict_sup['legislatura'] = 63
        dict_sup['id_legislador'] = str(uuid.uuid1())
        dict_sup['nombre_completo'] = name
        dict_sup['tipo_legislador'] = tipo_inc
        dict_sup['entidad'] = estado
        dict_sup['distrito'] = distrito
        dict_sup['curul'] = curul
        dict_sup['suplente_propietario'] = 'S'
        dict_sup['name_suplente'] = ''
        dict_sup['partido'] = mapping_parties[name]
        dict_sup['link_curricula'] = link
        return([dict_prop, dict_sup])
    else:
    
        dict_prop = {}
        dict_prop['legislatura'] = 63
        dict_prop['id_legislador'] = str(uuid.uuid1())
        dict_prop['nombre_completo'] = name
        dict_prop['tipo_legislador'] = tipo_inc
        dict_prop['entidad'] = estado
        dict_prop['distrito'] = distrito
        dict_prop['curul'] = curul
        dict_prop['suplente_propietario'] = 'P'
        dict_prop['name_suplente'] = re.sub('[ ]+$', '', re.sub('Suplente de[:]', '', suplente_propietario))
        dict_prop['partido'] = mapping_parties[name]
        dict_prop['link_curricula'] = link
        
        
        dict_sup = {}
        dict_sup['legislatura'] = 63
        dict_sup['id_legislador'] = str(uuid.uuid1())
        dict_sup['nombre_completo'] = re.sub('[ ]+$', '', re.sub('Suplente de[:]', '', suplente_propietario))
        dict_sup['tipo_legislador'] = tipo_inc
        dict_sup['entidad'] = estado
        dict_sup['distrito'] = distrito
        dict_sup['curul'] = curul
        dict_sup['suplente_propietario'] = 'S'
        dict_sup['name_suplente'] = ''
        dict_sup['partido'] = mapping_parties[name]
        dict_sup['link_curricula'] = link
        
        return([dict_prop, dict_sup])

# %%
data_id62 = []
for x, y in tqdm(zip(links_diputados, names_diputados), total = len(names_diputados)):
    driver.get(x)
    dicts = obtain_id_data60(y, mapping_name_party, x)
    for i in  dicts:
        data_id62.append(i)
# Out:
# 100%|██████████| 500/500 [03:07<00:00,  2.67it/s]

# %%
data_id62_clean = []
for i in data_id62:
    i['legislatura'] = 60
    i['nombre_completo'] = re.sub('Suplente: ', '', i['nombre_completo'])
    i['name_suplente'] = re.sub('Suplente: ', '', i['name_suplente'])
    data_id62_clean.append(i)

len(data_id62_clean)
# Out:
# 1000

# %%
data_id62_clean
# Out:
# [{'legislatura': 60,
#   'id_legislador': 'e7f3daa8-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Acosta Dávila Constantino',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Mexico',
#   'distrito': '4',
#   'curul': 'K-374',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Erika Galván Rivas',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=129'},
#  {'legislatura': 60,
#   'id_legislador': 'e7f3dbde-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Erika Galván Rivas',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Mexico',
#   'distrito': '4',
#   'curul': 'K-374',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=129'},
#  {'legislatura': 60,
#   'id_legislador': 'e82a705e-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': ' Efraín Arizmendi Uribe',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Guerrero',
#   'distrito': '4',
#   'curul': 'C-053',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Alanís Domínguez Martía Teresa',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=853'},
#  {'legislatura': 60,
#   'id_legislador': 'e82a718a-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Alanís Domínguez Martía Teresa',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Guerrero',
#   'distrito': '4',
#   'curul': 'C-053',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=853'},
#  {'legislatura': 60,
#   'id_legislador': 'e85d8a34-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Alcaraz Hernández Alma Edwviges (LICENCIA)',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Sinaloa',
#   'distrito': '1',
#   'curul': 'F-164',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Víctor Manuel Ahumada Inzunza',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=309'},
#  {'legislatura': 60,
#   'id_legislador': 'e85d8c1e-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Víctor Manuel Ahumada Inzunza',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Sinaloa',
#   'distrito': '1',
#   'curul': 'F-164',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=309'},
#  {'legislatura': 60,
#   'id_legislador': 'e88f3462-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Álvarez Bernal María Elena',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Michoacan',
#   'distrito': '5',
#   'curul': 'D-086',
#   'suplente_propietario': 'P',
#   'name_suplente': 'José Loyola Trujillo',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=358'},
#  {'legislatura': 60,
#   'id_legislador': 'e88f358e-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'José Loyola Trujillo',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Michoacan',
#   'distrito': '5',
#   'curul': 'D-086',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=358'},
#  {'legislatura': 60,
#   'id_legislador': 'e8c1e6c8-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Amezola Fonceca Gerardo',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Jalisco',
#   'distrito': '15',
#   'curul': 'L-426',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Gabriel Flores Castellanos',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=121'},
#  {'legislatura': 60,
#   'id_legislador': 'e8c1e7fe-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Gabriel Flores Castellanos',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Jalisco',
#   'distrito': '15',
#   'curul': 'L-426',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=121'},
#  {'legislatura': 60,
#   'id_legislador': 'e8f72734-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Aranda Orozco Gerardo',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Sonora',
#   'distrito': '1',
#   'curul': 'E-125',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Claudia Méndez Vargas',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=311'},
#  {'legislatura': 60,
#   'id_legislador': 'e8f72874-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Claudia Méndez Vargas',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Sonora',
#   'distrito': '1',
#   'curul': 'E-125',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=311'},
#  {'legislatura': 60,
#   'id_legislador': 'e9272d26-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Arellano Arellano Joel',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Jalisco',
#   'distrito': '6',
#   'curul': 'M-464',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Juan Manuel Hidalgo Morán',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=112'},
#  {'legislatura': 60,
#   'id_legislador': 'e9272e52-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Juan Manuel Hidalgo Morán',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Jalisco',
#   'distrito': '6',
#   'curul': 'M-464',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=112'},
#  {'legislatura': 60,
#   'id_legislador': 'e954ec7a-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Arenas Guzmán Margarita',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Guanajuato',
#   'distrito': '4',
#   'curul': 'G-502',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Marcos Amador García Olvera',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=80'},
#  {'legislatura': 60,
#   'id_legislador': 'e954edb0-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Marcos Amador García Olvera',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Guanajuato',
#   'distrito': '4',
#   'curul': 'G-502',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=80'},
#  {'legislatura': 60,
#   'id_legislador': 'e9862402-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': ' Felipe Borrego Estrada',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Zacatecas',
#   'distrito': '2',
#   'curul': 'E-119',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Argüelles Arellano María del Consuelo',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=828'},
#  {'legislatura': 60,
#   'id_legislador': 'e986272c-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Argüelles Arellano María del Consuelo',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Zacatecas',
#   'distrito': '2',
#   'curul': 'E-119',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=828'},
#  {'legislatura': 60,
#   'id_legislador': 'e9b86872-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Armendáriz García Pedro',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Aguascalientes',
#   'distrito': '1',
#   'curul': 'L-432',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Patricia Lucio Ochoa',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=1'},
#  {'legislatura': 60,
#   'id_legislador': 'e9b869a8-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Patricia Lucio Ochoa',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Aguascalientes',
#   'distrito': '1',
#   'curul': 'L-432',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=1'},
#  {'legislatura': 60,
#   'id_legislador': 'e9eae43c-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Arredondo Ibarra Salvador',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Mexico',
#   'distrito': '7',
#   'curul': 'E-135',
#   'suplente_propietario': 'P',
#   'name_suplente': 'María del Carmen Carvajal Adame',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=132'},
#  {'legislatura': 60,
#   'id_legislador': 'e9eae554-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'María del Carmen Carvajal Adame',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Mexico',
#   'distrito': '7',
#   'curul': 'E-135',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=132'},
#  {'legislatura': 60,
#   'id_legislador': 'ea1e687a-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Arredondo Velázquez Jesús',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Queretaro',
#   'distrito': '2',
#   'curul': 'J-336',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Andrea Álvarez Soto',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=332'},
#  {'legislatura': 60,
#   'id_legislador': 'ea1e6992-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Andrea Álvarez Soto',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Queretaro',
#   'distrito': '2',
#   'curul': 'J-336',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=332'},
#  {'legislatura': 60,
#   'id_legislador': 'ea54e2ce-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Ávila Mayo Obdulio',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Ciudad de Mexico',
#   'distrito': '4',
#   'curul': 'A-010',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Sandra Esther Pérez Toxqui Sánchez',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=351'},
#  {'legislatura': 60,
#   'id_legislador': 'ea54e486-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Sandra Esther Pérez Toxqui Sánchez',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Ciudad de Mexico',
#   'distrito': '4',
#   'curul': 'A-010',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=351'},
#  {'legislatura': 60,
#   'id_legislador': 'ea87c388-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Barradas Miravete Gregorio',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Veracruz',
#   'distrito': '20',
#   'curul': 'I-288',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Sonia Castañeda Arizmendi',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=290'},
#  {'legislatura': 60,
#   'id_legislador': 'ea87c4aa-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Sonia Castañeda Arizmendi',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Veracruz',
#   'distrito': '20',
#   'curul': 'I-288',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=290'},
#  {'legislatura': 60,
#   'id_legislador': 'eab9f1dc-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Barrios Rodríguez Juan Enrique',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Nuevo Leon',
#   'distrito': '6',
#   'curul': 'J-330',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Gloria Leticia González Rivera',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=191'},
#  {'legislatura': 60,
#   'id_legislador': 'eab9f2f4-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Gloria Leticia González Rivera',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Nuevo Leon',
#   'distrito': '6',
#   'curul': 'J-330',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=191'},
#  {'legislatura': 60,
#   'id_legislador': 'eaee2754-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Bello Pérez Alfonso Othón',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Puebla',
#   'distrito': '11',
#   'curul': 'F-175',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Martha Angélica Rubín Dávila',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=219'},
#  {'legislatura': 60,
#   'id_legislador': 'eaee295c-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Martha Angélica Rubín Dávila',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Puebla',
#   'distrito': '11',
#   'curul': 'F-175',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=219'},
#  {'legislatura': 60,
#   'id_legislador': 'eb1f08b0-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Berber Martínez Antonio',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Michoacan',
#   'distrito': '5',
#   'curul': 'J-340',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Elia Saucedo Chávez',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=365'},
#  {'legislatura': 60,
#   'id_legislador': 'eb1f0c70-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Elia Saucedo Chávez',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Michoacan',
#   'distrito': '5',
#   'curul': 'J-340',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=365'},
#  {'legislatura': 60,
#   'id_legislador': 'eb556f22-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': ' Andrés Bermúdez Viramontes',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Zacatecas',
#   'distrito': '2',
#   'curul': 'F-174',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Bernal Frausto Federico',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=798'},
#  {'legislatura': 60,
#   'id_legislador': 'eb557080-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Bernal Frausto Federico',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Zacatecas',
#   'distrito': '2',
#   'curul': 'F-174',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=798'},
#  {'legislatura': 60,
#   'id_legislador': 'eb85a8c2-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Bolaños Aguilar Edmundo Javier',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Morelos',
#   'distrito': '4',
#   'curul': 'H-255',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Consuelo Gómez Flores',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=356'},
#  {'legislatura': 60,
#   'id_legislador': 'eb85a9f8-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Consuelo Gómez Flores',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Morelos',
#   'distrito': '4',
#   'curul': 'H-255',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=356'},
#  {'legislatura': 60,
#   'id_legislador': 'ebb34f02-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Bracho González Carlos Augusto',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Coahuila',
#   'distrito': '5',
#   'curul': 'G-218',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Elizabeth Rodríguez Vega',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=20'},
#  {'legislatura': 60,
#   'id_legislador': 'ebb35038-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Elizabeth Rodríguez Vega',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Coahuila',
#   'distrito': '5',
#   'curul': 'G-218',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=20'},
#  {'legislatura': 60,
#   'id_legislador': 'ebe725e8-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Buganza Salmerón Gerardo',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Veracruz',
#   'distrito': '3',
#   'curul': 'C-055',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Judith Pineda Andrade',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=336'},
#  {'legislatura': 60,
#   'id_legislador': 'ebe72746-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Judith Pineda Andrade',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Veracruz',
#   'distrito': '3',
#   'curul': 'C-055',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=336'},
#  {'legislatura': 60,
#   'id_legislador': 'ec1ad3f2-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Campos Galván María Eugenia',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Chihuahua',
#   'distrito': '1',
#   'curul': 'A-009',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Luis Ernesto Nieves Robinson Bours',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=315'},
#  {'legislatura': 60,
#   'id_legislador': 'ec1ad514-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Luis Ernesto Nieves Robinson Bours',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Chihuahua',
#   'distrito': '1',
#   'curul': 'A-009',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=315'},
#  {'legislatura': 60,
#   'id_legislador': 'ec49581c-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Carbajal Méndez Liliana',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'San Luis Potosi',
#   'distrito': '2',
#   'curul': 'D-084',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Marco Antonio Hernández Ávila',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=323'},
#  {'legislatura': 60,
#   'id_legislador': 'ec49593e-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Marco Antonio Hernández Ávila',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'San Luis Potosi',
#   'distrito': '2',
#   'curul': 'D-084',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=323'},
#  {'legislatura': 60,
#   'id_legislador': 'ec78a5cc-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Cárdenas Sánchez Esmeralda (LICENCIA)',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Colima',
#   'distrito': '1',
#   'curul': 'C-060',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Ferdinando Enrique Martínez Valencia',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=23'},
#  {'legislatura': 60,
#   'id_legislador': 'ec78a798-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Ferdinando Enrique Martínez Valencia',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Colima',
#   'distrito': '1',
#   'curul': 'C-060',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=23'},
#  {'legislatura': 60,
#   'id_legislador': 'ecacd428-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': ' Luis Rodolfo Enríquez Martínez',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Baja California',
#   'distrito': '6',
#   'curul': 'I-297',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Cardona Benavidez Alma Xóchil',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=509'},
#  {'legislatura': 60,
#   'id_legislador': 'ecacd5cc-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Cardona Benavidez Alma Xóchil',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Baja California',
#   'distrito': '6',
#   'curul': 'I-297',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=509'},
#  {'legislatura': 60,
#   'id_legislador': 'ecdca8f6-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Carrasco Altamirano Diódoro Humberto',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Oaxaca',
#   'distrito': '3',
#   'curul': 'D-089',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Patricia Guadalupe Zúñiga Díaz',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=342'},
#  {'legislatura': 60,
#   'id_legislador': 'ecdcaa2c-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Patricia Guadalupe Zúñiga Díaz',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Oaxaca',
#   'distrito': '3',
#   'curul': 'D-089',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=342'},
#  {'legislatura': 60,
#   'id_legislador': 'ed100c64-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': ' Daniel Chávez García',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Michoacan',
#   'distrito': '8',
#   'curul': 'M-472',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Carrasco Cárdenas Susana Sarahí',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=673'},
#  {'legislatura': 60,
#   'id_legislador': 'ed100d90-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Carrasco Cárdenas Susana Sarahí',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Michoacan',
#   'distrito': '8',
#   'curul': 'M-472',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=673'},
#  {'legislatura': 60,
#   'id_legislador': 'ed490ad2-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Castaño Contreras Cristián',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Nuevo Leon',
#   'distrito': '7',
#   'curul': 'C-054',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Diana Esperanza Gamez Garza',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=192'},
#  {'legislatura': 60,
#   'id_legislador': 'ed490c30-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Diana Esperanza Gamez Garza',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Nuevo Leon',
#   'distrito': '7',
#   'curul': 'C-054',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=192'},
#  {'legislatura': 60,
#   'id_legislador': 'ed7a00c4-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Castro De la Rosa Osiel',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Veracruz',
#   'distrito': '17',
#   'curul': 'B-025',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Natividad Medina Tamayo',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=287'},
#  {'legislatura': 60,
#   'id_legislador': 'ed7a025e-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Natividad Medina Tamayo',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Veracruz',
#   'distrito': '17',
#   'curul': 'B-025',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=287'},
#  {'legislatura': 60,
#   'id_legislador': 'edaf5878-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Castro Romero Ma. Sofía Del Perpetuo Socorro',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Yucatan',
#   'distrito': '3',
#   'curul': 'C-051',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Fidel Antuña Batista (Sale de funciones)',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=294'},
#  {'legislatura': 60,
#   'id_legislador': 'edaf59b8-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Fidel Antuña Batista (Sale de funciones)',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Yucatan',
#   'distrito': '3',
#   'curul': 'C-051',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=294'},
#  {'legislatura': 60,
#   'id_legislador': 'ede9e5ec-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Ceja Romero Ramón',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Michoacan',
#   'distrito': '5',
#   'curul': 'M-466',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Rosa María Aguilar Solorio',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=170'},
#  {'legislatura': 60,
#   'id_legislador': 'ede9e70e-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Rosa María Aguilar Solorio',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Michoacan',
#   'distrito': '5',
#   'curul': 'M-466',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=170'},
#  {'legislatura': 60,
#   'id_legislador': 'ee1f4336-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Collado Lara Beatriz (LICENCIA)',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Tamaulipas',
#   'distrito': '7',
#   'curul': 'G-213',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Rubén Yañez Hernández',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=266'},
#  {'legislatura': 60,
#   'id_legislador': 'ee1f446c-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Rubén Yañez Hernández',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Tamaulipas',
#   'distrito': '7',
#   'curul': 'G-213',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=266'},
#  {'legislatura': 60,
#   'id_legislador': 'ee4f1804-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Contreras Coeto José Luis',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Puebla',
#   'distrito': '7',
#   'curul': 'J-331',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Hilda Leticia Salinas Hernández',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=215'},
#  {'legislatura': 60,
#   'id_legislador': 'ee4f1958-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Hilda Leticia Salinas Hernández',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Puebla',
#   'distrito': '7',
#   'curul': 'J-331',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=215'},
#  {'legislatura': 60,
#   'id_legislador': 'ee827712-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Corral Aguilar María Mercedes',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Sonora',
#   'distrito': '1',
#   'curul': 'I-303',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Cipriano Palafox Olivarría',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=314'},
#  {'legislatura': 60,
#   'id_legislador': 'ee827834-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Cipriano Palafox Olivarría',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Sonora',
#   'distrito': '1',
#   'curul': 'I-303',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=314'},
#  {'legislatura': 60,
#   'id_legislador': 'eeb5edfe-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': ' Alberto Vázquez Martínez',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Queretaro',
#   'distrito': '2',
#   'curul': 'A-011',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Cortés Osornio Luz Virginia',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=822'},
#  {'legislatura': 60,
#   'id_legislador': 'eeb5ef20-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Cortés Osornio Luz Virginia',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Queretaro',
#   'distrito': '2',
#   'curul': 'A-011',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=822'},
#  {'legislatura': 60,
#   'id_legislador': 'eee52f7e-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Cuen Garibi Marcela',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Guanajuato',
#   'distrito': '9',
#   'curul': 'H-243',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Francisco González García',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=85'},
#  {'legislatura': 60,
#   'id_legislador': 'eee530a0-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Francisco González García',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Guanajuato',
#   'distrito': '9',
#   'curul': 'H-243',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=85'},
#  {'legislatura': 60,
#   'id_legislador': 'ef17bea8-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Curiel Preciado Leobardo',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Jalisco',
#   'distrito': '5',
#   'curul': 'G-209',
#   'suplente_propietario': 'P',
#   'name_suplente': 'María Cristina Rodríguez Ramos',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=111'},
#  {'legislatura': 60,
#   'id_legislador': 'ef17bfde-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'María Cristina Rodríguez Ramos',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Jalisco',
#   'distrito': '5',
#   'curul': 'G-209',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=111'},
#  {'legislatura': 60,
#   'id_legislador': 'ef497998-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Dávila Fernández Adriana',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Tlaxcala',
#   'distrito': '4',
#   'curul': 'L-418',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Jaime Raymundo Bernal Léon',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=352'},
#  {'legislatura': 60,
#   'id_legislador': 'ef497ace-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Jaime Raymundo Bernal Léon',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Tlaxcala',
#   'distrito': '4',
#   'curul': 'L-418',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=352'},
#  {'legislatura': 60,
#   'id_legislador': 'ef7c5ebc-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Dávila García Francisco',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Aguascalientes',
#   'distrito': '2',
#   'curul': 'J-344',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Tania Lorena Valdez Parga',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=334'},
#  {'legislatura': 60,
#   'id_legislador': 'ef7c5ff2-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Tania Lorena Valdez Parga',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Aguascalientes',
#   'distrito': '2',
#   'curul': 'J-344',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=334'},
#  {'legislatura': 60,
#   'id_legislador': 'efb42ed2-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'De León Tello Jesús (LICENCIA)',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Coahuila',
#   'distrito': '6',
#   'curul': 'J-342',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Florentina Medrano Echeverría',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=21'},
#  {'legislatura': 60,
#   'id_legislador': 'efb42ffe-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Florentina Medrano Echeverría',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Coahuila',
#   'distrito': '6',
#   'curul': 'J-342',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=21'},
#  {'legislatura': 60,
#   'id_legislador': 'efe92dda-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'De la Torre Jaramillo Eduardo Sergio',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Veracruz',
#   'distrito': '3',
#   'curul': 'M-471',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Jorge Virgilio Domínguez Cedeño',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=498'},
#  {'legislatura': 60,
#   'id_legislador': 'efe930f0-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Jorge Virgilio Domínguez Cedeño',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Veracruz',
#   'distrito': '3',
#   'curul': 'M-471',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=498'},
#  {'legislatura': 60,
#   'id_legislador': 'f020d5c8-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'De la Torre Sánchez José',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Veracruz',
#   'distrito': '7',
#   'curul': 'L-422',
#   'suplente_propietario': 'P',
#   'name_suplente': 'María de Jesús Martínez Díaz',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=277'},
#  {'legislatura': 60,
#   'id_legislador': 'f020d71c-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'María de Jesús Martínez Díaz',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Veracruz',
#   'distrito': '7',
#   'curul': 'L-422',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=277'},
#  {'legislatura': 60,
#   'id_legislador': 'f0582de8-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Degante Romero Silvia Emilia',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'San Luis Potosi',
#   'distrito': '6',
#   'curul': 'B-032',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Gerardo Arellano Vera',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=237'},
#  {'legislatura': 60,
#   'id_legislador': 'f0582fe6-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Gerardo Arellano Vera',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'San Luis Potosi',
#   'distrito': '6',
#   'curul': 'B-032',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=237'},
#  {'legislatura': 60,
#   'id_legislador': 'f090f63c-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Del Toro del Villar Tomás',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Mexico',
#   'distrito': '5',
#   'curul': 'D-091',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Claudia Lilia Luna Islas',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=357'},
#  {'legislatura': 60,
#   'id_legislador': 'f090f786-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Claudia Lilia Luna Islas',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Mexico',
#   'distrito': '5',
#   'curul': 'D-091',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=357'},
#  {'legislatura': 60,
#   'id_legislador': 'f0c6370c-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Del Valle Toca Antonio',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Veracruz',
#   'distrito': '5',
#   'curul': 'M-473',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Rosa Elva Castro Ortiz',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=275'},
#  {'legislatura': 60,
#   'id_legislador': 'f0c6387e-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Rosa Elva Castro Ortiz',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Veracruz',
#   'distrito': '5',
#   'curul': 'M-473',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=275'},
#  {'legislatura': 60,
#   'id_legislador': 'f0fb78f4-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Delgado Oscoy Alejandro Enrique',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Queretaro',
#   'distrito': '4',
#   'curul': 'I-293',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Ma. Guadalupe González Ramírez',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=228'},
#  {'legislatura': 60,
#   'id_legislador': 'f0fb7ab6-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Ma. Guadalupe González Ramírez',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Queretaro',
#   'distrito': '4',
#   'curul': 'I-293',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=228'},
#  {'legislatura': 60,
#   'id_legislador': 'f131c3d2-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': ' José Manuel Minjares Jiménez',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Ciudad de Mexico',
#   'distrito': '15',
#   'curul': 'H-245',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Denegre Vaught Ramírez Rosaura Virginia',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=560'},
#  {'legislatura': 60,
#   'id_legislador': 'f131c508-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Denegre Vaught Ramírez Rosaura Virginia',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Ciudad de Mexico',
#   'distrito': '15',
#   'curul': 'H-245',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=560'},
#  {'legislatura': 60,
#   'id_legislador': 'f16b8c98-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Díaz García José Antonio',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Puebla',
#   'distrito': '4',
#   'curul': 'B-033',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Tirsa Teresa Lezama Álvarez',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=349'},
#  {'legislatura': 60,
#   'id_legislador': 'f16b8dce-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Tirsa Teresa Lezama Álvarez',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Puebla',
#   'distrito': '4',
#   'curul': 'B-033',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=349'},
#  {'legislatura': 60,
#   'id_legislador': 'f19cffbc-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Díaz Garibay Felipe',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Michoacan',
#   'distrito': '4',
#   'curul': 'F-173',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Sonia Ayala Martínez',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=169'},
#  {'legislatura': 60,
#   'id_legislador': 'f19d0142-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Sonia Ayala Martínez',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Michoacan',
#   'distrito': '4',
#   'curul': 'F-173',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=169'},
#  {'legislatura': 60,
#   'id_legislador': 'f1ccbde2-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Díaz Gordillo Martha Cecilia (LICENCIA)',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Chiapas',
#   'distrito': '3',
#   'curul': 'F-171',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Javier Díaz Díaz',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=337'},
#  {'legislatura': 60,
#   'id_legislador': 'f1ccbf18-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Javier Díaz Díaz',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Chiapas',
#   'distrito': '3',
#   'curul': 'F-171',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=337'},
#  {'legislatura': 60,
#   'id_legislador': 'f201eefe-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Díaz Mena Joaquín Jesús (LICENCIA)',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Yucatan',
#   'distrito': '1',
#   'curul': 'J-337',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Teresa de Jesús Alcocer y Gazca',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=292'},
#  {'legislatura': 60,
#   'id_legislador': 'f201f03e-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Teresa de Jesús Alcocer y Gazca',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Yucatan',
#   'distrito': '1',
#   'curul': 'J-337',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=292'},
#  {'legislatura': 60,
#   'id_legislador': 'f236c228-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Díaz de León Torres Leticia',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'San Luis Potosi',
#   'distrito': '2',
#   'curul': 'F-162',
#   'suplente_propietario': 'P',
#   'name_suplente': 'José Luis Romero Baldazo',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=331'},
#  {'legislatura': 60,
#   'id_legislador': 'f236c354-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'José Luis Romero Baldazo',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'San Luis Potosi',
#   'distrito': '2',
#   'curul': 'F-162',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=331'},
#  {'legislatura': 60,
#   'id_legislador': 'f2659990-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Duck Núñez Edgar Mauricio',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Veracruz',
#   'distrito': '16',
#   'curul': 'F-168',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Alma Rosa Hernández Escobar',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=286'},
#  {'legislatura': 60,
#   'id_legislador': 'f2659ada-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Alma Rosa Hernández Escobar',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Veracruz',
#   'distrito': '16',
#   'curul': 'F-168',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=286'},
#  {'legislatura': 60,
#   'id_legislador': 'f2944c7c-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Enríquez Flores Armando',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Mexico',
#   'distrito': '26',
#   'curul': 'F-165',
#   'suplente_propietario': 'P',
#   'name_suplente': 'María Aurora Ovalles Castro',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=151'},
#  {'legislatura': 60,
#   'id_legislador': 'f2944dbc-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'María Aurora Ovalles Castro',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Mexico',
#   'distrito': '26',
#   'curul': 'F-165',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=151'},
#  {'legislatura': 60,
#   'id_legislador': 'f2cd92b6-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Escaroz Soler Gerardo Antonio (LICENCIA)',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Yucatan',
#   'distrito': '5',
#   'curul': 'E-127',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Gaspar Manuel Azarcoya Gutiérrez',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=296'},
#  {'legislatura': 60,
#   'id_legislador': 'f2cd9464-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Gaspar Manuel Azarcoya Gutiérrez',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Yucatan',
#   'distrito': '5',
#   'curul': 'E-127',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=296'},
#  {'legislatura': 60,
#   'id_legislador': 'f3025186-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Espinosa Piña José Luis',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Michoacan',
#   'distrito': '10',
#   'curul': 'P-503',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Laura González Martínez',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=175'},
#  {'legislatura': 60,
#   'id_legislador': 'f30253a2-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Laura González Martínez',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Michoacan',
#   'distrito': '10',
#   'curul': 'P-503',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=175'},
#  {'legislatura': 60,
#   'id_legislador': 'f334870a-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Félix Holguín Armando Jesús',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Sonora',
#   'distrito': '6',
#   'curul': 'D-094',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Lizbeth Flores Moreno',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=252'},
#  {'legislatura': 60,
#   'id_legislador': 'f3348930-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Lizbeth Flores Moreno',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Sonora',
#   'distrito': '6',
#   'curul': 'D-094',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=252'},
#  {'legislatura': 60,
#   'id_legislador': 'f36e3d7e-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Felton González Carlos Eduardo',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Sinaloa',
#   'distrito': '8',
#   'curul': 'G-207',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Nadia Haydee Vega Olivas',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=246'},
#  {'legislatura': 60,
#   'id_legislador': 'f36e3ebe-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Nadia Haydee Vega Olivas',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Sinaloa',
#   'distrito': '8',
#   'curul': 'G-207',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=246'},
#  {'legislatura': 60,
#   'id_legislador': 'f3a6b2a8-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Fernández Cabrera Adrián',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Ciudad de Mexico',
#   'distrito': '4',
#   'curul': 'D-087',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Adriana de Lourdes Hinojosa Céspedes',
#   'partido': 'pan',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=346'},
#  {'legislatura': 60,
#   'id_legislador': 'f3a6b528-fe1f-11ea-95ca-acde48001122',
#   'nombre_completo': 'Adriana de Lourdes Hinojosa Céspedes',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Ciudad de Mexico',
#   'distrito': '4',
#   'curul': 'D-087',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pan',
# ...
#   'entidad': 'Oaxaca',
#   'distrito': '6',
#   'curul': 'D-117',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pt',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=203'},
#  {'legislatura': 60,
#   'id_legislador': '536e4ade-fe20-11ea-95ca-acde48001122',
#   'nombre_completo': ' Joaquín Humberto Vela González',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Mexico',
#   'distrito': '5',
#   'curul': 'C-081',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Sánchez Estrada Ma. del Rosario',
#   'partido': 'pt',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=975'},
#  {'legislatura': 60,
#   'id_legislador': '536e4cd2-fe20-11ea-95ca-acde48001122',
#   'nombre_completo': 'Sánchez Estrada Ma. del Rosario',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Mexico',
#   'distrito': '5',
#   'curul': 'C-081',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pt',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=975'},
#  {'legislatura': 60,
#   'id_legislador': '53a777f0-fe20-11ea-95ca-acde48001122',
#   'nombre_completo': 'Solís Parga Rodolfo',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Guanajuato',
#   'distrito': '2',
#   'curul': 'E-160',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Rosalinda Díaz López',
#   'partido': 'pt',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=436'},
#  {'legislatura': 60,
#   'id_legislador': '53a779f8-fe20-11ea-95ca-acde48001122',
#   'nombre_completo': 'Rosalinda Díaz López',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Guanajuato',
#   'distrito': '2',
#   'curul': 'E-160',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'pt',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=436'},
#  {'legislatura': 60,
#   'id_legislador': '53e01e98-fe20-11ea-95ca-acde48001122',
#   'nombre_completo': 'Arriola Mónica',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Mexico',
#   'distrito': '5',
#   'curul': 'D-100',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Luis Alberto García Guerrero',
#   'partido': 'alianza',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=495'},
#  {'legislatura': 60,
#   'id_legislador': '53e02014-fe20-11ea-95ca-acde48001122',
#   'nombre_completo': 'Luis Alberto García Guerrero',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Mexico',
#   'distrito': '5',
#   'curul': 'D-100',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'alianza',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=495'},
#  {'legislatura': 60,
#   'id_legislador': '54150f4a-fe20-11ea-95ca-acde48001122',
#   'nombre_completo': 'Cárdenas Fonseca Manuel',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Sinaloa',
#   'distrito': '1',
#   'curul': 'D-098',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Dora Ma. Guadalupe Talamante Lemas',
#   'partido': 'alianza',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=487'},
#  {'legislatura': 60,
#   'id_legislador': '541510da-fe20-11ea-95ca-acde48001122',
#   'nombre_completo': 'Dora Ma. Guadalupe Talamante Lemas',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Sinaloa',
#   'distrito': '1',
#   'curul': 'D-098',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'alianza',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=487'},
#  {'legislatura': 60,
#   'id_legislador': '544a39e0-fe20-11ea-95ca-acde48001122',
#   'nombre_completo': 'Castillo Nájera Ariel',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Mexico',
#   'distrito': '5',
#   'curul': 'C-066',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Gabriel Romero Vázquez',
#   'partido': 'alianza',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=494'},
#  {'legislatura': 60,
#   'id_legislador': '544a3b2a-fe20-11ea-95ca-acde48001122',
#   'nombre_completo': 'Gabriel Romero Vázquez',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Mexico',
#   'distrito': '5',
#   'curul': 'C-066',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'alianza',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=494'},
#  {'legislatura': 60,
#   'id_legislador': '54801402-fe20-11ea-95ca-acde48001122',
#   'nombre_completo': 'Dávila Esquivel Humberto',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Coahuila',
#   'distrito': '2',
#   'curul': 'D-097',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Regina Mahelet Delgado Hernández',
#   'partido': 'alianza',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=489'},
#  {'legislatura': 60,
#   'id_legislador': '548015ce-fe20-11ea-95ca-acde48001122',
#   'nombre_completo': 'Regina Mahelet Delgado Hernández',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Coahuila',
#   'distrito': '2',
#   'curul': 'D-097',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'alianza',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=489'},
#  {'legislatura': 60,
#   'id_legislador': '54bfe082-fe20-11ea-95ca-acde48001122',
#   'nombre_completo': 'Gómez Pasillas Jacinto',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Chihuahua',
#   'distrito': '1',
#   'curul': 'D-096',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Raúl Armando Navarrete Ordóñez',
#   'partido': 'alianza',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=488'},
#  {'legislatura': 60,
#   'id_legislador': '54bfe1f4-fe20-11ea-95ca-acde48001122',
#   'nombre_completo': 'Raúl Armando Navarrete Ordóñez',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Chihuahua',
#   'distrito': '1',
#   'curul': 'D-096',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'alianza',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=488'},
#  {'legislatura': 60,
#   'id_legislador': '54f5ad7a-fe20-11ea-95ca-acde48001122',
#   'nombre_completo': 'Luna Becerril Blanca',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Ciudad de Mexico',
#   'distrito': '4',
#   'curul': 'C-063',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Karime Iyari Sevilla Álvarez',
#   'partido': 'alianza',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=493'},
#  {'legislatura': 60,
#   'id_legislador': '54f5aee2-fe20-11ea-95ca-acde48001122',
#   'nombre_completo': 'Karime Iyari Sevilla Álvarez',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Ciudad de Mexico',
#   'distrito': '4',
#   'curul': 'C-063',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'alianza',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=493'},
#  {'legislatura': 60,
#   'id_legislador': '552ce150-fe20-11ea-95ca-acde48001122',
#   'nombre_completo': 'Luna Rodríguez Silvia',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Aguascalientes',
#   'distrito': '2',
#   'curul': 'C-064',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Dayana Maricela De la Peña Cepeda',
#   'partido': 'alianza',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=490'},
#  {'legislatura': 60,
#   'id_legislador': '552ce2b8-fe20-11ea-95ca-acde48001122',
#   'nombre_completo': 'Dayana Maricela De la Peña Cepeda',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Aguascalientes',
#   'distrito': '2',
#   'curul': 'C-064',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'alianza',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=490'},
#  {'legislatura': 60,
#   'id_legislador': '55672ae0-fe20-11ea-95ca-acde48001122',
#   'nombre_completo': ' Miguel Ángel Jiménez Godínez',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Ciudad de Mexico',
#   'distrito': '4',
#   'curul': 'D-099',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Pérez Bolaños Ana Elisa',
#   'partido': 'alianza',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=992'},
#  {'legislatura': 60,
#   'id_legislador': '55672d10-fe20-11ea-95ca-acde48001122',
#   'nombre_completo': 'Pérez Bolaños Ana Elisa',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Ciudad de Mexico',
#   'distrito': '4',
#   'curul': 'D-099',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'alianza',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=992'},
#  {'legislatura': 60,
#   'id_legislador': '55a37252-fe20-11ea-95ca-acde48001122',
#   'nombre_completo': 'Piñeyro Arias Irma',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Oaxaca',
#   'distrito': '3',
#   'curul': 'C-065',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Cinthia Mabel Rosado Correa',
#   'partido': 'alianza',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=491'},
#  {'legislatura': 60,
#   'id_legislador': '55a373ce-fe20-11ea-95ca-acde48001122',
#   'nombre_completo': 'Cinthia Mabel Rosado Correa',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Oaxaca',
#   'distrito': '3',
#   'curul': 'C-065',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'alianza',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=491'},
#  {'legislatura': 60,
#   'id_legislador': '55de72ee-fe20-11ea-95ca-acde48001122',
#   'nombre_completo': 'Arvizu Rivas Aida Marina',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Ciudad de Mexico',
#   'distrito': '4',
#   'curul': 'A-013',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Lissette Jessica Rodríguez Haro',
#   'partido': 'psd',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=499'},
#  {'legislatura': 60,
#   'id_legislador': '55de746a-fe20-11ea-95ca-acde48001122',
#   'nombre_completo': 'Lissette Jessica Rodríguez Haro',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Ciudad de Mexico',
#   'distrito': '4',
#   'curul': 'A-013',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'psd',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=499'},
#  {'legislatura': 60,
#   'id_legislador': '562512ee-fe20-11ea-95ca-acde48001122',
#   'nombre_completo': 'Conde Rodríguez Elsa de Guadalupe',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Mexico',
#   'distrito': '5',
#   'curul': 'A-014',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Verónica Rodríguez López',
#   'partido': 'psd',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=500'},
#  {'legislatura': 60,
#   'id_legislador': '56251456-fe20-11ea-95ca-acde48001122',
#   'nombre_completo': 'Verónica Rodríguez López',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Mexico',
#   'distrito': '5',
#   'curul': 'A-014',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'psd',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=500'},
#  {'legislatura': 60,
#   'id_legislador': '565fa3c8-fe20-11ea-95ca-acde48001122',
#   'nombre_completo': 'García Méndez Armando',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Mexico',
#   'distrito': '5',
#   'curul': 'A-016',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Claudia Isabel Barrón Martínez',
#   'partido': 'psd',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=486'},
#  {'legislatura': 60,
#   'id_legislador': '565fa54e-fe20-11ea-95ca-acde48001122',
#   'nombre_completo': 'Claudia Isabel Barrón Martínez',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Mexico',
#   'distrito': '5',
#   'curul': 'A-016',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'psd',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=486'},
#  {'legislatura': 60,
#   'id_legislador': '569d49bc-fe20-11ea-95ca-acde48001122',
#   'nombre_completo': 'Hernández Valadés Delio',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Colima',
#   'distrito': '5',
#   'curul': 'B-041',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Antelmo Iglesias Bravo',
#   'partido': 'psd',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=480'},
#  {'legislatura': 60,
#   'id_legislador': '569d4b2e-fe20-11ea-95ca-acde48001122',
#   'nombre_completo': 'Antelmo Iglesias Bravo',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Colima',
#   'distrito': '5',
#   'curul': 'B-041',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'psd',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=480'},
#  {'legislatura': 60,
#   'id_legislador': '56d7358c-fe20-11ea-95ca-acde48001122',
#   'nombre_completo': 'Pedro Cortés Santiago Gustavo',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Ciudad de Mexico',
#   'distrito': '4',
#   'curul': 'A-015',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Alfonso Primitivo Ríos Vázquez',
#   'partido': 'psd',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=460'},
#  {'legislatura': 60,
#   'id_legislador': '56d736f4-fe20-11ea-95ca-acde48001122',
#   'nombre_completo': 'Alfonso Primitivo Ríos Vázquez',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Ciudad de Mexico',
#   'distrito': '4',
#   'curul': 'A-015',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'psd',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=460'},
#  {'legislatura': 60,
#   'id_legislador': '5711f96a-fe20-11ea-95ca-acde48001122',
#   'nombre_completo': 'Jiménez Valenzuela María Eugenia',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Nayarit',
#   'distrito': '2',
#   'curul': 'P-501',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Jorge López Jiménez',
#   'partido': 'sin partido',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=184'},
#  {'legislatura': 60,
#   'id_legislador': '5711fb18-fe20-11ea-95ca-acde48001122',
#   'nombre_completo': 'Jorge López Jiménez',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Nayarit',
#   'distrito': '2',
#   'curul': 'P-501',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'sin partido',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=184'},
#  {'legislatura': 60,
#   'id_legislador': '574bd612-fe20-11ea-95ca-acde48001122',
#   'nombre_completo': 'López Lena Cruz Humberto',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Oaxaca',
#   'distrito': '3',
#   'curul': 'L-428',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Carlos Humberto López Lena Pineda',
#   'partido': 'sin partido',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=452'},
#  {'legislatura': 60,
#   'id_legislador': '574bd770-fe20-11ea-95ca-acde48001122',
#   'nombre_completo': 'Carlos Humberto López Lena Pineda',
#   'tipo_legislador': 'Representacion proporcional',
#   'entidad': 'Oaxaca',
#   'distrito': '3',
#   'curul': 'L-428',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'sin partido',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=452'},
#  {'legislatura': 60,
#   'id_legislador': '57862bf0-fe20-11ea-95ca-acde48001122',
#   'nombre_completo': 'Ochoa López Nabor',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Colima',
#   'distrito': '2',
#   'curul': 'K-381',
#   'suplente_propietario': 'P',
#   'name_suplente': 'Ana María Cervantes Martínez',
#   'partido': 'sin partido',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=24'},
#  {'legislatura': 60,
#   'id_legislador': '57862d76-fe20-11ea-95ca-acde48001122',
#   'nombre_completo': 'Ana María Cervantes Martínez',
#   'tipo_legislador': 'Mayoria Relativa',
#   'entidad': 'Colima',
#   'distrito': '2',
#   'curul': 'K-381',
#   'suplente_propietario': 'S',
#   'name_suplente': '',
#   'partido': 'sin partido',
#   'link_curricula': 'http://sitllx.diputados.gob.mx/curricula.php?dipt=24'}]

# %%
with open('/Users/cblanesg/cam.blanes Dropbox/Camila Blanes/Congressional-dataMX/data/00-id_data/id_legislatura60.json', 'w') as json_file:
    json.dump(data_id62_clean, json_file)

# %%
with open('/Users/cblanesg/cam.blanes Dropbox/Camila Blanes/Congressional-dataMX/data/00-id_data/id_legislatura64.json') as d:
    data = json.load(d)

# %%
data[0]
# Out:
# {'legislatura': 64,
#  'id_legislador': 'cc9474dc-fd0e-11ea-83d8-acde48001122',
#  'nombre_completo': 'Aguilar Castillo Heriberto Marcelo',
#  'tipo_legislador': 'Mayoria Relativa',
#  'entidad': 'Sonora',
#  'distrito': '4',
#  'curul': 'K-405',
#  'suplente_propietario': 'P',
#  'name_suplente': 'Ramon Angel Valdez Mendoza',
#  'partido': 'MORENA',
#  'link_curricula': 'http://sitl.diputados.gob.mx/LXIV_leg/curricula.php?dipt=250'}

# %% [markdown]
# ## Comisiones

# %%
all_comisiones = []
for x, y in tqdm(zip(links_diputados, names_diputados), total = len(names_diputados)):
    driver.get(x)
    id_inc = mapping_id_cand[y]
    
    comisiones = driver.find_element_by_css_selector('body > div > table:nth-child(7) > tbody > tr > td > table:nth-child(1) > tbody > tr:nth-child(2) > td').text
    for i in re.sub('ORDINARIA', '', comisiones.split('\n')[0]).split('|'):
        if any(i):
            temp = {}
            temp['nombre_completo'] = y
            temp['id_legislador'] = id_inc
            temp['comision'] = re.sub('[ ]+$', '', re.sub('^[ ]+', '', i))
            all_comisiones.append(temp)
        else:
            continue
# Out:
# 100%|██████████| 500/500 [10:39<00:00,  1.28s/it]

# %%
def dummy_remove(x):
    if any(re.findall('GRUPO DE AMISTAD', x)):
        return(1)
    else:
        return(0)
df = pd.DataFrame(all_comisiones)
df['dummy_remove'] = df.apply(lambda x: dummy_remove(x['comision']), axis = 1)

# %%
df_comisiones = df[df['dummy_remove'] == 0]
df_comisiones = df_comisiones[['nombre_completo', 'id_legislador', 'comision']]

# %%
df_comisiones

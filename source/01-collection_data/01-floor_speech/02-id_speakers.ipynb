# %%
import json
import unidecode
import re
import pandas as pd
from fuzzywuzzy import process
from tqdm import tqdm

# %%
## Load ID data
with open('/Users/cblanesg/cam.blanes Dropbox/Camila Blanes/Congressional-dataMX/data/00-id_data/00-id/id_legislatura61.json') as f:
    data = json.load(f)

# %%
mapping = {}
for i in data:
    if i['nombre_completo'] not in mapping.keys():
        mapping[re.sub(' [(]licencia[)]', '', re.sub('^[ ]+', '', unidecode.unidecode(i['nombre_completo'].lower())))] = i['id_legislador']
    else:
        continue

len(mapping)

# %%
## Load speeches
with open('/Users/cblanesg/cam.blanes Dropbox/Camila Blanes/Congressional-dataMX/data/01-floor_speech/00-scrape_speeches/intervenciones_61.json') as f:
    data_speech = json.load(f)

# %%
missing_names = []
for i in data_speech:
    name = unidecode.unidecode(i['inc_name'].lower())
    try:
        if name == 'flores escalera hilda esthela':
            i['id'] = ''
        elif name == 'garza flores noe fernando':
            i['id'] = ''
        else:
            i['id'] = mapping[name]
    except:
        try:
            name_matched = process.extractOne(name, list(mapping.keys()))[0]
            print(name_matched, ', ', name)
            i['id'] = mapping[name_matched]
        except:
            if name not in missing_names:
                missing_names.append(name)
                i['id'] = ''
            else:
                continue

# %%
for i in data_speech:
    if i['id'] == '':
        print(i['inc_name'])
    else:
        continue

# %%
with open('/Users/cblanesg/cam.blanes Dropbox/Camila Blanes/Congressional-dataMX/data/01-floor_speech/01-floor_speech_id/intervenciones_dip61.json', 'w') as d:
    json.dump(data_speech, d)

# %%
with open('/Users/cblanesg/cam.blanes Dropbox/Camila Blanes/Congressional-dataMX/data/01-floor_speech/01-floor_speech_id/intervenciones_dip61.json') as d:
    data = json.load(d)

# %% [markdown]
# ## Legislatura 62

# %%
## Load ID data
with open('/Users/cblanesg/cam.blanes Dropbox/Camila Blanes/Congressional-dataMX/data/00-id_data/00-id/id_legislatura62.json') as f:
    data = json.load(f)

# %%
mapping = {}
for i in data:
    if i['nombre_completo'] not in mapping.keys():
        mapping[re.sub(' [(]licencia[)]', '', re.sub('^[ ]+', '', unidecode.unidecode(i['nombre_completo'].lower())))] = i['id_legislador']
    else:
        continue

len(mapping)
# Out:
# 999

# %%
## Load speeches
with open('/Users/cblanesg/cam.blanes Dropbox/Camila Blanes/Congressional-dataMX/data/01-floor_speech/00-scrape_speeches/intervenciones_62.json') as f:
    data_speech = json.load(f)

# %%
missing_names = []
for i in data_speech:
    name = unidecode.unidecode(i['inc_name'].lower())
    try:
        if name == 'acosta pena brasil alberto':
            i['id'] = ''
        elif name == 'cruz morales maricruz':
            i['id'] = ''
        elif name == 'funes velazquez erika yolanda':
            i['id'] = ''
        elif name == 'villasenor vargas maria de la paloma':
            i['id'] = ''
        else:
            i['id'] = mapping[name]
    except:
        try:
            name_matched = process.extractOne(name, list(mapping.keys()))[0]
            print(name_matched, ', ', name)
            i['id'] = mapping[name_matched]
        except:
            if name not in missing_names:
                missing_names.append(name)
                i['id'] = ''
            else:
                continue
# Out:
# rocio adriana abreu artinano ,  abreu artinano rocio adriana
# rocio adriana abreu artinano ,  abreu artinano rocio adriana
# rocio adriana abreu artinano ,  abreu artinano rocio adriana
# rocio adriana abreu artinano ,  abreu artinano rocio adriana
# rocio adriana abreu artinano ,  abreu artinano rocio adriana
# rocio adriana abreu artinano ,  abreu artinano rocio adriana
# rocio adriana abreu artinano ,  abreu artinano rocio adriana
# rocio adriana abreu artinano ,  abreu artinano rocio adriana
# rocio adriana abreu artinano ,  abreu artinano rocio adriana
# rocio adriana abreu artinano ,  abreu artinano rocio adriana
# rocio adriana abreu artinano ,  abreu artinano rocio adriana
# arroyo vieyra francisco ,  arroyo vieyra francisco agustin
# arroyo vieyra francisco ,  arroyo vieyra francisco agustin
# arroyo vieyra francisco ,  arroyo vieyra francisco agustin
# arroyo vieyra francisco ,  arroyo vieyra francisco agustin
# arroyo vieyra francisco ,  arroyo vieyra francisco agustin
# ...

# %%
for i in data_speech:
    if i['id'] == '':
        print(i['inc_name'])
    else:
        continue
# Out:
# Acosta Peña Brasil Alberto
# Acosta Peña Brasil Alberto
# Cruz Morales Maricruz
# Funes Velázquez Erika Yolanda
# Funes Velázquez Erika Yolanda
# Funes Velázquez Erika Yolanda
# Funes Velázquez Erika Yolanda
# Funes Velázquez Erika Yolanda
# Villaseñor Vargas María de la Paloma
# Villaseñor Vargas María de la Paloma
# Villaseñor Vargas María de la Paloma
# Villaseñor Vargas María de la Paloma
# Villaseñor Vargas María de la Paloma
# Villaseñor Vargas María de la Paloma
# Villaseñor Vargas María de la Paloma
# Villaseñor Vargas María de la Paloma
# Villaseñor Vargas María de la Paloma
# Villaseñor Vargas María de la Paloma
# Villaseñor Vargas María de la Paloma
# Villaseñor Vargas María de la Paloma
# Villaseñor Vargas María de la Paloma
# Villaseñor Vargas María de la Paloma

# %%
with open('/Users/cblanesg/cam.blanes Dropbox/Camila Blanes/Congressional-dataMX/data/01-floor_speech/01-floor_speech_id/intervenciones_dip62.json', 'w') as d:
    json.dump(data_speech, d)

# %%
with open('/Users/cblanesg/cam.blanes Dropbox/Camila Blanes/Congressional-dataMX/data/01-floor_speech/01-floor_speech_id/intervenciones_dip61.json') as d:
    data = json.load(d)

# %%
clean_ = []
for i in data:
    i['legislatura'] = 61
    clean_.append(i)

# %%
with open('/Users/cblanesg/cam.blanes Dropbox/Camila Blanes/Congressional-dataMX/data/01-floor_speech/01-floor_speech_id/intervenciones_dip61.json', 'w') as d:
    json.dump(clean_, d)

# %%
## Load ID data
with open('/Users/cblanesg/cam.blanes Dropbox/Camila Blanes/Congressional-dataMX/data/00-id_data/00-id/id_legislatura61.json') as f:
    data = json.load(f)


mapping = {}
for i in data:
    if i['nombre_completo'] not in mapping.keys():
        mapping[re.sub(' [(]licencia[)]', '', re.sub('^[ ]+', '', unidecode.unidecode(i['nombre_completo'].lower())))] = i['id_legislador']
    else:
        continue

len(mapping)

## Load speeches
with open('/Users/cblanesg/cam.blanes Dropbox/Camila Blanes/Congressional-dataMX/data/01-floor_speech/00-scrape_speeches/intervenciones_61.json') as f:
    data_speech = json.load(f)

from fuzzywuzzy import process

missing_names = []
for i in data_speech:
    name = unidecode.unidecode(i['inc_name'].lower())
    try:
        if name == 'flores escalera hilda esthela':
            i['id'] = ''
        elif name == 'garza flores noe fernando':
            i['id'] = ''
        else:
            i['id'] = mapping[name]
    except:
        try:
            name_matched = process.extractOne(name, list(mapping.keys()))[0]
            print(name_matched, ', ', name)
            i['id'] = mapping[name_matched]
        except:
            if name not in missing_names:
                missing_names.append(name)
                i['id'] = ''
            else:
                continue

for i in data_speech:
    if i['id'] == '':
        print(i['inc_name'])
    else:
        continue

# %%
process.extractOne('sanchez de la fuente melchor', ['melchor sanchez de la fuente'])

# %%
len(missing_names)

# %%
missing_names

# %%
list(mapping.keys())
